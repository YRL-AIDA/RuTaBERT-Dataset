# %% [markdown]
# # Чтение данных

# %%
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

df_cleansed = pd.read_csv("df_cleansed.csv", sep=";")
df_cleansed.shape
# Out:
# (3371478, 3)

# %% [markdown]
# # Лемматизация
#
# *Дальнейшая кластеризация строится на предположении, что первое существительное в заголовке столбца отражает ту сущность, которая в нем содержится*

# %% [markdown]
# ## Работа с подвыборкой, из-за нехватки ресурсов

# %%
df_cleansed_sample = df_cleansed.sample(random_state=2023, frac=0.02)
df_cleansed_sample
# Out:
#                                                table_id  column_id  \
# 2720148  dataset/Dataset/data/3483326/table_6_meta.json          1
# 2167367  dataset/Dataset/data/5318820/table_1_meta.json          0
# 2438329  dataset/Dataset/data/2077534/table_3_meta.json          1
# 2649773  dataset/Dataset/data/1603484/table_2_meta.json          1
# 1782388  dataset/Dataset/data/3057834/table_6_meta.json          3
# ...                                                 ...        ...
# 1525628  dataset/Dataset/data/4403233/table_0_meta.json          0
# 643388   dataset/Dataset/data/4166863/table_0_meta.json          0
# 3181561  dataset/Dataset/data/6592321/table_0_meta.json          2
# 313452   dataset/Dataset/data/2977964/table_0_meta.json          0
# 2886820  dataset/Dataset/data/8469092/table_0_meta.json          2
#
#                                      column_name
# 2720148                      алгоритм шифрования
# 2167367                                     чарт
# 2438329                           легендас  года
# 2649773  титулы по меступроведенияматчей турнира
# 1782388                                   яванцы
# ...                                          ...
# 1525628                                      год
# 643388             условные цветовые обозначения
# 3181561                         русское название
# 313452                                       год
# 2886820                               годы жизни
#
# [67430 rows x 3 columns]

# %% [markdown]
# ## 3. Построение леммы для первого слова заголовка

# %%
import spacy
nlp = spacy.load("ru_core_news_sm", disable=['parser', 'ner'])

# %%
def lemmatize_first_word(sequence: str) -> str:
    for token in nlp(sequence):
        if token.pos_ == "NOUN":
            return token.lemma_
    return None

df_cleansed_sample["first_noun"] = df_cleansed_sample["column_name"].progress_apply(lemmatize_first_word)
# Out:
# 100%|████████████████████████████████████| 67430/67430 [01:28<00:00, 762.64it/s]

# %%
df_cleansed_sample["first_noun"].isna().sum()
# Out:
# 3593

# %%
df_cleansed_sample[df_cleansed_sample["first_noun"].isna()]['column_name'].unique()
# Out:
# array(['откууда', 'режиссры', 'европа', 'режисср', 'жлтый', 'пропущено',
#        'четвртый', 'запасной', 'первый', 'нац', 'погибло', 'зубные',
#        'том', 'конечные остановкиаб', 'всего', 'символшлефли', 'третий',
#        'испанский', 'за что получена', 'дома', 'фил', 'итого',
#        'квалифицирована как', 'я луна', 'эргативный', 'таксон', 'куда',
#        'франция', 'площадькм', 'спущен', 'партнр', 'ф и о', 'азотное',
#        'вен', 'патронус', 'исландия', 'амк', 'передние', 'и после',
#        'авестийский', 'вицегубернаторанглрусскк', 'синонимы', 'третья',
#        'гласные', 'соправители', 'ничьи', 'мсб', 'горная', 'начало',
#        'задненбные', 'самый результативный', 'ранено', 'шел', 'нов',
#        'когда использовался', 'налт', 'второй', 'я пада', 'вступил',
#        'населениечел', 'сша', 'побит', 'умер', 'хун', 'произведено',
#        'дополнительно', 'независимые', 'крп', 'видзв', 'синий',
#        'винительный', 'платформаы', 'нушл', 'построено', 'австралия',
#        'номинирован', 'русский', 'ателт', 'лигадивизион',
#        'впервые использован', 'французский', 'майнацу бас токио',
#        'крутой', 'начинается на', 'сербия', 'инфинитив', 'берлин',
#        'взрослый', 'хитпарад', 'синоним', 'прочие', 'детройт ред уингз',
#        'базовая ате', 'номерпосева', 'автомашин', 'микс', 'творительный',
#        'что', 'пит', 'задний', 'оканчивающиеся на', 'дин', 'выпущена',
#        'впервые использован с', 'андорра получила', 'игорь матвиенко',
#        'ваханский', 'кры', 'похоронен', 'подъм', 'общая', 'приобретена',
#        'юниор', 'синий и голубой', 'основан', 'новыйалфавит', 'аверс',
#        'молодежная', 'итальянский', 'дэвид цукер', 'китай', 'кто',
#        'россия', 'кокс', 'палатальные', 'хохфильцен', 'гуджарати',
#        'частотный каналггц', 'стив ривз', 'цзюани', 'бортовойномер',
#        'управляющий', 'дзонгхаг', 'возд', 'заложен', 'мвв',
#        'за что награждена', 'центральные блокирующие', 'весенняя', 'г п',
#        'гло', 'вдв', 'вдовцывдовы', 'индивидуальная', 'штрафные',
#        'подробнее', 'молоджная', 'смягчнный гласный', 'един', 'ярус',
#        'михаил шуфутинский', 'д  в', 'ско', 'фриделин', 'указан как',
#        'кому объявил', 'лабиовелярные', 'проигравший', 'чел', 'перепись',
#        'шту', 'тав', 'кому служила', 'твсеть', 'сеяные', 'прочее',
#        'девятый', 'вил', 'энантиомер донепезил', 'двойственный', 'пхвзи',
#        'сербский иекавский и боснийский', 'губные', 'выведен',
#        'алфавит касем буркинафасо', 'ариете', 'дания', 'губногубные',
#        'санскрит', 'пят', 'эпоним', 'м сб', 'короткий', 'что соединяет',
#        'неназализованные', 'учреждена', 'принят', 'эло', 'хват',
#        'средняя', 'соединениевершинно транзитивны', 'стала княгиней',
#        'максим дунаевский', 'участницаы', 'телесеть', 'юве',
#        'июльнагоя бас нагоя', 'оригинальный', 'перед а о у', 'алт',
#        'за что награждн', 'польский', 'исполнительныйпродюсер',
#        'всего чел', 'входит в', 'потеряно лтчиков', 'ттх', 'открыт',
#        'клеро', 'ливерпуль', 'иные', 'урл', 'нбные', 'сибсельмаш', 'вул',
#        'глоттальные', 'годан', 'ком', 'белый', 'бтрб', 'теленовелла',
#        'италия', 'отрицат', 'контрадмирал', 'награжднный',
#        'стандартный немецкий', 'велярные', 'юрий николаев', 'задние',
#        'челси', 'тбдсм', 'уэс', 'последнийгранпри', 'днепродзержинск',
#        'китайский', 'гранпри', 'соло', 'отправлен в', 'откуда',
#        'именительный', 'проведеногранпри', 'размерымм', 'несеяные',
#        'средние', 'пропилен', 'множественное', 'там', 'азия', 'длит',
#        'весг', 'нидерландский', 'мили', 'действительны при',
#        'стандартный  или', 'гассиев', 'наивпоз', 'турция', 'обо',
#        'служебнаямассатонн', 'согласные', 'гюйс', 'уил', 'японский',
#        'допсв', 'текущий сетевой партнр', 'нас', 'среднеязычные',
#        'китай цев', 'манчестер юнайтед', 'производная', 'шлефли',
#        'носовые', 'вит', 'сам', 'выиграно', 'мн косв', 'закрытостановлен',
#        'основана', 'сттрана', 'городское', 'сибирь', 'массаг', 'кнр',
#        'зара', 'алфавит йемба', 'задние гласные', 'асомтаврули', 'сла',
#        'суханкина', 'уефа', 'монтажры', 'мячипен', 'юрм', 'объм см',
#        'позывные', 'плюс', 'ничьих', 'алфавит', 'тайское',
#        'гласные слоговые', 'канада квебек', 'не имеет',
#        'на азербайджанском', 'количествозапусков', 'самоанский',
#        'спонсорские', 'лац', 'мол', 'заказано', 'направительный',
#        'хацу бас', 'паракомпактная', 'чужой', 'дер', 'английский', 'вба',
#        'мехико', 'федерер', 'нина демурова', 'олим', 'скр', 'заложена',
#        'восточная европа', 'сим', 'й вмф', 'эрроминчела', 'нью',
#        'успешных', 'объм', 'голландский', 'красный', 'скауз', 'цска',
#        'показательные', 'заболевшие', 'заднеязычные', 'когда принят',
#        'населнныйпункт', 'лабиальные', 'переднеязычные', 'уна',
#        'остальные', 'стандартный албанский', 'в сша', 'высокие',
#        'чтениезапись', 'на русском', 'ста', 'джулианна мюррей',
#        'окончаниеполномочий', 'картчрнобелых', 'порядковые', 'в гц',
#        'шанхай шэньхуа', 'л дв ч', 'латинский', 'вицеадмирал', 'под',
#        'мхедрули', 'пн на гсо', 'устаревший', 'грузовые',
#        'зубныеальвеолярные', 'спинофф', 'последующие', 'мастерская',
#        'альвеолярные', 'заглавные', 'гостевая', 'ном', 'яванский',
#        'золототонн', 'вакуумные трубчатые', 'сыграно', 'германия',
#        'первыйгранпри', 'х захариан', 'нив', 'ретрофлексные', 'чм европы',
#        'интердентальные', 'полное', 'безразлично', 'неверующие',
#        'родился', 'элементовгрупп', 'всегокм', 'актр дубляжа',
#        'барселона', 'зато', 'древнеисландская', 'сампрадая', 'рос',
#        'брно', 'что номинировано', 'лидия козлова',
#        'уступили жириновскому', 'ретороманский', 'алфавит леле',
#        'по всей россии', 'номинирован за', 'зеленые', 'против', 'ккто',
#        'ала', 'спаслось', 'итоговоеместо', 'разъм', 'немецкий',
#        'разведнные', 'назарбаев на', 'для десятичных', 'пасьют',
#        'голевые', 'против всех', 'хен', 'камон', 'бах', 'хяким', 'забито',
#        'они', 'чср', 'в ср', 'авиационные', 'глоттальный',
#        'электрические', 'зубные  альвеолярные', 'классические',
#        'начинается на гласный', 'китайский п', 'лучший связующий',
#        'александр розенбаум', 'финиши', 'перси', 'населениетыс чел',
#        'поставлено', 'т см', 'ошер', 'эскорпион', 'вебсайт', 'евразия',
#        'вел', 'лос', 'постоянноенаселениечел  г', 'македонские',
#        'глоттал', 'алла сурикова', 'взамен', 'объм л', 'марокко', 'нсш',
#        'зво', 'межзубные', 'кэф', 'двс', 'сел', 'лео', 'соланидан',
#        'мн ч', 'мво', 'численностьчел', 'что символизирует',
#        'актерактриса', 'мощностьпри обмин', 'грузтонны', 'см также',
#        'в японии', 'посвящн', 'центральные', 'сферическое', 'тасн', 'адм',
#        'ака', 'даурский', 'вверх', 'сарыкольский', 'дрожащие', 'вюнст',
#        'номерраздела', 'самюэль адамс', 'продано', 'увулярные',
#        'количественные', 'лучший', 'лозанна', 'страленберг', 'открыта',
#        'теофил', 'америка', 'адм единица', 'проиграно', 'хорватский',
#        'количествобарангаев', 'мод', 'абу', 'сюффрен', 'полт',
#        'зрителеймлн', 'лингвистическая', 'завершен', 'шугнанский',
#        'драхма', 'геом', 'четыре', 'впн', 'списан', 'нусхури', 'хур',
#        'кем выдвинут', 'чему учит', 'сербский и боснийский', 'кто выбил',
#        'лиль', 'онлайн', 'неогубленный', 'заст', 'айз',
#        'премьерав японии', 'ямз', 'трое', 'лолита', 'мур', 'гим',
#        'конечный', 'джекцы', 'глоттализованные', 'местный',
#        'рекомендуемые', 'муг', 'кубм', 'жальгирис', 'поступило',
#        'бортовой', 'хокк', 'борац чачак', 'актуальное', 'более',
#        'колвокоманд', 'другие', 'ромадзи', 'селт', 'мкч', 'сенегал',
#        'горноалеманнский зенслерисский', 'никак', 'зубные альвеолярные',
#        'новеместо', 'южная корея', 'лег', 'ничьитай', 'губнозубные',
#        'закрыт', 'арджун', 'нбутилен', 'частичнонеудачных', 'страйкауты',
#        'бревно', 'квалифицировалась как', 'существительное',
#        'всего продано', 'генеральная', 'сформирована', 'числокоммун',
#        'ным', 'индия', 'вмс', 'поларис', 'майкл', 'сек', 'коптский',
#        'кумулятивный', 'англфранц', 'мэн', 'заводскойномер',
#        'аудиообразец', 'филипп каи', 'китайское', 'вместе с',
#        'великобритания отдала', 'первичная атете', 'менделеев',
#        'минимальные', 'подряд', 'не определились', 'общий', 'приво',
#        'рабочий объм', 'макэведи и джонс', 'максимальнаяскоростькмч',
#        'сферическая', 'илч', 'нич', 'тен', 'великобритания',
#        'лучшееместо', 'высшееместо', 'нпентан', 'алексей чумаков',
#        'николай валуев', 'вторая', 'абсвелич', 'будапешт', 'считалось',
#        'пластин макс', 'ден', 'также вышел', 'рлр', 'лучшийсвязующий',
#        'рена', 'тве', 'старый', 'ари', 'циклические', 'авс', 'аякс',
#        'чешский', 'заказан', 'бод', 'самая высокая', 'нить', 'а е',
#        'звонкие', 'времямс', 'шмельм', 'ср авг', 'спродюсировано с',
#        'ср скоростькмч', 'и с', 'про', 'лил', 'подси', 'лабиодентальные',
#        'лигерад', 'три', 'жит', 'изменениепоз', 'стандартная',
#        'альтернативное', 'заказанные', 'питтсбург пингвинз',
#        'ганнушкин п б', 'вак', 'отдельно стоящие', 'кмнд', 'баттерфляй',
#        'эрмэв', 'пгс', 'зеленый', 'шдд', 'хбс', 'ньютон', 'прошедшее',
#        'драфт', 'волол', 'разведнныеофициально', 'боснийский', 'чар',
#        'елена ваенга', 'проигравшие', 'египет', 'транслит', 'саскачеван',
#        'предкидеди  фон веттина', 'стоя', 'ара', 'южные', 'белорусский',
#        'п  о', 'выбыло', 'эск', 'вла', 'иркутск', 'странатерритория чарт',
#        'осенняя', 'стрелять', 'постальвеолярные', 'вильнюс', 'нап',
#        'высшпоз', 'претерит', 'цифровой', 'мужжен', 'хаз', 'брахмана',
#        'рабочий объм л', 'пал', 'пофф', 'карен', 'повят', 'чем управлял',
#        'фуцзяньский', 'дентальные', 'кнж', 'могул', 'центральноюпикский',
#        'мтрл', 'концепткар', 'призовые', 'оаэ', 'инк', 'южная',
#        'см мстас', 'гвадалахара', 'представляет', 'горловые',
#        'рабочий объм см', 'халле', 'итоговыйсчт', 'буфернаязона',
#        'михаил стефанович', 'сидней', 'гродно', 'порусски', 'уильямс',
#        'абр', 'финляндия', 'кро', 'годаа', 'лукашенко', 'пратюркский',
#        'кем назначен', 'джесси джеймс', 'всего погибших', 'суо',
#        'атематический', 'дэвис', 'максскоростькмч', 'за что получен',
#        'кинг', 'вершин', 'барнард', 'где', 'все опрошенные',
#        'производствотонны', 'кау', 'трихлорэтилен', 'оскар', 'ссср',
#        'женский парный', 'грузия', 'циолковский', 'за что вручен',
#        'типоваяполезнаянагрузкаспутниккосмическийкорабльитп', 'единый',
#        'тестпилотыы', 'шяс', 'поддерживаемые ос', 'джон адамс',
#        'где использовался', 'общее', 'я категория',
#        'далеко от говорящего близко к слушающему', 'файткард', 'усс',
#        'рау', 'императив', 'кпн', 'объмсм', 'согласный', 'обратно',
#        'финикийские', 'рад', 'заменяет', 'пн на со', 'номиналсенов',
#        'эль', 'синомимы', 'нейтральные', 'алфавит дагари гана', 'аты',
#        'афелий ае', 'впоследствии', 'потенциальное нак', 'зан',
#        'макс скоростькмч', 'городрегионстрана', 'общие', 'они пртяж',
#        'корейские числительные', 'дисс кджмоль', 'светосила', 'долгий',
#        'туркмены', 'из нак', 'пирахан', 'экстрактг мл',
#        'знаковый меньше беззнакового а беззнаковый не менее', 'средний',
#        'неудачных', 'романчук', 'кпрф', 'лилль', 'выпущен', 'забил',
#        'кратко', 'погибших', 'лин', 'берза партиярешительныхграждан',
#        'поставлялся с', 'защит', 'восточный', 'п в',
#        'впервыеопубликована', 'по пб', 'алфавит пана', 'асу',
#        'китайский у', 'энв', 'украина', 'умерло чел', 'покинуть', 'учные',
#        'к с', 'внутренние', 'полином', 'клапанов', 'шкала', 'мммммм',
#        'зрит', 'отст', 'пятый', 'угольмлнтонн', 'сопернк', 'кекв',
#        'си ло', 'странычлены', 'злотый', 'проживает', 'тот', 'австрия',
#        'чфр', 'дредноут', 'выбрано', 'из них посмертно', 'голыс пен',
#        'ркх', 'конечные', 'долгие гласные', 'намечено', 'описан в',
#        'октавные', 'мимтвмив', 'рисуноктело', 'гаусс', 'очковая',
#        'проиграли', 'воздержались', 'древнеанглийский', 'венгрия',
#        'новых заболевших', 'да и нет', 'злаковые', 'клапаны грм', 'также',
#        'святая', 'кто объявил', 'традиционные', 'опередил зюганова',
#        'парадная', 'эксклюзив', 'услобоз', 'ссылкаи', 'пятое',
#        'альтернптивное', 'ккрб', 'окленд', 'казахский', 'пассивы', 'сто',
#        'самый результативнай', 'кому присуждается', 'корпоративная',
#        'проксима центавра', 'единственное', 'ли фанкуэй',
#        'топоним склоняется', 'содержит', 'совр турецкий', 'п по',
#        'финалов', 'командная', 'чтное', 'плотностькгл', 'леман', 'атб',
#        'неполноечастное', 'млр', 'е местонесеянные', 'когда',
#        'полугласные неслоговые', 'катакана', 'гремио', 'гвав',
#        'одушевлнное', 'выбыли в юккнен', 'греческий', 'татарскийязык',
#        'александр новиков', 'уайт', 'жанры', 'имястрана',
#        'номинированы за', 'записан', 'выглядит', 'ман', 'названиеангл',
#        'горнохимическая'], dtype=object)

# %% [markdown]
# # Создание эмбеддингов
# Для кластеризации удаляем столбцы, для которых не было получено ембеддингов

# %%
import gensim.downloader
import numpy as np

ru_model = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def get_embedding(word: str) -> list|None:
    try:
        return ru_model.__getitem__([f"{word}_NOUN"])[0].astype(float)
    except KeyError:
        return None

df_cleansed_sample["embedding"] = df_cleansed_sample["first_noun"].progress_apply(get_embedding)
df_cleansed_sample
# Out:
# 100%|█████████████████████████████████| 67430/67430 [00:00<00:00, 235130.03it/s]
#                                                table_id  column_id  \
# 2720148  dataset/Dataset/data/3483326/table_6_meta.json          1
# 2167367  dataset/Dataset/data/5318820/table_1_meta.json          0
# 2438329  dataset/Dataset/data/2077534/table_3_meta.json          1
# 2649773  dataset/Dataset/data/1603484/table_2_meta.json          1
# 1782388  dataset/Dataset/data/3057834/table_6_meta.json          3
# ...                                                 ...        ...
# 1525628  dataset/Dataset/data/4403233/table_0_meta.json          0
# 643388   dataset/Dataset/data/4166863/table_0_meta.json          0
# 3181561  dataset/Dataset/data/6592321/table_0_meta.json          2
# 313452   dataset/Dataset/data/2977964/table_0_meta.json          0
# 2886820  dataset/Dataset/data/8469092/table_0_meta.json          2
#
#                                      column_name   first_noun  \
# 2720148                      алгоритм шифрования     алгоритм
# 2167367                                     чарт         чарт
# 2438329                           легендас  года     легендас
# 2649773  титулы по меступроведенияматчей турнира        титул
# 1782388                                   яванцы       яванец
# ...                                          ...          ...
# 1525628                                      год          год
# 643388             условные цветовые обозначения  обозначение
# 3181561                         русское название     название
# 313452                                       год          год
# 2886820                               годы жизни          год
#
#                                                  embedding
# 2720148  [0.04933843016624451, -0.04191359877586365, -0...
# 2167367  [0.029721805825829506, 0.03733756020665169, -0...
# 2438329                                               None
# 2649773  [0.12037932872772217, -0.047469932585954666, -...
# 1782388  [0.0452362522482872, -0.030167412012815475, -0...
# ...                                                    ...
# 1525628  [-0.02274102345108986, -0.043927066028118134, ...
# 643388   [0.07376829534769058, 0.031282924115657806, -0...
# 3181561  [0.15615154802799225, 0.042191389948129654, -0...
# 313452   [-0.02274102345108986, -0.043927066028118134, ...
# 2886820  [-0.02274102345108986, -0.043927066028118134, ...
#
# [67430 rows x 5 columns]

# %% [markdown]
# ## Фильтрация столбцов, для которых не построились эмбеддинги

# %%
mask_hasnt_embedding = df_cleansed_sample["embedding"].isna()
df_cleansed_sample = df_cleansed_sample[~mask_hasnt_embedding]
df_cleansed_sample = df_cleansed_sample.drop_duplicates(subset=["first_noun"]) 
df_cleansed_sample
# Out:
#                                                table_id  column_id  \
# 2720148  dataset/Dataset/data/3483326/table_6_meta.json          1
# 2167367  dataset/Dataset/data/5318820/table_1_meta.json          0
# 2649773  dataset/Dataset/data/1603484/table_2_meta.json          1
# 1782388  dataset/Dataset/data/3057834/table_6_meta.json          3
# 3370842  dataset/Dataset/data/1176153/table_0_meta.json          3
# ...                                                 ...        ...
# 2318256   dataset/Dataset/data/184282/table_1_meta.json          2
# 2446801  dataset/Dataset/data/6625005/table_0_meta.json          5
# 51431    dataset/Dataset/data/3630710/table_6_meta.json          3
# 737424   dataset/Dataset/data/3732326/table_0_meta.json          0
# 2638026  dataset/Dataset/data/2405858/table_0_meta.json          3
#
#                                      column_name first_noun  \
# 2720148                      алгоритм шифрования   алгоритм
# 2167367                                     чарт       чарт
# 2649773  титулы по меступроведенияматчей турнира      титул
# 1782388                                   яванцы     яванец
# 3370842                         полное население  население
# ...                                          ...        ...
# 2318256        без подпора в облицованном канале     подпор
# 2446801                             белорусы тыс    белорус
# 51431                                    девочки    девочка
# 737424                         файловый менеджер   менеджер
# 2638026                            вдкриття року        рок
#
#                                                  embedding
# 2720148  [0.04933843016624451, -0.04191359877586365, -0...
# 2167367  [0.029721805825829506, 0.03733756020665169, -0...
# 2649773  [0.12037932872772217, -0.047469932585954666, -...
# 1782388  [0.0452362522482872, -0.030167412012815475, -0...
# 3370842  [0.032919786870479584, -0.030262669548392296, ...
# ...                                                    ...
# 2318256  [0.013514978811144829, 0.04030410572886467, -0...
# 2446801  [0.01209559291601181, 0.09944429993629456, 0.0...
# 51431    [-0.09372813254594803, 0.060462430119514465, -...
# 737424   [-0.027020612731575966, -0.027391137555241585,...
# 2638026  [-0.04953337088227272, 0.10413207858800888, 0....
#
# [2180 rows x 5 columns]

# %% [markdown]
# # Кластеризация
#
# ---
#
# https://github.com/src-d/kmcuda
#
# TODO: HDBSCAN
#
# ---

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### Silhouette-coefficient
#
# https://scikit-learn.org/stable/modules/clustering.html#silhouette-coefficient
#
# Более высокая оценка коэффициента относится к модели с лучше определенными кластерами.
#
# Коэффициент силуэт определен для каждой точки и состоит из двух оценок:
#
# $a$ - среднее расстояние между  и всеми другими точками в кластере
#
# $b$ - среднее расстояние между точкой и всеми другими точками в другом ближайшем кластере
#
# Для конкретной точки, коэффициент рассчитывается:
#
# $s = \dfrac{b - a}{max(a, b)}$
#
# Для оценки кластеризации используется среднее из всех значений коэффициента для каждой точки.
#
# *Advantages:*
# - Оценка находится на отрезке [-1; 1], где -1 для некорректных кластеров, +1 для очень плотных кластеров. Оценки около нуля указывают на пересекающиеся кластеры.
# - Оценка выше, когда кластеры плотные и хорошо разделены
#
# *Drawbacks:*
# - Коэффициент обычно выше для выпуклых кластеров, чем для других концепций кластеров, таких как кластеры, основанные на плотности (DBSCAN)

# %%
from sklearn import metrics

def silhouette_score(X, labels, metric="euclidean"):
    return metrics.silhouette_score(X, labels, metric=metric)

# %% [markdown]
# ### Calinski-Harabasz index
#
# https://scikit-learn.org/stable/modules/clustering.html#calinski-harabasz-index
#
# Индекс представляет собой отношение суммы межкластерной дисперсии и внутрикластерной дисперсии для всех кластеров (где дисперсия определяется как сумма квадратов расстояний):
#
# Для набора данных $S$ размера $n_E$, который был сгруппирован в $k$ кластеров, оценка Калински-Харабаша определяется как соотношение среднего значения межкластерной дисперсии и внутрикластерной дисперсии:
#
# $s = \dfrac{tr(B_k)}{tr(W_k)} * \dfrac{n_e - k}{k - 1}$
#
# где $tr(B_k)$ является сумма элементов главной диагонали матрицы межгрупповой дисперсии и $tr(W_k)$ — сумма элементов главной диагонали матрицы внутрикластерной дисперсии:
#
# $W_k = \sum_{q=1}^{k}\sum_{x \in C_q}{(x-c_q)(x-c_q)^T}$
#
# $B_k = \sum_{q=1}^{k}n_q*(c_q-c_E)(c_q-c_E)^T$
#
# $C_q$ набор точек в кластере $q$, $c_q$ - центр кластера $q$, $c_E$ - центр $E$, $n_q$ - число точек в кластере $q$.
#
# Advantages:
# - Оценка выше, когда кластеры плотные и хорошо разделены
# - Оценка быстро вычисляется
#
# Drawbacks:
# - Коэффициент обычно выше для выпуклых кластеров, чем для других концепций кластеров, таких как кластеры, основанные на плотности (DBSCAN)

# %%
def calinski_harabasz_index(X, labels):
    return metrics.calinski_harabasz_score(X, labels)

# %% [markdown]
# ### Davies-Bouldin index
#
# https://scikit-learn.org/stable/modules/clustering.html#davies-bouldin-index
#
# Оценка интерпретируется, как среднее сходство между кластерами, где сходство — это мера, которая сравнивает расстояние между кластерами с размер самих кластеров.
#
# Минимальная оценка = 0. Значения близкие к нулю, указывают на лучшее разбиение.
#
# Индекс определяется как среднее сходство между каждым кластером $C_i, i = 1, ..., k$ и самым похожим на него $C_j$. В контексте этом показателе сходство определяется как мера $R_{ij}$:
#
# $R_{ij} = \dfrac{s_i + s_j}{d_{ij}}$
#
# где:
#
# $s_i$ среднее расстояние между каждой точкой кластера $i$ и центра тяжести этого кластера.
#
# $d_{ij}$ расстояние между центрами кластеров $i$ и $j$.
#
#
# $DB = \dfrac{1}{k} * \sum_{i=1}^{k} \max_{i \neq j} R{ij}$
#
# Преимущества:
# - Расчет показателей проще, чем расчет показателей Silhouette.
# - Индекс основывается исключительно на величинах и характеристиках, присущих набору данных, поскольку при его расчете используются только расстояния между точками.
#
# Недостатки:
# - Коэффициент обычно выше для выпуклых кластеров, чем для других концепций кластеров, таких как кластеры, основанные на плотности (DBSCAN)
# - Использование расстояния до центроида ограничивает метрику расстояния евклидовым пространством.

# %%
def davies_bouldin_index(X, labels):
    return metrics.davies_bouldin_score(X, labels)

# %% [markdown]
# ### Get metrics values

# %%
def get_metrics(X, labels):
    metrics = dict()
    metrics["silhouette_score"] = silhouette_score(X, labels)
    metrics["calinski_harabasz_index"] = calinski_harabasz_index(X, labels)
    metrics["davies_bouldin_index"] = davies_bouldin_index(X, labels)

    return metrics

# %% [markdown]
# ## Ram info

# %%
import os

sample = True

mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')
ram = mem_bytes / (1024. ** 3)
ram
# Out:
# 14.983638763427734

# %% [markdown]
# ## Reshape embeddings

# %%
import numpy as np
from random import randint

rs = 13

embeddings_reshaped = np.array(list(map(lambda x: x, df_cleansed_sample["embedding"])))
embeddings_reshaped.shape

df_cls = pd.DataFrame()
df_cls["first_noun"] = df_cleansed_sample["first_noun"]

# %%
def get_cluster_id_words(cluster_name: str):
    cluster_to_word = dict()
    for cluster_id in df_cls[cluster_name].unique():
        cluster_to_word[cluster_id] = df_cls[df_cls[name] == cluster_id]["first_noun"].unique()
    
    return cluster_to_word

def print_cluster_to_word(cluster_dict: dict, threshold: int = 1):
    for i in cluster_dict.keys():
        if len(cluster_dict[i]) > threshold:
            print(i, cluster_dict[i], len(cluster_dict[i]))

# %% [markdown]
# ## DBSCAN; memory complexity($N^2$)
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html
#
#
# Алгоритм DBSCAN рассматривает кластеры как области высокой плотности. разделены областями с низкой плотностью. Из-за этого довольно общего взгляда кластеры найденное с помощью DBSCAN, может иметь любую форму, в отличие от k-средних, которое предполагает, что кластеры имеют выпуклую форму.
#
# Алгоритм DBSCAN является детерминированным и всегда генерирует одни и те же кластеры. когда даны одни и те же данные в том же порядке. Однако результаты могут отличаться, когда данные предоставляются в другом порядке.
#
# Текущая реализация использует ball-trees и kd-trees.
#
# Эта реализация неэффективна с точки зрения использования памяти, на больших датасетах лучше использовать OPTICS или HDBSCAN

# %%
if sample or ram > 20:
    from sklearn.cluster import DBSCAN
    
    name = "dbscan"
    model = DBSCAN
    
    df_cls[name] = model(eps=0.9, min_samples=2).fit_predict(embeddings_reshaped)

    cluster_dict = get_cluster_id_words(name)
    print_cluster_to_word(cluster_dict)
else:
    print("Not enough memory")
# Out:
# 0 ['алгоритм' 'показатель' 'способ' 'динамика' 'использование'
#  'характеристика' 'прирост' 'уровень' 'величина' 'оценка' 'метод'
#  'классификация' 'индекс' 'критерий' 'компонент' 'размерность' 'параметр'
#  'ввп' 'эффективность' 'коэффициент' 'наличие' 'технология'
#  'результативность' 'техника' 'применение' 'отсутствие' 'анализ'
#  'исследование'] 28
# -1 ['чарт' 'яванец' 'категория' ... 'подпор' 'менеджер' 'рок'] 1432
# 1 ['титул' 'звание' 'должность' 'чин'] 4
# 2 ['население' 'житель'] 2
# 3 ['матч' 'мяч' 'кубок' 'спортсмен' 'турнир' 'игрок' 'соревнование' 'финал'
#  'пилот' 'поул' 'чемпион' 'сборная' 'чемпионат' 'игра' 'старт' 'финиш'
#  'суперкубок' 'атлет' 'теннисист' 'тренер' 'спринт' 'вратарь'
#  'спортсменка' 'гонка' 'фигурист' 'заезд' 'гонщик' 'футболист'
#  'нападающий' 'полузащитник' 'первенство' 'динамо' 'чемпионка' 'велоспорт'
#  'ралли' 'юниор' 'форвард' 'шайба' 'спорт' 'полуфинал' 'плейофф'
#  'бундеслига' 'биатлонист' 'фигуристка' 'олимпиада' 'гимнастка'
#  'состязание' 'овертайм' 'спартак' 'хоккеист' 'многоборье' 'тайм'
#  'пенальти' 'гимнаст' 'лыжник' 'волейбол' 'суперлига' 'шахматист'
#  'торпедо' 'баскетбол' 'олимпиакос' 'баскетболист' 'бешикташ'
#  'четвертьфинал'] 64
# 4 ['название' 'наименование'] 2
# 5 ['очки' 'очко'] 2
# 6 ['страна' 'регион' 'государство' 'империя'] 4
# 7 ['имя' 'фамилия'] 2
# 8 ['соперник' 'соперница' 'конкурент'] 3
# 9 ['год' 'месяц' 'день' 'выходной' 'минута' 'вечер' 'час' 'неделя'
#  'праздник' 'понедельник' 'суббота' 'воскресение'] 12
# 10 ['персонаж' 'сюжет' 'жанр' 'эпизод' 'герой'] 5
# 11 ['сертификация' 'сертификат'] 2
# 12 ['итог' 'результат'] 2
# 13 ['победитель' 'победительница'] 2
# 14 ['млн' 'вес' 'сумма' 'процент' 'кг' 'тыс' 'тонна' 'руб' 'среднее'
#  'миллион' 'сотня' 'тысяча'] 12
# 15 ['планета' 'юпитер' 'эксцентриситет' 'космос' 'астероид' 'сатурн'
#  'вселенная' 'перигелий'] 8
# 16 ['город' 'столица' 'провинция' 'пригород'] 4
# 17 ['издание' 'переиздание' 'тираж' 'сборник' 'заглавие' 'заметка' 'издатель'
#  'книга' 'строка' 'рецензия' 'публикация' 'издательство' 'статья'
#  'заголовок' 'журнал' 'редактор' 'страница' 'библия'] 18
# 18 ['номинация' 'конкурс' 'жюри' 'приз'] 4
# 19 ['сценарист' 'фильм' 'режиссура' 'зритель' 'премьера' 'студия' 'песня'
#  'артист' 'театр' 'президент' 'актриса' 'сериал' 'композитор' 'архитектор'
#  'фестиваль' 'спектакль' 'художник' 'танец' 'музыка' 'поэт' 'скульптура'
#  'хореограф' 'либретто' 'музыкант' 'кино' 'сцена' 'сценарий' 'мультфильм'
#  'телесериал' 'опера' 'постановщик' 'танцор' 'драматург' 'солист' 'труппа'
#  'скульптор' 'экранизация' 'киностудия' 'пьеса' 'балет' 'исполнительница'
#  'ария' 'ммкф' 'премьер'] 44
# 20 ['факультет' 'колледж' 'университет' 'кафедра' 'ректор'] 5
# 21 ['армия' 'фронт' 'судно' 'капитан' 'корабль' 'отряд' 'дивизия' 'войско'
#  'дивизион' 'офицер' 'штурман' 'порт' 'флот' 'боец' 'полк' 'командир'
#  'танк' 'генерал' 'водоизмещение' 'штаб' 'бригада' 'борт' 'адмирал'
#  'военный' 'начальник' 'тоннаж' 'танкер' 'эскадрон' 'артиллерия' 'палуба'
#  'командующий' 'солдат'] 32
# 22 ['отель' 'мажестик'] 2
# 23 ['деталь' 'подробность'] 2
# 24 ['судьба' 'участь'] 2
# 25 ['владелец' 'собственник'] 2
# 26 ['награда' 'медаль'] 2
# 27 ['лауреат' 'премия'] 2
# 28 ['значение' 'смысл'] 2
# 29 ['язык' 'диалект'] 2
# 30 ['число' 'количество'] 2
# 31 ['группа' 'подгруппа'] 2
# 32 ['двигатель' 'шасси' 'автомобиль' 'мотор' 'машина' 'мотоцикл' 'движок'
#  'кузов' 'зажигание' 'карбюратор' 'авто' 'трансмиссия'] 12
# 33 ['исполнитель' 'исполнение'] 2
# 34 ['напряжение' 'частота' 'ток' 'эдс' 'индуктивность' 'вольтаж'] 6
# 35 ['бомбардировщик' 'штурмовка' 'аэродром' 'авиакомпания' 'аэропорт'
#  'эскадрилья' 'эксплуатант' 'истребитель' 'авиация' 'авиалиния'] 10
# 36 ['пассажиропоток' 'грузооборот' 'грузопоток' 'пассажирооборот'] 4
# 37 ['серебро' 'золото' 'никель' 'металл' 'платина'] 5
# 38 ['участник' 'лидер' 'руководитель' 'участница' 'директор' 'руководство'
#  'организатор' 'лидерство' 'инициатор'] 9
# 39 ['автор' 'соавтор'] 2
# 40 ['брак' 'супруг'] 2
# 41 ['экран' 'обслуживание' 'сервис' 'процессор' 'сервер' 'видеокарта'
#  'модуль' 'дисплей' 'пользователь' 'озу' 'хостинг'] 11
# 42 ['противник' 'бой' 'сражение' 'атака'] 4
# 43 ['голос' 'бас'] 2
# 44 ['окончание' 'завершение'] 2
# 45 ['декабрь' 'май' 'июль' 'январь' 'август' 'февраль' 'октябрь' 'июнь'
#  'март' 'апрель' 'сентябрь'] 11
# 46 ['правительство' 'власть'] 2
# 47 ['метр' 'км' 'километр' 'верста'] 4
# 48 ['рождаемость' 'смертность'] 2
# 49 ['погон' 'петлица'] 2
# 50 ['градус' 'мфа' 'вещество' 'температура' 'руда' 'частица' 'препарат'
#  'доза' 'алкан' 'компартмент' 'липаза' 'ингибирование' 'плавление'
#  'кислород' 'лекарство' 'сингония' 'кислота' 'днп' 'гипертермия'
#  'античастица' 'треонин' 'нуклид' 'фосфор' 'концентрация' 'минерал'
#  'гистамин' 'медикамент' 'стереоизомер' 'икосаэдр' 'цельсий' 'активность'] 31
# 51 ['фотография' 'фото' 'портрет' 'альбом' 'гравюра' 'картинка' 'рисунок'] 7
# 52 ['комментарий' 'пояснение'] 2
# 53 ['продажа' 'предприятие' 'производитель' 'производство' 'дистрибьютор'
#  'бренд' 'компания' 'выпуск' 'фирма' 'экспорт' 'поставщик'
#  'промышленность' 'изделие' 'дистрибутор' 'контракт' 'нефтепереработка'
#  'договор' 'потребление' 'отрасль' 'продукция' 'рынок' 'сбыт' 'импорт'
#  'поставка' 'завод'] 25
# 54 ['таблица' 'диаграмма'] 2
# 55 ['пантера' 'леопард'] 2
# 56 ['длительность' 'продолжительность' 'интервал'] 3
# 57 ['вооружение' 'оружие'] 2
# 58 ['конструктор' 'разработчик' 'окб'] 3
# 59 ['вершина' 'плато' 'устье' 'река' 'гора' 'хребет' 'озеро'] 7
# 60 ['рыба' 'улов'] 2
# 61 ['дизайн' 'дизайнер'] 2
# 62 ['тв' 'сми' 'телеканал'] 3
# 63 ['обозначение' 'представление' 'понятие' 'термин'] 4
# 64 ['пассажир' 'паровоз' 'локомотив' 'поезд' 'вагон'] 5
# 65 ['начало' 'конец'] 2
# 66 ['продюсер' 'кинокомпания'] 2
# 67 ['трасса' 'автодром'] 2
# 68 ['африка' 'штат' 'ирландия' 'япония' 'америка' 'чехия' 'португалия'
#  'бельгия' 'шотландия' 'гвинея' 'швеция' 'англия' 'норвегия' 'зеландия'] 14
# 69 ['организация' 'объединение'] 2
# 70 ['длина' 'диаметр' 'радиус' 'ширина' 'толщина' 'мм'] 6
# 71 ['фракция' 'лдпр' 'дпр' 'спс'] 4
# 72 ['оля' 'женщина' 'девушка' 'мужчина' 'юноша' 'девочка'] 6
# 73 ['подбор' 'отбор'] 2
# 74 ['стадия' 'этап' 'фаза'] 3
# 75 ['кредит' 'банк' 'погашение' 'инвестор' 'эмитент'] 5
# 76 ['алфавит' 'буква' 'латиница' 'кириллица' 'глаголица'] 5
# 77 ['информация' 'данные' 'сведение'] 3
# 78 ['председатель' 'член' 'комитет' 'совет' 'секретарь' 'комиссия'] 6
# 79 ['эмблема' 'атрибут' 'символ'] 3
# 80 ['прибыль' 'бюджет' 'заработок' 'расход' 'налог' 'доход'] 6
# 81 ['этнос' 'национальность' 'народ' 'нация' 'вероисповедание' 'народность'] 6
# 82 ['защитник' 'защита'] 2
# 83 ['изменение' 'сдвиг'] 2
# 84 ['восток' 'север' 'запад'] 3
# 85 ['еврей' 'гагауз' 'армянин' 'венгр' 'киргиз' 'мусульманин' 'немец' 'шах'
#  'араб' 'литовец' 'мордва' 'украинец' 'татарин' 'султан' 'грузин'
#  'болгарин' 'поляк' 'турок' 'башкир' 'серб' 'курд' 'перс' 'чех' 'черкес'
#  'адыгеец' 'осетин' 'латыш' 'бей' 'белорус'] 29
# 86 ['съезд' 'созыв' 'конгресс' 'конференция'] 4
# 87 ['кратер' 'извержение'] 2
# 88 ['диапазон' 'спектр'] 2
# 89 ['патрон' 'ппш' 'винтовка'] 3
# 90 ['энергоблок' 'аэс' 'реактор' 'ускоритель'] 4
# 91 ['отдел' 'заведующий'] 2
# 92 ['судья' 'суд'] 2
# 93 ['дуэль' 'поединок'] 2
# 94 ['формула' 'множитель' 'уравнение'] 3
# 95 ['четверть' 'половина'] 2
# 96 ['текст' 'цитата'] 2
# 97 ['тема' 'тематика'] 2
# 98 ['запуск' 'ракета'] 2
# 99 ['радио' 'радиостанция' 'передатчик'] 3
# 100 ['транспорт' 'груз' 'перевозка'] 3
# 101 ['фигурка' 'фигура'] 2
# 102 ['вязкость' 'плотность'] 2
# 103 ['дифтонг' 'альтернация' 'аффриката' 'частотность' 'фонема' 'аффикс'] 6
# 104 ['цена' 'стоимость' 'тариф'] 3
# 105 ['уезд' 'волость' 'село' 'деревня'] 4
# 106 ['религия' 'идеология'] 2
# 107 ['верфь' 'судоверфь'] 2
# 108 ['родитель' 'отец'] 2
# 109 ['запах' 'аромат'] 2
# 110 ['оригинал' 'копия'] 2
# 111 ['запрет' 'ограничение'] 2
# 112 ['храм' 'духовенство' 'церковь' 'причт' 'священник' 'часовня' 'собор'] 7
# 113 ['структура' 'функция' 'формирование' 'создание'] 4
# 114 ['королева' 'герцогиня' 'императрица'] 3
# 115 ['белград' 'югославия'] 2
# 116 ['эра' 'эпоха' 'тысячелетие' 'век'] 4
# 117 ['субрегион' 'атр'] 2
# 118 ['прыжок' 'бросок'] 2
# 119 ['созвездие' 'звезда'] 2
# 120 ['семейство' 'семья'] 2
# 121 ['минимум' 'максимум'] 2
# 122 ['заболевание' 'болезнь'] 2
# 123 ['звук' 'звучание'] 2
# 124 ['роман' 'повесть' 'рассказ'] 3
# 125 ['широта' 'долгота'] 2
# 126 ['сенатор' 'советник'] 2
# 127 ['предок' 'потомок'] 2
# 128 ['свойство' 'способность'] 2
# 129 ['доходность' 'котировка'] 2
# 130 ['потеря' 'утрата'] 2
# 131 ['депутат' 'голосование' 'парламент' 'референдум' 'избиратель' 'дума'] 6
# 132 ['кореец' 'китаец'] 2
# 133 ['дуб' 'дерево' 'ветвь'] 3
# 134 ['путь' 'дорога'] 2
# 135 ['выигрыш' 'проигрыш'] 2
# 136 ['комбинация' 'сочетание'] 2
# 137 ['независимость' 'свобода'] 2
# 138 ['ром' 'вино'] 2
# 139 ['кабинет' 'гостиная'] 2
# 140 ['музей' 'экспонат'] 2
# 141 ['южн' 'зап'] 2
# 142 ['строительство' 'строитель'] 2
# 143 ['монастырь' 'монах'] 2
# 144 ['физиология' 'химия'] 2
# 145 ['таджик' 'казах'] 2
# 146 ['платье' 'костюм'] 2
# 147 ['монарх' 'царь'] 2
# 148 ['жир' 'масло'] 2
# 149 ['бок' 'спина'] 2
# 150 ['заказ' 'заказчик' 'подрядчик'] 3

# %%
get_metrics(embeddings_reshaped, df_cls[name])
# Out:
# {'silhouette_score': -0.06462939856511825,
#  'calinski_harabasz_index': 2.9887848074062586,
#  'davies_bouldin_index': 1.9067114563621759}

# %%
len(df_cls['dbscan'].unique())
# Out:
# 152

# %% [markdown]
# ## Affinity propagation; memory comp.($N^2$), time comp.($N^2 * T$)
#
# AffinityPropagation создает кластеры, посылая сообщения между парами образцов до сходимости. Затем набор данных описывается с помощью небольшого числа образцов, которые определяются как наиболее репрезентативные для других образцов.
#
# Сообщения, отправляемые между парами, представляют собой оценку пригодности одного образца быть образцом другого, которая обновляется в зависимости от значений, полученных от других пар.
#
# Это обновление происходит итеративно до сходимости, после чего выбираются окончательные образцы, и, следовательно, получается окончательная кластеризация.

# %%
if sample or ram > 50:
    from sklearn.cluster import AffinityPropagation
    
    name = "affinity_prop"
    model = AffinityPropagation
    df_cls[name] = model().fit_predict(embeddings_reshaped)

    cluster_dict = get_cluster_id_words(name)
    print_cluster_to_word(cluster_dict)
else:
    print("Not enough memory")
# Out:
# 101 ['алгоритм' 'модель' 'координата' 'характеристика' 'объект' 'модификация'
#  'константа' 'диапазон' 'ксп' 'компонент' 'стандарт' 'фактор'
#  'размерность' 'параметр' 'вероятность' 'техпроцесс' 'вариант' 'разбиение'
#  'спецификация' 'периодичность' 'вариация' 'кластер' 'зависимость'
#  'распределение' 'диаграмма' 'шкала' 'точность' 'пропорциональность'
#  'отображение'] 29
# 173 ['чарт' 'лейбл' 'релиз' 'сингл' 'трек' 'дискография' 'саундтрек' 'хит'
#  'мультиплекс' 'тихомир' 'жаргонизм' 'ремикс' 'лэйбл' 'слоган' 'наив'
#  'мантра'] 16
# 4 ['титул' 'звание' 'должность' 'ранг' 'гражданство' 'карьера' 'присвоение'
#  'разряд' 'чин' 'кавалер' 'профессия' 'сан'] 12
# 193 ['яванец' 'уйгур' 'кореец' 'кантон' 'айн' 'приамурье' 'китаец'] 7
# 24 ['население' 'регион' 'статус' 'муниципалитет' 'субъект' 'субрегион'
#  'освоенность' 'ресурс' 'кузбасс' 'федерация' 'миграция' 'атр' 'ингушетия'] 13
# 188 ['категория' 'транскрипция' 'обозначение' 'транслитерация' 'префикс' 'мас'
#  'принадлежность' 'единица' 'артикль' 'падеж' 'нек' 'деление' 'эквивалент'
#  'комбинация' 'частотность' 'индивид' 'соссюр' 'валентность'
#  'маскулинность' 'самоназвание' 'переоткрытие' 'пси' 'пм' 'просодия'
#  'контекст' 'аффикс' 'сиб' 'местоимение' 'употребление' 'греча'] 30
# 0 ['матч' 'команда' 'финал' 'раунд' 'очко' 'игра' 'гол' 'сет' 'динамо'
#  'шайба' 'полуфинал' 'плейофф' 'ничья' 'локомотив' 'рапид' 'арбитр' 'ска'
#  'овертайм' 'спартак' 'блиц' 'тайм' 'квн' 'пенальти' 'торпедо' 'цдка'
#  'четвертьфинал'] 26
# 163 ['партия' 'макашов' 'фракция' 'лдпр' 'дпр' 'спс' 'яблоко' 'референдум'
#  'коалиция' 'кампания'] 10
# 47 ['позиция' 'линия' 'направление' 'сторона' 'толчок' 'точка' 'путь' 'охват'
#  'уклон' 'прорыв'] 10
# 59 ['мяч' 'игрок' 'клуб' 'стадион' 'теннисист' 'тренер' 'вратарь' 'футболист'
#  'нападающий' 'полузащитник' 'зенит' 'форвард' 'хоккеист' 'неудачник'
#  'бутсы' 'волейбол' 'шахматист' 'баскетболист' 'теннисистка'] 19
# 1 ['название' 'имя' 'наименование' 'слово' 'адрес' 'честь' 'фамилия'
#  'основатель' 'прозвище' 'псевдоним'] 10
# 26 ['очки' 'погон' 'петлица' 'шеврон' 'подбой' 'ношение'] 6
# 63 ['дата' 'дст' 'список' 'фио' 'документ' 'мандат' 'банкнот' 'явка'
#  'подпись' 'акт' 'запись' 'пакет' 'протокол'] 13
# 73 ['страна' 'правительство' 'государство' 'община' 'королевство' 'гражданин'
#  'независимость' 'республика' 'конфедерация' 'власть' 'общество' 'империя'] 12
# 23 ['кубок' 'сезон' 'турнир' 'соревнование' 'слалом' 'лига' 'поул' 'чемпион'
#  'сборная' 'заплыв' 'чемпионат' 'старт' 'финиш' 'спринт' 'гонка' 'заезд'
#  'эстафета' 'забег' 'первенство' 'чемпионка' 'велоспорт' 'ралли' 'юниор'
#  'биатлонист' 'фигуристка' 'олимпиада' 'состязание' 'многоборье' 'фукуока'
#  'лидерство' 'индианаполис' 'суперлига' 'марафон' 'баскетбол'] 34
# 49 ['место' 'расположение' 'местонахождение' 'местоположение'
#  'месторасположение'] 5
# 150 ['торговля' 'валюта' 'выпуск' 'экспорт' 'квота' 'ввп' 'сальдо'
#  'потребление' 'рынок' 'импорт' 'поставка'] 11
# 2 ['соперник' 'соперница' 'пас' 'оппонент' 'претендент' 'рестлер'
#  'конкурент'] 7
# 43 ['дисциплина' 'мероприятие' 'центр' 'деятельность' 'участие' 'организация'
#  'программа' 'ассоциация' 'фонд' 'поддержка' 'объединение' 'сообщество'
#  'представительство' 'нкз' 'членство' 'сда' 'подразделение' 'ячейка'
#  'союз' 'ппс' 'подготовка' 'учреждение' 'рсо' 'бюро'] 24
# 19 ['год' 'срок' 'месяц' 'день' 'мес' 'час' 'неделя' 'зима'] 8
# 164 ['порядок' 'мера' 'режим' 'барьер' 'выбор' 'предел' 'запрет' 'превышение'
#  'свобода' 'ограничение' 'норма'] 11
# 91 ['численность' 'млн' 'кг' 'тыс' 'тонна' 'руб' 'среднее' 'шт'] 8
# 3 ['спортсмен' 'атлет' 'спортсменка' 'бокс' 'фигурист' 'гонщик' 'дистанция'
#  'конькобежец' 'велогонщик' 'рекорд' 'спорт' 'водник' 'гимнастка'
#  'гимнаст' 'лыжник' 'лыжница' 'пловец' 'самбо'] 18
# 30 ['примечание' 'персоналия' 'замечание' 'комментарий' 'текст' 'упоминание'
#  'цитата' 'пояснение' 'умолчание' 'ответ' 'комментатор'] 11
# 108 ['свдп' 'мфа' 'микрограмм' 'реакция' 'ед' 'ген' 'алкан' 'подкласс' 'домен'
#  'компартмент' 'липаза' 'ингибирование' 'крс' 'тиг' 'акцентуация' 'мышца'
#  'днп' 'белок' 'кпр' 'нуклеотид' 'треонин' 'нер' 'нуклид'
#  'чувствительность' 'концентрация' 'ирт' 'сог' 'аст' 'среда' 'способность'
#  'гистамин' 'минерализация' 'реципиент' 'рецептор' 'локализация' 'эдм'
#  'активность'] 37
# 45 ['персонаж' 'композиция' 'сюжет' 'жанр' 'сага' 'тема' 'эпизод' 'мотив'
#  'тематика' 'пролог' 'раскадровка' 'герой' 'диалог'] 13
# 198 ['мон' 'кат' 'вва' 'вис' 'бре' 'гро' 'зен' 'беш' 'рош' 'кам' 'гал' 'ои'
#  'сол' 'олд' 'тро' 'спо' 'кас' 'кру' 'каз' 'ске' 'хард' 'инт' 'ноо'] 23
# 82 ['сертификация' 'разрешение' 'лицензия' 'сертификат' 'контракт' 'заявка'
#  'договор' 'выдача' 'мкк' 'франшиза' 'лицензиат'] 11
# 70 ['роль' 'артист' 'актриса' 'преподавательница' 'амплуа' 'драматург'
#  'знаменитость' 'сценаристка' 'исполнительница'] 9
# 5 ['итог' 'показатель' 'рождаемость' 'динамика' 'состояние' 'прирост'
#  'рейтинг' 'уровень' 'балл' 'индекс' 'критерий' 'темп' 'индикатор'
#  'коэффициент' 'баланс' 'обеспеченность' 'отметка'] 17
# 148 ['вид' 'род' 'подвид' 'фин' 'племя' 'триба' 'ареал' 'имаго' 'неарктика'
#  'нор' 'тенер' 'аус'] 12
# 93 ['тип' 'степень' 'особенность' 'разнообразие' 'признак' 'черта' 'характер'] 7
# 22 ['победитель' 'победа' 'трофей' 'поражение' 'знамя' 'вождь'] 6
# 113 ['результат' 'нтк' 'квалификация' 'качество' 'масштаб' 'доступность'
#  'эффект' 'выработка' 'приоритет' 'эффективность' 'твд' 'контроль'
#  'возможность' 'повышение' 'риск' 'результативность' 'совместимость'
#  'производительность'] 18
# 200 ['лек' 'дир' 'кош' 'осм' 'окс' 'арг' 'бир' 'бом' 'бур' 'заб' 'кал' 'диз'
#  'гур' 'лут'] 14
# 156 ['эволюция' 'рост' 'отставание' 'достижение' 'образование' 'прогресс'
#  'создание' 'распространение' 'развитие' 'расширение' 'экспансия'
#  'обогащение' 'культура' 'регресс'] 14
# 157 ['работа' 'чтение' 'занятие' 'упражнение'] 4
# 10 ['номер' 'отель' 'либра' 'майами' 'спа' 'бангкок' 'метрдотель' 'пасифик'
#  'бар' 'мажестик'] 10
# 196 ['нагрузка' 'планка' 'напряжение' 'эксцентриситет' 'мощность' 'частота'
#  'скорость' 'энергия' 'бс' 'кориолис' 'нейтраль' 'контур' 'ток' 'эдс'
#  'импульс' 'кабель' 'зазор' 'индуктивность' 'сверловка' 'вольтаж' 'сжатие'] 21
# 128 ['кан' 'тор' 'хет' 'атл' 'бер' 'чак' 'заруб' 'мит' 'ард'] 9
# 6 ['планета' 'орбита' 'юпитер' 'космос' 'мир' 'астероид' 'кратер' 'ио'
#  'луна' 'созвездие' 'земля' 'звезда' 'спутник' 'шар' 'извержение' 'сатурн'
#  'полушарие' 'светимость' 'астронавт' 'вселенная' 'перигелий'] 21
# 7 ['город' 'столица' 'провинция' 'житель' 'бел' 'поселение' 'окрестность'
#  'новгород' 'квартал' 'пожар' 'деревня' 'резиденция' 'ессентуки'
#  'пригород'] 14
# 8 ['издание' 'серия' 'перевод' 'переиздание' 'каталог' 'тираж' 'сборник'
#  'заглавие' 'календарь' 'издатель' 'энциклопедия' 'книга' 'публикация'
#  'издательство' 'журнал' 'редактор' 'страница' 'библия'] 18
# 27 ['номинация' 'награда' 'лауреат' 'премия' 'медаль' 'жюри' 'приз' 'гук'
#  'академик' 'вклад' 'вручение'] 11
# 55 ['вес' 'размер' 'длина' 'величина' 'диаметр' 'кольцо' 'радиус' 'ширина'
#  'толщина' 'нарез' 'мм' 'ярд' 'рис' 'цилиндр' 'куб' 'сечение'] 16
# 9 ['сценарист' 'фильм' 'экран' 'продюсер' 'дубляж' 'фильмография' 'клип'
#  'сериал' 'показ' 'роб' 'дубль' 'прокат' 'прокатчик' 'мультсериал' 'кино'
#  'видеоклип' 'сценарий' 'мультфильм' 'комикс' 'телесериал' 'озвучивание'
#  'просмотр' 'метраж' 'кинокомпания' 'лента' 'экранизация' 'киностудия'
#  'анимация' 'ммкф'] 29
# 80 ['факультет' 'курс' 'аудитория' 'колледж' 'университет' 'кафедра' 'ректор'
#  'магистратура' 'школа'] 9
# 42 ['армия' 'корпус' 'фронт' 'отряд' 'дивизия' 'войско' 'дивизион' 'разведка'
#  'полк' 'командир' 'генерал' 'штаб' 'бригада' 'кав' 'гв' 'сал' 'эскадрон'
#  'артиллерия' 'ая' 'ково' 'командующий'] 21
# 85 ['расстояние' 'метр' 'км' 'километр' 'верста'] 5
# 209 ['основание' 'пример' 'аргумент' 'доказательство' 'признание'] 5
# 184 ['деталь' 'покрытие' 'могул' 'устройство' 'прочность' 'схема' 'монтаж'
#  'конструкция' 'габарит'] 9
# 41 ['рио' 'остров' 'африка' 'америка' 'колумбия' 'океания' 'гвинея'
#  'зеландия' 'александрия' 'нигер'] 10
# 46 ['марка' 'производитель' 'производство' 'дистрибьютор' 'бренд' 'компания'
#  'фирма' 'поставщик' 'вещатель' 'изделие' 'дистрибутор' 'продукт'
#  'продукция' 'маркировка' 'сбыт' 'экспонент'] 16
# 179 ['номинал' 'банк' 'асв' 'адр' 'инвестор' 'эмитент' 'котировка' 'сделка'] 8
# 11 ['судьба' 'участь' 'будущее' 'рок'] 4
# 34 ['способ' 'использование' 'носитель' 'размещение' 'действие' 'передача'
#  'база' 'реализация' 'средство' 'тос' 'соответствие' 'воздействие'
#  'аналог' 'наличие' 'технология' 'замена' 'техника' 'применение'
#  'сочетание' 'питание'] 20
# 144 ['ратификация' 'получение' 'исполнение' 'введение' 'вступление' 'принятие'
#  'подача'] 7
# 83 ['шоу' 'режиссура' 'зритель' 'премьера' 'студия' 'театр' 'телеверсия'
#  'фестиваль' 'спектакль' 'действо' 'хореограф' 'постановка' 'сцена'
#  'постановщик' 'труппа' 'стд' 'пьеса'] 17
# 94 ['пол' 'возраст' 'женщина' 'телосложение' 'мужчина' 'человек'
#  'гомосексуальность'] 7
# 197 ['поз' 'петух' 'охотник' 'любитель'] 4
# 12 ['владелец' 'хозяин' 'обладатель' 'владение' 'посетитель' 'гильдия'
#  'продавец' 'собственник'] 8
# 18 ['пункт' 'район' 'микрорайон' 'подрайон' 'местность' 'территория' 'округ'
#  'зона' 'участок' 'пгт' 'райцентр' 'вах' 'пос'] 13
# 138 ['цвет' 'чистота' 'алк' 'запах' 'аромат' 'цветок' 'вкус'] 7
# 13 ['время' 'пора' 'минута' 'момент' 'ожидание'] 5
# 77 ['значение' 'смысл' 'предмет' 'представление' 'понятие' 'формулировка'
#  'образ' 'термин' 'суть' 'знание' 'ценность' 'выражение'] 12
# 14 ['язык' 'эсперанто' 'спряжение' 'произношение' 'переводчик' 'диалект'
#  'письменность' 'акцент'] 8
# 17 ['число' 'масса' 'количество' 'вместимость' 'запас' 'содержание' 'колич'
#  'большинство'] 8
# 51 ['ита' 'сплит' 'бонус' 'дизайн' 'обслуживание' 'сервис' 'сеть' 'офис'
#  'бизнес' 'туризм' 'услуга' 'хостинг' 'комплектация' 'менеджер'] 14
# 161 ['пилот' 'бомбардировщик' 'штурмовка' 'вооружение' 'вылет' 'аэродром'
#  'ант' 'перехват' 'танк' 'сау' 'эскадрилья' 'тб' 'истребитель' 'авиация'
#  'авма' 'су'] 16
# 25 ['бронза' 'серебро' 'золото' 'монета' 'рубин' 'добыча' 'клад'] 7
# 75 ['конь' 'гурт' 'вол' 'раб' 'повозка' 'тит'] 6
# 15 ['группа' 'класс' 'состав' 'подгруппа' 'ряд' 'одиночка' 'саф'] 7
# 67 ['номинант' 'подиум' 'медалист' 'конкурс' 'участница' 'финалистка'
#  'финалист' 'победительница' 'стэм' 'олимпия' 'итт' 'фила' 'мисс'
#  'евровидение' 'итс' 'рэнди'] 16
# 165 ['сумма' 'кредит' 'долг' 'погашение' 'начисление' 'списание'] 6
# 16 ['двигатель' 'реверс' 'шасси' 'мотор' 'привод' 'движок' 'зажигание' 'бак'
#  'стабилизатор' 'тяга' 'карбюратор' 'тормоз' 'трансмиссия'] 13
# 199 ['исполнитель' 'получатель' 'изготовитель' 'заказ' 'заказчик' 'подрядчик'] 6
# 152 ['изображение' 'образец' 'иллюстрация' 'мозаика' 'оригинал' 'этикетка'
#  'резьба' 'гравюра' 'рисунок' 'картина' 'репродукция'] 11
# 178 ['корзина' 'палочка' 'доска' 'кол' 'трос' 'шест'] 6
# 206 ['тур' 'суперкубок' 'чемп' 'томь' 'шанс' 'солид' 'шир' 'бундеслига' 'хаф'
#  'мальорка' 'экс' 'олимпиакос' 'шнайдер' 'бешикташ'] 14
# 57 ['переход' 'обновление' 'изменение' 'дополнение' 'смена' 'сокращение'
#  'сдвиг' 'новация' 'уточнение' 'разница' 'стабилизация' 'прикрепление'
#  'смещение' 'отклонение'] 14
# 62 ['материал' 'источник' 'версия' 'таблица' 'информация' 'данные'
#  'статистика' 'цск' 'сведение' 'цифра' 'опрос' 'наблюдение' 'перепись'] 13
# 166 ['блок' 'ведущий' 'скип' 'гпз' 'абс' 'ввод' 'апо' 'стыковка' 'иаэ' 'суг'
#  'окп' 'мтз' 'ппд' 'ифк' 'амп' 'кз' 'рпо' 'мтд' 'рэс' 'тмс' 'мкб' 'сат'
#  'опп'] 23
# 162 ['пассажиропоток' 'супергигант' 'доля' 'полугодие' 'посещаемость'
#  'терминал' 'заполняемость' 'грузооборот' 'хельсинки' 'грузопоток'
#  'пассажирооборот' 'виннипег'] 12
# 171 ['фра' 'герцогство' 'королева' 'граф' 'бох' 'герцогиня' 'императрица'] 7
# 118 ['коммуна' 'юрг' 'уезд' 'сход' 'волость' 'сельсовет' 'полт' 'село' 'вече'
#  'кеми'] 10
# 189 ['процент' 'лат' 'миллион' 'сотня' 'тысяча'] 5
# 53 ['участник' 'лидер' 'спр' 'глава' 'руководитель' 'представитель'
#  'наставник' 'супервайзер' 'специалист' 'директор' 'руководство'
#  'учредитель' 'организатор' 'администрация' 'филиал' 'деятель' 'инициатор'] 17
# 20 ['автор' 'соавтор' 'создатель' 'произведение' 'синопсис' 'аннотация'
#  'номинатор' 'авторство' 'классика' 'прототип' 'популярность' 'написание'
#  'историк'] 13
# 119 ['улица' 'гз' 'дворец' 'этаж' 'дом' 'гнездо' 'двор' 'здание' 'заведение'] 9
# 90 ['брак' 'рождение' 'супруг' 'родитель' 'родственник' 'семейство' 'отец'
#  'семья' 'супруги'] 9
# 38 ['противник' 'бой' 'сражение' 'война' 'перестрелка' 'атака' 'осада'] 7
# 115 ['голос' 'громкость' 'звук' 'звучание' 'рокот' 'гам' 'такт'] 7
# 140 ['период' 'стиль' 'хронология' 'эра' 'формация' 'история' 'эпоха'
#  'тысячелетие' 'цивилизация' 'романизация' 'артефакт' 'век'] 12
# 21 ['напор' 'сила' 'поток' 'стихия' 'подпор'] 5
# 71 ['канал' 'тв' 'спонсор' 'сми' 'эфир' 'телеканал' 'хронометраж' 'интервью'
#  'телезритель' 'телешоу' 'обозреватель'] 11
# 39 ['окончание' 'начало' 'конец' 'исход' 'продолжение' 'завершение'] 6
# 181 ['описание' 'легенда' 'пересказ' 'речь' 'подробность' 'рассказчик' 'роман'
#  'нотация' 'повесть' 'рассказ'] 10
# 149 ['декабрь' 'май' 'июль' 'январь' 'август' 'февраль' 'октябрь' 'июнь'
#  'март' 'вр' 'апрель' 'сентябрь'] 12
# 40 ['маршрут' 'трасса' 'болид' 'автодорога' 'дорога' 'напарник' 'пересечение'
#  'автодром' 'полоса' 'магистраль'] 10
# 154 ['идентификатор' 'сайт' 'оператор' 'сервер' 'доступ' 'работодатель'
#  'пользователь' 'абонент' 'запрос'] 9
# 136 ['катион' 'симметрия' 'строение' 'элемент' 'порода' 'грань' 'гранит'
#  'спин' 'свойство' 'светочувствительность' 'сингония' 'мос' 'полиамид'
#  'сма' 'минерал' 'осадок' 'сродство' 'стереоизомер' 'икосаэдр' 'эманация'] 20
# 172 ['назначение' 'правило' 'требование' 'приказ' 'кип' 'рекомендация'
#  'расписание' 'инструкция' 'предупреждение'] 9
# 102 ['система' 'дислокация' 'форма' 'механизм' 'структура' 'функция'
#  'формирование' 'соотношение' 'аппарат' 'взаимодействие' 'основа'
#  'направленность' 'звено'] 13
# 207 ['вывод' 'датировка' 'обоснование' 'определение' 'оценка' 'расшифровка'
#  'метод' 'классификация' 'спектр' 'последовательность' 'поиск'
#  'мониторинг' 'анализ' 'исследование' 'интерпретация' 'применяемость'] 16
# 65 ['градус' 'температура' 'вязкость' 'плотность' 'плавление' 'давление'
#  'цельсий'] 7
# 86 ['кегль' 'алфавит' 'орфография' 'буква' 'шрифт' 'литера' 'строка'
#  'иероглиф' 'аббревиатура' 'тир' 'латиница' 'кириллица' 'каллиграф'
#  'надпись' 'начертание'] 15
# 105 ['дорожка' 'площадь' 'парк' 'спуск' 'поле' 'площадка' 'арена' 'ступень'
#  'аут' 'каток' 'линейка' 'вход'] 12
# 87 ['событие' 'условие' 'причина' 'обстоятельство' 'положение' 'последствие'
#  'случай'] 7
# 28 ['код' 'нумерация' 'кодировка' 'пиктограмма' 'кодирование' 'ключ' 'метка'
#  'инн'] 8
# 29 ['фотография' 'фото' 'портрет' 'альбом' 'копия' 'картинка' 'карточка'] 7
# 208 ['строй' 'офицер' 'воин' 'боец' 'артикул' 'рабочий' 'военный' 'солдат'] 8
# 76 ['продажа' 'цена' 'ставка' 'стоимость' 'тариф' 'плата'] 6
# 99 ['церемония' 'аббатство' 'канонизация' 'храм' 'неф' 'монастырь' 'церковь'
#  'донатор' 'часовня' 'собор'] 10
# 100 ['песня' 'танец' 'музыка' 'танцор' 'бал' 'катание'] 6
# 107 ['рывок' 'бег' 'разгон' 'брасс' 'трамплин' 'лазание' 'прыжок' 'размах'
#  'жим' 'акробатика' 'движение' 'шаг' 'бросок'] 13
# 186 ['пантера' 'окрас' 'фламинго' 'гладиатор' 'лев' 'леопард' 'стервятник'] 7
# 79 ['илл' 'стр' 'соч' 'ред'] 4
# 195 ['карта' 'выигрыш' 'проигрыш'] 3
# 31 ['судно' 'флаг' 'корабль' 'экспедиция' 'порт' 'флот' 'верфь'
#  'водоизмещение' 'плавание' 'борт' 'эсминец' 'тоннаж' 'танкер' 'суд'
#  'палуба' 'гондола'] 16
# 32 ['длительность' 'продолжительность' 'удлинение' 'интервал' 'промежуток'
#  'задержка' 'течение' 'сложность'] 8
# 36 ['восхождение' 'вершина' 'высота' 'плато' 'тау' 'пик' 'гора' 'кай'
#  'хребет'] 9
# 129 ['арс' 'галерея' 'музей' 'достопримечательность' 'экспонат' 'захоронение'
#  'памятник'] 7
# 33 ['конструктор' 'разработчик' 'проектант' 'завод' 'окб'] 5
# 35 ['капитан' 'штурман' 'вручитель' 'механик' 'бомбардир' 'старшина'
#  'адмирал' 'кока' 'командор'] 9
# 72 ['пост' 'департамент' 'министр' 'губернатор' 'посол' 'отставка'
#  'ведомство' 'внутр' 'поливанов' 'советник'] 10
# 44 ['пар' 'пара' 'тройка' 'связка'] 4
# 74 ['сеп' 'янг' 'рез' 'лив' 'аджа' 'кок' 'ория' 'мек' 'ата' 'тер' 'кер'
#  'панчо'] 12
# 194 ['стрельба' 'орудие' 'боезапас' 'дальномер' 'мин' 'попадание' 'стрела'
#  'ядро' 'калибр' 'осколок' 'снаряд' 'боеприпас'] 12
# 37 ['рыба' 'кит' 'рыболовство' 'улов'] 4
# 106 ['даза' 'хер' 'кри' 'вар' 'бик' 'тра' 'кла' 'фак' 'лок' 'глот' 'фен' 'сме'
#  'ад' 'асс' 'ник' 'спар' 'жем' 'чер' 'ску' 'гри' 'шем' 'ета' 'бро' 'мат'] 24
# 64 ['посадка' 'авиакомпания' 'миль' 'агентство' 'рейс' 'аэропорт' 'впп'
#  'эксплуатант' 'икао' 'авиалиния'] 10
# 151 ['пассажир' 'платформа' 'склад' 'станция' 'паровоз' 'остановка' 'поезд'
#  'вагон' 'депо'] 9
# 183 ['часть' 'четверть' 'остаток' 'половина'] 4
# 56 ['преследование' 'защитник' 'судья' 'борец' 'защита' 'оплот'] 6
# 127 ['копь' 'вода' 'инд' 'белогорье' 'устье' 'ангара' 'река' 'эри' 'бассейн'
#  'водохранилище' 'озеро'] 11
# 104 ['трансляция' 'радио' 'радиостанция' 'передатчик'] 4
# 175 ['ссылка' 'жертва' 'смерть' 'мор' 'приговор' 'казнь' 'убийство' 'деяние'
#  'наказание'] 9
# 81 ['пересадка' 'транспорт' 'груз' 'перевозка' 'передвижение' 'перевозчик'
#  'мпс' 'хранение' 'отправление'] 9
# 126 ['предприятие' 'промышленность' 'нефтепереработка' 'отрасль' 'хозяйство'
#  'раздел' 'сектор' 'автомобилестроение'] 8
# 145 ['ро' 'поб' 'рах' 'авт' 'вич' 'вос' 'кре' 'проп' 'кра'] 9
# 54 ['знак' 'герб' 'эмблема' 'атрибут' 'символ' 'значок' 'девиз' 'логотип'] 8
# 210 ['оля' 'кукла' 'девушка' 'рен' 'юноша' 'барбара' 'лека' 'девочка'] 8
# 89 ['формат' 'процессор' 'приставка' 'синхронизация' 'видеокарта' 'боулер'
#  'модуль' 'топ' 'диск' 'видео' 'дисплей' 'фокусировка' 'память' 'локация'
#  'телефон' 'байт' 'бит' 'набор' 'озу' 'камера' 'табло' 'розетка' 'хеш'
#  'комплект' 'эоп' 'консоль'] 26
# 60 ['шина' 'подкова' 'колесо' 'крыло' 'вал' 'колея'] 6
# 143 ['кролик' 'размножение' 'растение' 'крыса' 'животное' 'протист' 'обезьяна'
#  'существо'] 8
# 95 ['зомби' 'муха' 'соты' 'рой' 'вампир'] 5
# 190 ['штат' 'квебек' 'ирландия' 'япония' 'рим' 'португалия' 'бельгия'
#  'шотландия' 'берн' 'швеция' 'англия' 'норвегия' 'амстердам' 'мальта'
#  'норфолк'] 15
# 177 ['выходной' 'вечер' 'праздник' 'обрезание' 'понедельник' 'суббота'
#  'воскресение'] 7
# 48 ['подбор' 'отбор' 'расстановка'] 3
# 168 ['сбор' 'прибыль' 'бюджет' 'заработок' 'расход' 'доходность' 'штраф'
#  'налог' 'капитал' 'доход' 'выручка'] 11
# 170 ['бас' 'инструмент' 'струна' 'каденция' 'нота' 'фуга' 'аккорд'
#  'тональность' 'октава' 'тон'] 10
# 139 ['македония' 'куба' 'кабул' 'белград' 'гдр' 'югославия' 'чехия' 'латвия'] 8
# 205 ['деньга' 'сбавка' 'трояк' 'скрупул' 'рысачок' 'фунт' 'галлон' 'копейка'] 8
# 50 ['стадия' 'этап' 'цикл' 'фаза'] 4
# 109 ['сессия' 'съезд' 'выступление' 'конгресс' 'ассамблея' 'конференция'
#  'резолюция' 'секция'] 8
# 121 ['кандидат' 'исп' 'созыв' 'совет' 'депутат' 'голосование' 'парламент'
#  'горсовет' 'избиратель' 'дума'] 10
# 125 ['лич' 'кло' 'ром' 'спирт' 'вино' 'пинта'] 6
# 110 ['леклерк' 'буркхардт' 'уолд' 'фор' 'фабрициус' 'марсель' 'делиль' 'араго'] 8
# 137 ['эксплуатация' 'этажность' 'судоверфь' 'закладка' 'комплекс' 'проект'
#  'водоснабжение' 'строительство' 'расселение' 'строитель'] 10
# 185 ['гость' 'зал' 'бра' 'кабинет' 'порог' 'гостиная'] 6
# 52 ['председатель' 'член' 'комитет' 'правление' 'отс' 'секретарь' 'комиссия'] 7
# 132 ['попытка' 'задание' 'операция' 'задача' 'план' 'цель' 'предназначение'
#  'вопрос'] 8
# 160 ['хай' 'пао' 'бан' 'бай' 'коу' 'дин' 'ган' 'син'] 8
# 131 ['шеф' 'служба' 'отдел' 'заведующий' 'управление' 'начальник' 'комиссар'
#  'орб' 'коммисар' 'отделение' 'лво' 'префектура' 'помощник' 'пом'] 14
# 88 ['этнос' 'национальность' 'миссия' 'народ' 'нация' 'братство' 'раса'
#  'самоидентификация' 'меньшинство' 'народность'] 10
# 117 ['аэростат' 'запуск' 'дальность' 'ракета' 'боезаряд' 'челленджер'
#  'космодром' 'телебашня'] 8
# 58 ['восток' 'север' 'запад'] 3
# 182 ['круг' 'область' 'оборот' 'компетенция' 'сфера' 'рамка' 'периферия'] 7
# 191 ['уход' 'выход' 'пребывание' 'путешествие' 'приход' 'выезд' 'пробуждение'
#  'прибытие' 'освобождение' 'возобновление' 'возвращение' 'предлог'
#  'воскрешение'] 13
# 174 ['еврей' 'венгр' 'эст' 'немец' 'пан' 'воеводство' 'литовец' 'украинец'
#  'молдаванин' 'поляк' 'вязьма' 'чех' 'латыш' 'белорус'] 14
# 68 ['камаз' 'автомобиль' 'кар' 'экипаж' 'машина' 'мотоцикл' 'маз' 'трейлер'
#  'кузов' 'авто'] 10
# 142 ['гагауз' 'армянин' 'цыган' 'рус' 'киргиз' 'орд' 'мордва' 'сибиряк'
#  'татарин' 'грузин' 'таджик' 'башкир' 'казах' 'аварец' 'черкес' 'адыгеец'
#  'улус' 'осетин'] 18
# 61 ['вещество' 'соединение' 'частица' 'кислород' 'кислота' 'античастица'
#  'фосфор' 'ткань'] 8
# 159 ['патрон' 'ппш' 'рпд' 'оружие' 'шашка' 'сум' 'винтовка'] 7
# 203 ['причастие' 'крест' 'епархия' 'духовенство' 'монах' 'причт' 'викарий'
#  'священник'] 8
# 153 ['энергоблок' 'топливо' 'мкс' 'мвт' 'бор' 'аэс' 'энергетика' 'реактор'
#  'ускоритель' 'изотоп'] 10
# 84 ['идеал' 'партийность' 'религия' 'личность' 'идеология' 'вероисповедание'
#  'индуизм' 'конфессия' 'славянофил'] 9
# 66 ['дуэль' 'рапира' 'поединок' 'пари' 'инцидент'] 5
# 78 ['руда' 'никель' 'металл' 'платина' 'газ' 'уголь' 'сурьма'] 7
# 176 ['ени' 'мусульманин' 'араб' 'султан' 'болгарин' 'вилайет' 'турок' 'серб'
#  'курд' 'нахия' 'перс' 'бей'] 12
# 69 ['президент' 'нок' 'сенатор' 'мид' 'персона' 'анк' 'бакатин' 'элита'
#  'ширак' 'премьер'] 10
# 103 ['формула' 'множитель' 'уравнение' 'разность' 'дау' 'скобка'] 6
# 96 ['композитор' 'архитектор' 'художник' 'мастер' 'поэт' 'скульптура'
#  'музыкант' 'мыслитель' 'скульптор' 'дизайнер'] 10
# 114 ['травма' 'энцефалит' 'смертность' 'заболевание' 'болезнь' 'медпомощь'
#  'повреждение' 'синдром' 'кома'] 9
# 169 ['фигурка' 'лицо' 'фигура'] 3
# 133 ['дифтонг' 'альтернация' 'северовосток' 'глосса' 'наклонение' 'аффриката'
#  'фонема' 'изм' 'глаголица' 'огласовка' 'ударение'] 11
# 187 ['голова' 'пояс' 'пот' 'грудь' 'тело' 'зад' 'кость' 'ребро' 'бок' 'спина'
#  'хвост' 'угол'] 12
# 192 ['династия' 'происхождение' 'предок' 'поколение' 'потомок'] 5
# 167 ['брауэр' 'клапрот' 'вирджиния' 'онтарио' 'эксетер' 'эве' 'александер'
#  'альберта' 'мад' 'миннеаполис' 'гардинер' 'мак' 'бостон'] 13
# 141 ['промах' 'погрешность' 'слабость' 'недостаток' 'достоинство'
#  'препятствие' 'отсутствие' 'преимущество'] 8
# 158 ['погода' 'синева' 'ветер' 'инка' 'воздух' 'циклон' 'сырь'] 7
# 116 ['посев' 'сев' 'картофель' 'ранетка' 'гриб' 'чечевица' 'сорт'] 7
# 92 ['заметка' 'хроника' 'рецензия' 'статья' 'заголовок' 'анонс'] 6
# 97 ['жрец' 'глашатай' 'фараон' 'посвящение' 'маг' 'спарта' 'нум'] 7
# 98 ['препарат' 'доза' 'лекарство' 'бад' 'гипертермия' 'медикамент'
#  'стимулятор'] 7
# 204 ['кир' 'шах' 'правитель' 'монарх' 'кинт' 'коронация' 'князь' 'царь'] 8
# 120 ['изобретение' 'появление' 'открытие' 'открыватель' 'закрытие'] 5
# 201 ['отв' 'творение' 'евр' 'любовь' 'моисей' 'тму' 'бог' 'бес' 'чт'] 9
# 123 ['жирность' 'молоко' 'шти' 'жир' 'масло' 'литр' 'яйцо'] 7
# 135 ['склонение' 'кук' 'широта' 'долгота' 'азимут'] 5
# 111 ['обращение' 'связь' 'отношение' 'контакт' 'подчинение' 'поведение'
#  'близость'] 7
# 180 ['полость' 'глубина' 'край' 'луч' 'поверхность' 'кора' 'слой' 'оболочка'
#  'касание' 'сток' 'осадка'] 11
# 155 ['кос' 'мех' 'платье' 'мода' 'костюм' 'браслет' 'шапка'] 7
# 112 ['минимум' 'максимум'] 2
# 130 ['бол' 'южн' 'таврия' 'ниж' 'зак' 'зап' 'кап' 'лех'] 8
# 134 ['либретто' 'либреттист' 'опера' 'солист' 'балет' 'ария'] 6
# 202 ['полиция' 'мот' 'мошенничество' 'вор' 'злодей'] 5
# 122 ['потеря' 'утрата' 'разрыв' 'разрушение'] 4
# 147 ['дуб' 'корень' 'лес' 'дерево' 'лист' 'ветвь' 'виноград' 'насаждение'] 8
# 124 ['рот' 'вилка' 'губа'] 3
# 146 ['психология' 'физиология' 'химия'] 3

# %% [markdown]
# ## BIRCH
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.Birch.html
#
# Birch строит (Clustering Feature Tree, CFT), для заданных данных.
#
# Данные сжимаются с потерями до набора узлов кластеризации признаков (CF Nodes). Узлы CF имеют ряд подкластеров, называемых подкластерами признаков кластеризации (CF Subclusters), и эти подкластеры CF, расположенные в нетерминальных узлах CF, могут иметь узлы CF в качестве дочерних.
#
# Подкластеры CF содержат необходимую для кластеризации информацию, которая позволяет избежать необходимости хранить в памяти все входные данные.
#
# Алгоритм BIRCH имеет два параметра - порог и фактор ветвления. Фактор ветвления ограничивает количество подкластеров в узле, а порог - расстояние между входящей выборкой и существующими подкластерами.
#
# Если n_clusters равно None, то подкластеры из листьев считываются напрямую, в противном случае шаг глобальной кластеризации помечает эти подкластеры в глобальные кластеры (метки), и образцы сопоставляются с глобальной меткой ближайшего подкластера.

# %%
def find_best_clustering_params(X, model_cls, min_num_clusters=100, max_num_clusters=101):
    best_num_clusters = -1
    best_clustering_score = -5
    best_clusters = None

    from tqdm import tqdm
    # tqdm
    for num_clusters in tqdm(range(min_num_clusters, max_num_clusters)):
        labels = model(n_clusters=num_clusters).fit_predict(embeddings_reshaped)
        score = calinski_harabasz_index(X, labels)
        # score = silhouette_score(X, labels)
        # score = davies_bouldin_index(X, labels)

        if score > best_clustering_score:
            best_clustering_score = score
            best_num_clusters = num_clusters
            best_clusters = labels

    return {
        "best_clustering_score": best_clustering_score,
        "best_num_clusters": best_num_clusters,
        "best_clusters": best_clusters
    }

# %%
from sklearn.cluster import Birch

name = "birch"
model = Birch

clustering_params = find_best_clustering_params(embeddings_reshaped, model, min_num_clusters=200, max_num_clusters=220)

print(clustering_params, end="\n\n\n")

df_cls[name] = clustering_params["best_clusters"]
cluster_dict = get_cluster_id_words(name)

print_cluster_to_word(cluster_dict)
# Out:
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  2.91it/s]
# {'best_clustering_score': 5.077229933890018, 'best_num_clusters': 200, 'best_clusters': array([ 48, 169, 143, ..., 151,   6, 169])}
#
#
# 48 ['алгоритм' 'показатель' 'модель' 'система' 'таблица' 'динамика' 'метод'
#  'механизм' 'индекс' 'критерий' 'размерность' 'параметр' 'индикатор'
#  'техпроцесс' 'разбиение' 'спецификация' 'схема' 'рис' 'кластер'
#  'конструкция' 'диаграмма' 'шкала'] 22
# 169 ['чарт' 'лейбл' 'релиз' 'сингл' 'дискография' 'саундтрек' 'хит' 'ремикс'
#  'лэйбл' 'хард' 'рок'] 11
# 143 ['титул' 'звание' 'должность' 'назначение' 'ранг' 'пост' 'служба' 'чин'
#  'отставка'] 9
# 182 ['яванец' 'македония' 'мусульманин' 'белград' 'шах' 'араб' 'султан'
#  'болгарин' 'вилайет' 'турок' 'серб' 'курд' 'нахия' 'перс' 'бей'] 15
# 60 ['население' 'численность' 'млн' 'число' 'сумма' 'масса' 'количество'
#  'процент' 'микрограмм' 'мощность' 'км' 'доля' 'кг' 'тыс' 'тонна'
#  'минимум' 'руб' 'среднее' 'миллион' 'вклад' 'меньшинство' 'сотня'
#  'тысяча' 'большинство' 'максимум'] 25
# 54 ['категория' 'группа' 'класс' 'состав' 'подгруппа' 'разряд' 'ряд'
#  'подкласс' 'сда' 'подразделение' 'ппс' 'саф' 'звено'] 13
# 186 ['матч' 'мяч' 'команда' 'финал' 'лига' 'раунд' 'тур' 'суперкубок' 'гол'
#  'сет' 'полуфинал' 'плейофф' 'бундеслига' 'ничья' 'овертайм' 'тайм'
#  'пенальти' 'суперлига' 'олимпиакос' 'бешикташ' 'четвертьфинал'] 21
# 82 ['партия' 'свдп' 'лидер' 'фракция' 'сми' 'мандат' 'созыв' 'лдпр' 'депутат'
#  'дпр' 'спс' 'голосование' 'референдум' 'коалиция' 'избиратель' 'дума'] 16
# 8 ['позиция' 'место' 'пункт' 'направление' 'сторона' 'восток' 'путь' 'север'
#  'дорога' 'колея' 'запад'] 11
# 161 ['название' 'имя' 'наименование' 'фамилия' 'аббревиатура' 'прозвище'
#  'псевдоним'] 7
# 61 ['очки' 'очко' 'бокс' 'дуэль' 'рапира' 'шайба' 'рапид' 'блиц' 'поединок'
#  'пари'] 10
# 130 ['дата' 'рождение' 'канонизация' 'календарь' 'пролог' 'посвящение'
#  'праздник' 'обрезание' 'память' 'скобка'] 10
# 129 ['страна' 'африка' 'ирландия' 'королевство' 'герцогство' 'гдр' 'япония'
#  'америка' 'югославия' 'чехия' 'португалия' 'бельгия' 'латвия' 'шотландия'
#  'швеция' 'англия' 'норвегия'] 17
# 4 ['кубок' 'спортсмен' 'турнир' 'игрок' 'соревнование' 'чемпион' 'сборная'
#  'чемпионат' 'игра' 'атлет' 'теннисист' 'тренер' 'спринт' 'спортсменка'
#  'фигурист' 'футболист' 'эстафета' 'конькобежец' 'первенство' 'чемпионка'
#  'велоспорт' 'юниор' 'спорт' 'биатлонист' 'фигуристка' 'олимпиада'
#  'гимнастка' 'арбитр' 'состязание' 'хоккеист' 'акробатика' 'многоборье'
#  'гимнаст' 'каток' 'лыжник' 'лыжница' 'волейбол' 'шахматист' 'баскетбол'
#  'катание' 'баскетболист' 'самбо' 'теннисистка'] 43
# 70 ['торговля' 'продажа' 'предприятие' 'производитель' 'изготовитель'
#  'производство' 'выпуск' 'экспорт' 'промышленность' 'изделие'
#  'нефтепереработка' 'сальдо' 'отрасль' 'продукция' 'рынок' 'сбыт' 'импорт'
#  'хозяйство' 'поставка' 'завод' 'сектор'] 21
# 114 ['сезон' 'год' 'время' 'месяц' 'декабрь' 'май' 'июль' 'начало' 'конец'
#  'день' 'выходной' 'пора' 'январь' 'вечер' 'август' 'февраль' 'час'
#  'октябрь' 'июнь' 'март' 'неделя' 'понедельник' 'апрель' 'суббота'
#  'воскресение' 'сентябрь' 'зима'] 27
# 17 ['соперник' 'соперница' 'победитель' 'трофей' 'победительница' 'выигрыш'
#  'конкурент' 'проигрыш'] 8
# 13 ['линия' 'точка' 'сдвиг' 'удлинение' 'контур' 'пересечение' 'прикрепление'
#  'смещение' 'касание' 'отклонение'] 10
# 71 ['дисциплина' 'порядок' 'строй' 'нумерация' 'приказ' 'расписание'
#  'инструкция'] 7
# 81 ['валюта' 'номинал' 'кредит' 'прибыль' 'сбавка' 'бюджет' 'цена' 'ставка'
#  'стоимость' 'заработок' 'расход' 'доходность' 'банк' 'тариф' 'налог'
#  'капитал' 'погашение' 'доход' 'эмитент' 'котировка' 'выручка' 'плата'] 22
# 121 ['примечание' 'описание' 'комментарий' 'пересказ' 'дополнение' 'текст'
#  'оригинал' 'упоминание' 'цитата' 'уточнение' 'пояснение'] 11
# 152 ['персонаж' 'автор' 'сюжет' 'жанр' 'произведение' 'творение' 'рассказчик'
#  'роман' 'герой' 'повесть' 'рассказ'] 11
# 115 ['мон' 'фра' 'сан' 'викарий'] 4
# 50 ['сертификация' 'лицензия' 'сертификат' 'квота' 'рыболовство' 'контроль'
#  'мкк' 'туризм' 'мониторинг' 'лицензиат'] 10
# 67 ['роль' 'исполнитель' 'режиссура' 'исполнение' 'артист' 'театр' 'актриса'
#  'спектакль' 'хореограф' 'либретто' 'постановка' 'амплуа' 'сцена'
#  'либреттист' 'опера' 'постановщик' 'драматург' 'солист' 'труппа' 'пьеса'
#  'балет' 'исполнительница'] 22
# 104 ['итог' 'результат' 'вывод' 'характеристика' 'информация' 'обоснование'
#  'определение' 'оценка' 'данные' 'классификация' 'рекомендация' 'сведение'
#  'наблюдение' 'анализ' 'исследование'] 15
# 63 ['вид' 'основание' 'пример' 'образец' 'форма' 'прототип' 'аналог' 'основа'] 8
# 149 ['тип' 'род' 'происхождение' 'эра' 'формация' 'предок' 'эпоха'
#  'тысячелетие' 'поколение' 'потомок' 'век'] 11
# 175 ['лек' 'оля' 'лека'] 3
# 78 ['эволюция' 'прогресс' 'идеал' 'партийность' 'религия' 'идеология'
#  'цивилизация' 'индуизм' 'славянофил' 'культура' 'регресс' 'ценность'] 12
# 196 ['работа' 'образование' 'деятельность' 'содержание' 'выработка' 'нкз'
#  'колич' 'кпр' 'кузбасс'] 9
# 15 ['номер' 'карта' 'получатель' 'фио' 'адрес' 'документ' 'бик' 'копия'
#  'подпись' 'карточка' 'телефон' 'инн' 'протокол'] 13
# 79 ['нагрузка' 'вес' 'эксцентриситет' 'температура' 'скорость' 'вязкость'
#  'плотность' 'погрешность' 'разность' 'плавление' 'днп' 'стабилизатор'
#  'сечение' 'зазор' 'давление' 'сжатие' 'габарит'] 17
# 170 ['кан' 'хай' 'пао' 'янг' 'лив' 'бай' 'коу' 'дин' 'кай' 'син' 'мак' 'су'] 12
# 128 ['клуб' 'стадион' 'квн' 'стэм' 'цдка'] 5
# 173 ['планета' 'юпитер' 'астероид' 'луна' 'созвездие' 'звезда' 'сатурн'
#  'перигелий'] 8
# 29 ['город' 'ссылка' 'столица' 'провинция' 'житель' 'уезд' 'сход' 'волость'
#  'поселение' 'сельсовет' 'полт' 'райцентр' 'село' 'деревня' 'резиденция'
#  'горсовет' 'кеми' 'пригород'] 18
# 5 ['издание' 'альбом' 'перевод' 'переиздание' 'каталог' 'тираж' 'сборник'
#  'заглавие' 'аннотация' 'заметка' 'издатель' 'энциклопедия' 'книга'
#  'строка' 'рецензия' 'публикация' 'издательство' 'статья' 'заголовок'
#  'журнал' 'редактор' 'страница' 'библия'] 23
# 171 ['номинация' 'награда' 'лауреат' 'номинант' 'медалист' 'премия' 'конкурс'
#  'финалистка' 'фестиваль' 'жюри' 'финалист' 'приз' 'претендент'
#  'евровидение' 'ммкф'] 15
# 51 ['сценарист' 'фильм' 'шоу' 'студия' 'продюсер' 'клип' 'сериал' 'роб'
#  'мультсериал' 'видео' 'кино' 'видеоклип' 'мультфильм' 'комикс'
#  'телесериал' 'кинокомпания' 'экранизация' 'киностудия' 'телешоу'
#  'сценаристка' 'анимация'] 21
# 133 ['факультет' 'колледж' 'университет' 'преподавательница' 'кафедра'
#  'ректор' 'магистратура' 'школа'] 8
# 0 ['срок' 'ратификация' 'получение' 'присвоение' 'явка' 'заявка' 'открытие'
#  'введение' 'вступление' 'закрытие' 'принятие' 'подача' 'выдача'
#  'начисление' 'сат' 'вручение' 'списание'] 17
# 14 ['армия' 'корпус' 'фронт' 'отряд' 'дивизия' 'войско' 'офицер' 'воин'
#  'боец' 'полк' 'командир' 'генерал' 'штаб' 'бригада' 'перестрелка'
#  'старшина' 'военный' 'комиссар' 'сал' 'эскадрон' 'командующий' 'солдат'] 22
# 101 ['расстояние' 'метр' 'длина' 'высота' 'диаметр' 'радиус' 'ширина'
#  'толщина' 'глубина'] 9
# 85 ['рост' 'прирост' 'полугодие' 'темп' 'посещаемость' 'ввп' 'потребление'
#  'квартал' 'заполняемость' 'производительность'] 10
# 123 ['отель' 'рио' 'либра' 'майами' 'бангкок' 'пасифик' 'олд' 'бар' 'мальорка'
#  'мажестик' 'барбара'] 11
# 66 ['слалом' 'поул' 'старт' 'финиш' 'трасса' 'гонка' 'заезд' 'гонщик'
#  'супергигант' 'велогонщик' 'ралли' 'трек' 'болид' 'фукуока' 'автодром'
#  'индианаполис'] 16
# 20 ['деталь' 'легенда' 'событие' 'датировка' 'сага' 'синопсис' 'эпизод'
#  'хронология' 'хроника' 'подробность' 'история' 'историк' 'инцидент'] 13
# 73 ['марка' 'банкнот' 'монета' 'этикетка' 'маркировка'] 5
# 89 ['отставание' 'остановка' 'потеря' 'утрата' 'разрыв' 'задержка'] 6
# 55 ['судьба' 'карьера' 'профессия' 'неудачник' 'участь' 'будущее'] 6
# 41 ['способ' 'предмет' 'принадлежность' 'устройство' 'изобретение' 'средство'
#  'хранение' 'ношение' 'употребление'] 9
# 22 ['расположение' 'район' 'дислокация' 'местонахождение' 'подрайон'
#  'месторасположение' 'территория' 'зона' 'участок' 'разведка'
#  'освоенность' 'поиск'] 12
# 103 ['пол' 'голова' 'пот' 'лицо' 'грудь' 'рот' 'зад' 'порог' 'ребро' 'бок'
#  'спина' 'губа' 'угол'] 13
# 80 ['поз' 'пантера' 'кролик' 'крыло' 'крыса' 'лев' 'обезьяна' 'подбой'
#  'петух' 'леопард' 'стервятник' 'хвост'] 12
# 23 ['владелец' 'хозяин' 'обладатель' 'поставщик' 'контракт' 'договор' 'заказ'
#  'сделка' 'продавец' 'заказчик' 'собственник' 'подрядчик'] 12
# 58 ['достижение' 'мероприятие' 'программа' 'миссия' 'проект' 'задание'
#  'задача' 'план' 'цель' 'предназначение'] 10
# 122 ['цвет' 'алк' 'запах' 'ранетка' 'аромат' 'яблоко' 'цветок' 'вкус' 'сорт'] 9
# 39 ['значение' 'обозначение' 'смысл' 'тема' 'представление' 'понятие' 'мотив'
#  'тематика' 'глосса' 'психология' 'акцентуация' 'термин' 'физиология'
#  'маскулинность' 'переоткрытие' 'направленность' 'химия' 'контекст'
#  'романизация' 'гомосексуальность' 'знание' 'интерпретация'
#  'применяемость'] 23
# 30 ['язык' 'префикс' 'артикль' 'дифтонг' 'приставка' 'эсперанто'
#  'альтернация' 'произношение' 'аффриката' 'частотность' 'соссюр' 'диалект'
#  'фонема' 'просодия' 'аффикс' 'расстановка' 'акцент' 'огласовка'
#  'ударение'] 19
# 74 ['ита' 'ио' 'мас' 'кар' 'бра' 'спа' 'фак' 'гро' 'ои' 'бад' 'спо' 'мос'
#  'мот' 'бро'] 14
# 26 ['пилот' 'бомбардировщик' 'штурмовка' 'вылет' 'аэродром' 'авиакомпания'
#  'дальность' 'перехват' 'аэропорт' 'эскадрилья' 'впп' 'эксплуатант' 'тб'
#  'истребитель' 'локация' 'рэс' 'икао' 'авиация' 'авиалиния'] 19
# 146 ['бронза' 'серебро' 'золото' 'руда' 'никель' 'металл' 'платина' 'добыча'
#  'уголь' 'сурьма'] 10
# 158 ['конь' 'пар' 'пара' 'гурт' 'вол' 'повозка' 'кип' 'тройка'] 8
# 1 ['планка' 'сайт' 'уровень' 'формат' 'сеть' 'топ' 'домен' 'контакт'
#  'раздел' 'рамка' 'диалог'] 11
# 12 ['двигатель' 'шасси' 'шина' 'колесо' 'камаз' 'автомобиль' 'мотор' 'машина'
#  'привод' 'мотоцикл' 'движок' 'маз' 'трейлер' 'кузов' 'зажигание'
#  'карбюратор' 'тормоз' 'авто' 'трансмиссия'] 19
# 180 ['изображение' 'фотография' 'фото' 'портрет' 'иллюстрация' 'гравюра'
#  'картинка' 'рисунок' 'картина' 'репродукция'] 10
# 47 ['корзина' 'фен' 'ключ' 'вилка' 'розетка' 'пакет' 'связка'] 7
# 38 ['подиум' 'дизайн' 'стиль' 'классика' 'логотип' 'жаргонизм' 'мода'
#  'дизайнер' 'изм' 'наив'] 10
# 44 ['координата' 'градус' 'кориолис' 'широта' 'долгота' 'циклон' 'азимут'
#  'авма' 'цельсий'] 9
# 108 ['переход' 'барьер' 'выход' 'ступень' 'доступ' 'вход' 'препятствие'] 7
# 162 ['напряжение' 'нейтраль' 'ток' 'амп' 'эдс' 'индуктивность' 'вольтаж'] 7
# 28 ['сплит' 'блок' 'ведущий' 'скип' 'куба' 'вал' 'куб' 'телебашня'] 8
# 172 ['материал' 'покрытие' 'прочность' 'полиамид' 'ткань'] 5
# 135 ['персоналия' 'версия' 'соавтор' 'фильмография' 'телеверсия' 'номинатор'
#  'сценарий' 'вариант' 'интервью' 'анонс' 'обозреватель'] 11
# 188 ['пассажиропоток' 'пассажир' 'порт' 'транспорт' 'груз' 'перевозка'
#  'перевозчик' 'терминал' 'грузооборот' 'грузопоток' 'пассажирооборот'
#  'мпс'] 12
# 43 ['тор' 'сеп' 'шир' 'ория' 'лок' 'мек' 'хет' 'бир' 'айн' 'кер' 'переводчик'
#  'бер' 'мит' 'ард' 'аус' 'шем'] 16
# 86 ['коммуна' 'рабочий' 'ячейка' 'бюро' 'секция'] 5
# 144 ['микрорайон' 'этажность' 'водоснабжение' 'автодорога' 'строительство'
#  'строитель' 'магистраль'] 7
# 106 ['участник' 'участие' 'спонсор' 'организация' 'глава' 'руководитель'
#  'фонд' 'участница' 'поддержка' 'объединение' 'представитель'
#  'представительство' 'управление' 'руководство' 'учредитель' 'организатор'
#  'филиал' 'инициатор'] 18
# 45 ['чистота' 'мера' 'качество' 'доступность' 'степень' 'разнообразие'
#  'разница' 'недостаток' 'наличие' 'обеспеченность' 'точность'
#  'совместимость' 'отсутствие' 'преимущество' 'сложность'] 15
# 110 ['кат' 'церемония' 'чтение' 'действо' 'занятие' 'упражнение' 'мантра'] 7
# 157 ['размер' 'величина' 'константа' 'формула' 'единица' 'множитель' 'деление'
#  'уравнение' 'эквивалент' 'коэффициент' 'цифра' 'пропорциональность'] 12
# 99 ['улица' 'дорожка' 'площадь' 'парк' 'дворец' 'площадка' 'этаж' 'дом'
#  'двор' 'здание'] 10
# 65 ['зритель' 'канал' 'громкость' 'тв' 'трансляция' 'аудитория' 'эфир'
#  'телеканал' 'радио' 'передача' 'радиостанция' 'передатчик' 'телезритель'] 13
# 155 ['брак' 'супруг' 'родитель' 'родственник' 'семейство' 'отец' 'любовь'
#  'семья' 'супруги'] 9
# 178 ['экран' 'идентификатор' 'код' 'процессор' 'сервер' 'синхронизация'
#  'видеокарта' 'модуль' 'диск' 'дисплей' 'фокусировка' 'пользователь'
#  'абонент' 'озу' 'табло'] 15
# 168 ['противник' 'бой' 'дивизион' 'орудие' 'танк' 'сау' 'атака' 'артиллерия'
#  'прорыв'] 9
# 33 ['голос' 'бас' 'инструмент' 'звук' 'струна' 'каденция' 'нота' 'звучание'
#  'рокот' 'аккорд' 'тональность' 'октава' 'гам' 'тон'] 14
# 189 ['заплыв' 'дистанция' 'бег' 'забег' 'рекорд' 'брасс' 'плавание' 'жим'
#  'марафон' 'пловец'] 10
# 7 ['замечание' 'разрешение' 'балл' 'требование' 'промах' 'нотация' 'ответ'
#  'вопрос' 'отметка' 'запрос'] 10
# 46 ['период' 'серия' 'длительность' 'продолжительность' 'стадия' 'этап'
#  'цикл' 'фаза' 'интервал' 'периодичность' 'промежуток'] 11
# 2 ['остров' 'рим' 'океания' 'марсель' 'гвинея' 'зеландия' 'александрия'
#  'мальта'] 8
# 68 ['транскрипция' 'ген' 'комбинация' 'последовательность' 'фуга' 'вариация'
#  'нуклеотид' 'сочетание'] 8
# 37 ['напор' 'сила' 'масштаб' 'размах' 'охват' 'стихия'] 6
# 24 ['вва' 'даза' 'ро' 'поб' 'чемп' 'бре' 'тра' 'кла' 'кло' 'беш' 'тиг' 'сме'
#  'сол' 'тро' 'кре' 'проп' 'чер' 'кра' 'ску' 'гри' 'ноо' 'эдм'] 22
# 131 ['премьера' 'посол' 'мид' 'бакатин' 'ширак' 'советник' 'премьер'] 7
# 126 ['победа' 'сражение' 'поражение' 'война' 'операция' 'кампания' 'осада'] 7
# 151 ['возраст' 'женщина' 'девушка' 'телосложение' 'мужчина' 'юноша' 'девочка'] 7
# 163 ['окончание' 'исход' 'продолжение' 'завершение' 'течение'] 5
# 62 ['палочка' 'доска' 'подкова' 'вар' 'стрела' 'тир' 'шашка' 'кол' 'бутсы'
#  'заруб' 'шест' 'линейка' 'сырь' 'мат'] 14
# 9 ['юрг' 'инд' 'вручитель' 'кош' 'отв' 'артикул' 'осм' 'авт' 'пан'
#  'воеводство' 'вич' 'коммисар' 'ково' 'вязьма' 'кома'] 15
# 148 ['источник' 'частота' 'диапазон' 'энергия' 'спектр' 'поток' 'импульс'
#  'светимость' 'ускоритель' 'эоп'] 10
# 3 ['дст' 'правительство' 'муниципалитет' 'гражданство' 'президент' 'министр'
#  'округ' 'губернатор' 'сенатор' 'гражданин' 'республика' 'орб' 'ведомство'
#  'учреждение' 'федерация' 'лво' 'парламент' 'префектура' 'администрация'
#  'ингушетия' 'заведение'] 21
# 167 ['регион' 'рейтинг' 'приоритет' 'субрегион' 'ресурс' 'популярность'
#  'баланс' 'бизнес' 'инвестор' 'лидерство' 'атр'] 11
# 88 ['маршрут' 'экспедиция' 'пребывание' 'рейс' 'путешествие' 'выезд'
#  'прибытие' 'отправление' 'возвращение'] 9
# 84 ['катион' 'симметрия' 'вещество' 'соединение' 'элемент' 'частица' 'алкан'
#  'спин' 'кислород' 'сингония' 'кислота' 'валентность' 'античастица' 'пси'
#  'нуклид' 'фосфор' 'минерал' 'минерализация' 'изотоп' 'сродство'
#  'стереоизомер' 'икосаэдр'] 22
# 154 ['курс' 'гз' 'гпз' 'пгт' 'адр' 'аст' 'ске'] 7
# 72 ['композиция' 'мозаика' 'неф' 'галерея' 'резьба' 'донатор' 'консоль'] 7
# 174 ['список' 'кандидат' 'председатель' 'член' 'комитет' 'совет' 'правление'
#  'секретарь' 'комиссия'] 9
# 52 ['вместимость' 'жирность' 'молоко' 'ром' 'спирт' 'вино' 'бом' 'жир'
#  'масло' 'галлон' 'пинта' 'ессентуки' 'литр' 'виноград'] 14
# 124 ['центр' 'круг' 'субъект' 'область' 'предел' 'грань' 'функция'
#  'компетенция' 'акт' 'сфера' 'периферия'] 11
# 197 ['орбита' 'космос' 'запуск' 'мкс' 'ракета' 'спутник' 'стыковка'
#  'челленджер' 'астронавт' 'космодром'] 10
# 91 ['рождаемость' 'сбор' 'статистика' 'смертность' 'цск' 'опрос' 'расселение'
#  'миграция' 'перепись'] 9
# 112 ['погон' 'флаг' 'медаль' 'петлица' 'крест' 'шеврон' 'значок' 'знамя'
#  'лента'] 9
# 31 ['кегль' 'знак' 'герб' 'эмблема' 'атрибут' 'буква' 'шрифт' 'литера'
#  'символ' 'иероглиф' 'девиз' 'слоган' 'надпись' 'начертание'] 14
# 159 ['песня' 'танец' 'музыка' 'музыкант' 'танцор' 'ария'] 6
# 136 ['рывок' 'толчок' 'трамплин' 'прыжок' 'рестлер' 'такт' 'шаг' 'бросок'] 8
# 40 ['илл' 'бан' 'стр' 'мин' 'соч' 'шт' 'ред' 'ник' 'инт' 'пом' 'подпор'] 11
# 147 ['судно' 'корабль' 'флот' 'верфь' 'судоверфь' 'водоизмещение' 'эсминец'
#  'тоннаж' 'танкер'] 9
# 64 ['вооружение' 'склад' 'запас' 'оружие' 'продукт' 'боезаряд' 'медпомощь'
#  'медикамент' 'питание' 'боеприпас'] 10
# 166 ['восхождение' 'вершина' 'кратер' 'плато' 'тау' 'пик' 'гора' 'хребет'] 8
# 160 ['мфа' 'энцефалит' 'компартмент' 'липаза' 'ингибирование' 'крс' 'белок'
#  'треонин' 'нер' 'ирт' 'гистамин' 'рецептор'] 12
# 153 ['пас' 'вратарь' 'нападающий' 'полузащитник' 'зенит' 'динамо' 'томь'
#  'форвард' 'локомотив' 'ска' 'спартак' 'торпедо'] 12
# 6 ['арс' 'бонус' 'обслуживание' 'сервис' 'оператор' 'дистрибьютор' 'бренд'
#  'компания' 'агентство' 'фирма' 'офис' 'дистрибутор' 'боулер'
#  'супервайзер' 'прокат' 'прокатчик' 'отс' 'работодатель' 'ифк'
#  'мультиплекс' 'рсо' 'услуга' 'стд' 'хостинг' 'франшиза' 'менеджер'] 26
# 36 ['конструктор' 'нтк' 'разработчик' 'водник' 'экспонент' 'асв' 'проектант'
#  'асс' 'сма' 'мкб' 'окб'] 11
# 87 ['использование' 'размещение' 'изменение' 'компонент' 'сокращение'
#  'фактор' 'структура' 'реализация' 'связь' 'формирование' 'отношение'
#  'создание' 'стабилизация' 'соотношение' 'распространение' 'повышение'
#  'превышение' 'взаимодействие' 'развитие' 'расширение' 'зависимость'
#  'распределение' 'применение' 'локализация'] 24
# 59 ['квалификация' 'объект' 'база' 'комплекс' 'эффективность' 'твд' 'иаэ'
#  'окп' 'специалист' 'подготовка' 'технология' 'мтд' 'результативность'
#  'техника' 'тмс' 'автомобилестроение'] 16
# 119 ['капитан' 'штурман' 'нок' 'бомбардир' 'адмирал' 'командор'] 6
# 25 ['реверс' 'вис' 'дир' 'миль' 'фин' 'рез' 'ант' 'лат' 'кру' 'атл' 'гур'] 11
# 90 ['состояние' 'условие' 'режим' 'положение' 'среда'] 5
# 113 ['стрельба' 'патрон' 'нарез' 'ппш' 'рпд' 'боезапас' 'мм' 'калибр'
#  'винтовка' 'снаряд' 'сверловка'] 11
# 184 ['статус' 'ассоциация' 'сообщество' 'членство' 'конфедерация' 'союз'
#  'элита' 'гильдия' 'общество'] 9
# 18 ['макашов' 'слово' 'оппонент' 'вещатель' 'формулировка' 'новация' 'речь'
#  'обращение' 'оборот' 'умолчание' 'комментатор' 'аргумент'
#  'доказательство' 'признание'] 14
# 93 ['рыба' 'фламинго' 'кит' 'улов'] 4
# 49 ['посадка' 'пересадка' 'посев' 'сев' 'картофель' 'рош' 'чечевица' 'греча'] 8
# 145 ['часть' 'четверть' 'остаток' 'половина'] 4
# 156 ['преследование' 'судья' 'полиция' 'приговор' 'штраф' 'суд'
#  'мошенничество' 'деяние' 'вор' 'наказание' 'злодей'] 11
# 120 ['копь' 'зен' 'рах' 'окс' 'кам' 'арг' 'нор' 'бур' 'заб' 'кал' 'диз' 'лут'] 12
# 140 ['дубляж' 'хронометраж' 'показ' 'дубль' 'раскадровка' 'озвучивание'
#  'просмотр' 'метраж' 'монтаж'] 9
# 69 ['носитель' 'расшифровка' 'ксп' 'тос' 'кодировка' 'пиктограмма'
#  'кодирование' 'байт' 'бит' 'запись' 'метка' 'хеш' 'отображение'] 13
# 137 ['уйгур' 'еврей' 'гагауз' 'армянин' 'цыган' 'киргиз' 'кореец' 'татарин'
#  'грузин' 'таджик' 'молдаванин' 'башкир' 'казах' 'китаец' 'аварец'
#  'черкес' 'адыгеец' 'осетин'] 18
# 179 ['платформа' 'станция' 'паровоз' 'поезд' 'вагон' 'депо'] 6
# 132 ['кукла' 'кольцо' 'фигурка' 'пояс' 'кос' 'мех' 'платье' 'сум' 'фигура'
#  'костюм' 'браслет' 'шапка'] 12
# 105 ['транслитерация' 'алфавит' 'орфография' 'авторство' 'латиница'
#  'кириллица' 'написание' 'письменность' 'глаголица'] 9
# 134 ['создатель' 'спр' 'буркхардт' 'брауэр' 'основатель' 'уолд' 'фор'
#  'академик' 'мыслитель' 'гардинер'] 10
# 125 ['обновление' 'эксплуатация' 'закладка' 'ввод' 'замена' 'разрушение'
#  'возобновление' 'обогащение' 'насаждение'] 9
# 76 ['зомби' 'эст' 'аджа' 'кри' 'бел' 'маг' 'бох' 'жем' 'панчо' 'вампир'] 10
# 92 ['штат' 'кабул' 'кук' 'ярд' 'эри' 'вирджиния' 'колумбия' 'онтарио' 'тенер'
#  'мисс' 'нигер' 'норфолк'] 12
# 187 ['подбор' 'выбор' 'отбор'] 3
# 11 ['модификация' 'ед' 'бс' 'абс' 'мтз' 'ппд' 'кз' 'рпо' 'набор' 'пм' 'опп'
#  'комплект' 'комплектация'] 13
# 116 ['деньга' 'трояк' 'скрупул' 'рысачок' 'шти' 'фунт' 'копейка'] 7
# 53 ['местоположение' 'местность' 'вода' 'километр' 'устье' 'поле' 'ангара'
#  'земля' 'окрестность' 'река' 'верста' 'озеро'] 12
# 117 ['мир' 'нек' 'личность' 'человек' 'образ' 'индивид' 'суть' 'существо'
#  'вселенная' 'эманация'] 10
# 141 ['сессия' 'съезд' 'выступление' 'конгресс' 'конференция' 'резолюция'] 6
# 57 ['лич' 'строение' 'бор' 'гук' 'рен' 'дау' 'открыватель' 'фабрициус'] 8
# 19 ['леклерк' 'солид' 'рубин' 'анк' 'хаф' 'тер' 'тихомир' 'эксетер' 'экс'
#  'зак' 'спар' 'эве' 'александер' 'альберта' 'итт' 'мад' 'шнайдер' 'итс'
#  'рэнди'] 19
# 150 ['окрас' 'мес' 'порода' 'гранит'] 4
# 199 ['департамент' 'шеф' 'отдел' 'заведующий' 'начальник' 'директор'
#  'отделение' 'помощник'] 8
# 83 ['гость' 'зал' 'кавалер' 'метрдотель' 'персона' 'кабинет' 'бал'
#  'посетитель' 'гостиная'] 9
# 96 ['хер' 'кок' 'глот' 'кока' 'чак' 'аут'] 6
# 95 ['попытка' 'причина' 'шанс' 'обстоятельство' 'вероятность' 'возможность'
#  'риск' 'последствие' 'случай' 'предупреждение'] 10
# 193 ['этнос' 'национальность' 'народ' 'нация' 'племя' 'вероисповедание' 'раса'
#  'самоназвание' 'самоидентификация' 'народность' 'конфессия'] 11
# 100 ['реакция' 'действие' 'эффект' 'свойство' 'светочувствительность'
#  'воздействие' 'чувствительность' 'концентрация' 'способность'
#  'активность'] 10
# 111 ['защитник' 'наставник' 'глашатай' 'арена' 'гладиатор' 'вождь'
#  'знаменитость' 'борец' 'защита' 'деятель' 'оплот'] 11
# 97 ['аэростат' 'дальномер' 'аппарат' 'шар' 'трос' 'кабель'] 6
# 194 ['уход' 'смена' 'приход' 'появление' 'пробуждение' 'воскрешение'] 6
# 75 ['минута' 'момент' 'ожидание' 'инка' 'близость'] 5
# 94 ['квебек' 'ассамблея' 'хельсинки' 'виннипег' 'миннеаполис' 'амстердам'
#  'бостон'] 7
# 177 ['подвид' 'размножение' 'триба' 'ареал' 'растение' 'имаго' 'животное'
#  'протист' 'неарктика'] 9
# 183 ['причастие' 'падеж' 'склонение' 'спряжение' 'наклонение' 'местоимение'
#  'предлог'] 7
# 191 ['энергоблок' 'топливо' 'мвт' 'аэс' 'суг' 'газ' 'энергетика' 'реактор'
#  'сог'] 9
# 185 ['правило' 'стандарт' 'запрет' 'соответствие' 'ограничение' 'норма'] 6
# 21 ['ени' 'белогорье' 'апо' 'ата' 'кас' 'вос' 'каз' 'вах' 'сиб' 'ая' 'ета'
#  'лех'] 12
# 142 ['венгр' 'немец' 'литовец' 'украинец' 'поляк' 'чех' 'латыш' 'белорус'] 8
# 107 ['композитор' 'архитектор' 'художник' 'мастер' 'поэт' 'скульптор'
#  'каллиграф'] 7
# 181 ['долг' 'честь' 'достоинство'] 3
# 35 ['рус' 'орд' 'северовосток' 'новгород' 'мордва' 'вече' 'улус'] 7
# 32 ['жертва' 'смерть' 'мор' 'извержение' 'казнь' 'пожар' 'убийство'] 7
# 192 ['могул' 'разгон' 'спуск' 'передвижение' 'лазание' 'тяга' 'уклон'
#  'движение'] 8
# 190 ['травма' 'попадание' 'осколок' 'повреждение'] 4
# 27 ['государство' 'династия' 'община' 'братство' 'независимость' 'владение'
#  'подчинение' 'свобода' 'власть' 'освобождение' 'экспансия' 'империя'] 12
# 195 ['исп' 'вр' 'внутр' 'поливанов'] 4
# 16 ['экипаж' 'полость' 'борт' 'бак' 'цилиндр' 'палуба' 'гондола'] 7
# 138 ['погода' 'синева' 'ветер' 'луч' 'воздух'] 5
# 118 ['особенность' 'признак' 'черта' 'слабость' 'характер' 'поведение'
#  'выражение'] 7
# 198 ['аббатство' 'храм' 'епархия' 'духовенство' 'монастырь' 'церковь' 'монах'
#  'причт' 'священник' 'часовня' 'собор'] 11
# 109 ['муха' 'соты' 'рой' 'гриб' 'гнездо' 'яйцо'] 6
# 139 ['жрец' 'раб' 'кир' 'фараон' 'спарта' 'тит' 'олимпия' 'фила'] 8
# 164 ['препарат' 'доза' 'заболевание' 'болезнь' 'лекарство' 'гипертермия'
#  'синдром' 'реципиент' 'стимулятор'] 9
# 42 ['механик' 'одиночка' 'напарник' 'камера' 'охотник' 'любитель'] 6
# 176 ['королева' 'граф' 'правитель' 'монарх' 'герцогиня' 'коронация'
#  'императрица' 'князь' 'царь'] 9
# 98 ['клапрот' 'кантон' 'ган' 'делиль' 'берн' 'араго'] 6
# 102 ['кав' 'бол' 'гв' 'южн' 'ниж' 'зап' 'кап' 'пос'] 8
# 77 ['скульптура' 'музей' 'достопримечательность' 'клад' 'экспонат'
#  'захоронение' 'памятник' 'артефакт'] 8
# 10 ['тело' 'ядро' 'мышца' 'полушарие' 'кость' 'поверхность' 'кора' 'слой'
#  'оболочка'] 9
# 56 ['евр' 'гал' 'ад' 'моисей' 'нум' 'тму' 'кинт' 'бог' 'бес' 'чт'] 10
# 127 ['дуб' 'корень' 'лес' 'дерево' 'лист' 'ветвь'] 6
# 165 ['сибиряк' 'таврия' 'край' 'приамурье' 'полоса'] 5
# 34 ['бассейн' 'осадок' 'сток' 'осадка' 'водохранилище'] 5

# %%
get_metrics(embeddings_reshaped, df_cls[name])
# Out:
# {'silhouette_score': 0.03368078649065845,
#  'calinski_harabasz_index': 5.077229933890018,
#  'davies_bouldin_index': 2.7805275651323145}

# %% [markdown]
# ## OPTICS; time complexity($N^2$)
#
# Алгоритм OPTICS имеет много общего с алгоритмом DBSCAN и может рассматриваться как обобщение DBSCAN, в котором требование к параметру eps ослаблено с единственного значения до диапазона значений.
#
# Ключевое различие между DBSCAN и OPTICS заключается в том, что алгоритм OPTICS строит граф достижимости, который присваивает каждому образцу как расстояние_достижимости, так и место в атрибуте_упорядочивания_кластера; эти два атрибута присваиваются при подгонке модели и используются для определения принадлежности к кластеру.

# %%
if sample:
    from sklearn.cluster import OPTICS

    name = "optics"
    model = OPTICS
    df_cls[name] = model(
        min_samples=2,
        max_eps=0.91,
        min_cluster_size=2,
        n_jobs=-1,
        # cluster_method="dbscan"
    ).fit_predict(embeddings_reshaped)
    
    cluster_dict = get_cluster_id_words(name)
    print_cluster_to_word(cluster_dict)
else:
    print("Do not wait slow algos enabled")
# Out:
# -1 ['алгоритм' 'чарт' 'яванец' ... 'подпор' 'менеджер' 'рок'] 1693
# 13 ['титул' 'звание' 'должность' 'чин'] 4
# 14 ['население' 'житель'] 2
# 15 ['матч' 'турнир' 'чемпион' 'сборная' 'чемпионат' 'тренер' 'чемпионка'] 7
# 28 ['название' 'наименование'] 2
# 29 ['очки' 'очко'] 2
# 30 ['страна' 'регион' 'правительство' 'муниципалитет' 'государство'
#  'губернатор' 'сенатор' 'власть' 'империя' 'администрация' 'советник'] 11
# 31 ['имя' 'фамилия'] 2
# 32 ['соперник' 'соперница' 'конкурент'] 3
# 36 ['сертификация' 'сертификат'] 2
# 37 ['итог' 'результат'] 2
# 38 ['победитель' 'победа' 'победительница'] 3
# 0 ['показатель' 'параметр'] 2
# 6 ['млн' 'тыс'] 2
# 39 ['планета' 'астероид'] 2
# 40 ['город' 'столица' 'провинция' 'пригород'] 4
# 42 ['факультет' 'колледж' 'университет' 'кафедра' 'ректор'] 5
# 43 ['армия' 'фронт' 'дивизия' 'войско' 'полк' 'эскадрон'] 6
# 50 ['отель' 'мажестик'] 2
# 51 ['деталь' 'подробность'] 2
# 52 ['судьба' 'участь'] 2
# 3 ['способ' 'метод'] 2
# 53 ['владелец' 'собственник'] 2
# 54 ['награда' 'медаль'] 2
# 21 ['лауреат' 'премия'] 2
# 55 ['значение' 'смысл'] 2
# 56 ['язык' 'диалект'] 2
# 57 ['число' 'количество'] 2
# 58 ['группа' 'подгруппа'] 2
# 59 ['двигатель' 'мотор'] 2
# 61 ['исполнитель' 'исполнение'] 2
# 48 ['бомбардировщик' 'эскадрилья' 'истребитель' 'авиация'] 4
# 63 ['район' 'территория'] 2
# 64 ['пассажиропоток' 'грузооборот' 'грузопоток' 'пассажирооборот'] 4
# 33 ['месяц' 'день' 'неделя'] 3
# 65 ['серебро' 'золото'] 2
# 67 ['участник' 'руководитель' 'руководство' 'организатор'] 4
# 69 ['улица' 'двор'] 2
# 70 ['брак' 'супруг'] 2
# 73 ['голос' 'бас'] 2
# 75 ['окончание' 'завершение'] 2
# 78 ['метр' 'км' 'километр' 'верста'] 4
# 19 ['старт' 'финиш'] 2
# 77 ['май' 'июль' 'июнь'] 3
# 79 ['рождаемость' 'смертность'] 2
# 80 ['погон' 'петлица'] 2
# 81 ['градус' 'температура' 'плавление' 'цельсий'] 4
# 84 ['комментарий' 'пояснение'] 2
# 27 ['студия' 'киностудия'] 2
# 17 ['суперкубок' 'бундеслига'] 2
# 85 ['таблица' 'диаграмма'] 2
# 86 ['пантера' 'леопард'] 2
# 46 ['судно' 'корабль'] 2
# 87 ['длительность' 'продолжительность' 'интервал'] 3
# 88 ['вооружение' 'оружие'] 2
# 12 ['конструктор' 'окб'] 2
# 2 ['использование' 'применение'] 2
# 91 ['пар' 'пара'] 2
# 92 ['рыба' 'улов'] 2
# 93 ['дизайн' 'дизайнер'] 2
# 94 ['тв' 'сми' 'телеканал'] 3
# 95 ['обозначение' 'представление' 'понятие' 'термин'] 4
# 72 ['бой' 'сражение'] 2
# 96 ['начало' 'конец'] 2
# 97 ['продюсер' 'кинокомпания'] 2
# 98 ['трасса' 'автодром'] 2
# 101 ['организация' 'объединение'] 2
# 102 ['длина' 'диаметр' 'радиус' 'ширина' 'толщина' 'мм'] 6
# 103 ['фракция' 'лдпр' 'дпр' 'спс'] 4
# 11 ['предприятие' 'промышленность' 'отрасль'] 3
# 104 ['оля' 'женщина' 'девушка' 'мужчина' 'юноша' 'девочка'] 6
# 105 ['подбор' 'отбор'] 2
# 106 ['стадия' 'этап' 'фаза'] 3
# 107 ['кредит' 'банк' 'погашение'] 3
# 108 ['кандидат' 'претендент'] 2
# 109 ['алфавит' 'буква'] 2
# 111 ['информация' 'данные' 'сведение'] 3
# 35 ['пересказ' 'рассказчик' 'роман' 'повесть' 'рассказ'] 5
# 112 ['гость' 'посетитель'] 2
# 113 ['эмблема' 'атрибут' 'символ'] 3
# 114 ['прибыль' 'бюджет' 'заработок' 'расход' 'налог' 'доход'] 6
# 115 ['этнос' 'национальность' 'народ' 'нация' 'племя' 'вероисповедание'
#  'народность'] 7
# 116 ['защитник' 'защита'] 2
# 117 ['изменение' 'сдвиг'] 2
# 118 ['восток' 'север' 'запад'] 3
# 123 ['гагауз' 'адыгеец'] 2
# 125 ['съезд' 'созыв' 'конгресс' 'конференция'] 4
# 126 ['кратер' 'извержение'] 2
# 23 ['театр' 'спектакль' 'драматург' 'труппа' 'пьеса'] 5
# 127 ['произведение' 'творение'] 2
# 62 ['диапазон' 'спектр'] 2
# 10 ['компания' 'фирма'] 2
# 71 ['сервер' 'пользователь'] 2
# 128 ['патрон' 'ппш' 'винтовка' 'снаряд'] 4
# 129 ['энергоблок' 'аэс' 'реактор' 'ускоритель'] 4
# 130 ['отдел' 'заведующий'] 2
# 131 ['судья' 'суд'] 2
# 49 ['авиакомпания' 'эксплуатант' 'авиалиния'] 3
# 76 ['январь' 'февраль'] 2
# 45 ['офицер' 'солдат'] 2
# 132 ['дуэль' 'поединок'] 2
# 60 ['автомобиль' 'машина' 'мотоцикл' 'авто'] 4
# 119 ['армянин' 'грузин'] 2
# 133 ['формула' 'множитель' 'уравнение'] 3
# 134 ['четверть' 'половина'] 2
# 135 ['текст' 'цитата'] 2
# 22 ['сериал' 'телесериал'] 2
# 26 ['композитор' 'музыкант'] 2
# 136 ['тема' 'тематика'] 2
# 137 ['радио' 'радиостанция' 'передатчик'] 3
# 9 ['экспорт' 'импорт'] 2
# 68 ['комитет' 'совет' 'комиссия'] 3
# 138 ['транспорт' 'груз' 'перевозка'] 3
# 139 ['фигурка' 'фигура'] 2
# 140 ['вязкость' 'плотность'] 2
# 18 ['динамо' 'спартак'] 2
# 141 ['дифтонг' 'альтернация' 'аффриката' 'частотность' 'фонема' 'аффикс'] 6
# 66 ['никель' 'металл' 'платина'] 3
# 8 ['цена' 'стоимость'] 2
# 142 ['стр' 'соч'] 2
# 143 ['уезд' 'волость'] 2
# 145 ['религия' 'идеология'] 2
# 146 ['верфь' 'судоверфь'] 2
# 147 ['родитель' 'родственник' 'отец'] 3
# 148 ['запах' 'аромат'] 2
# 25 ['художник' 'скульптура' 'скульптор'] 3
# 149 ['оригинал' 'копия'] 2
# 150 ['запрет' 'ограничение'] 2
# 16 ['полуфинал' 'четвертьфинал'] 2
# 151 ['храм' 'часовня'] 2
# 90 ['устье' 'река' 'озеро'] 3
# 153 ['структура' 'реализация' 'функция' 'формирование' 'создание'
#  'взаимодействие'] 6
# 154 ['королева' 'герцогиня' 'императрица'] 3
# 100 ['белград' 'югославия'] 2
# 44 ['штаб' 'командующий'] 2
# 155 ['ареал' 'неарктика'] 2
# 41 ['строка' 'страница'] 2
# 47 ['борт' 'палуба'] 2
# 156 ['субрегион' 'атр'] 2
# 157 ['прыжок' 'бросок'] 2
# 158 ['созвездие' 'звезда'] 2
# 82 ['компартмент' 'липаза' 'гистамин'] 3
# 159 ['семейство' 'семья'] 2
# 160 ['минимум' 'максимум'] 2
# 161 ['индикатор' 'шкала'] 2
# 1 ['эффективность' 'результативность'] 2
# 162 ['заболевание' 'болезнь'] 2
# 163 ['звук' 'звучание' 'тональность'] 3
# 164 ['широта' 'долгота'] 2
# 24 ['либретто' 'опера' 'балет'] 3
# 165 ['предок' 'потомок'] 2
# 166 ['свойство' 'способность'] 2
# 167 ['потеря' 'утрата'] 2
# 168 ['депутат' 'парламент'] 2
# 170 ['кореец' 'китаец'] 2
# 171 ['дуб' 'дерево' 'ветвь'] 3
# 172 ['путь' 'дорога'] 2
# 124 ['шах' 'султан'] 2
# 173 ['выигрыш' 'проигрыш'] 2
# 174 ['комбинация' 'сочетание'] 2
# 175 ['психология' 'физиология' 'химия'] 3
# 176 ['независимость' 'свобода'] 2
# 177 ['ром' 'вино'] 2
# 20 ['поезд' 'вагон'] 2
# 178 ['кабинет' 'гостиная'] 2
# 122 ['украинец' 'белорус'] 2
# 179 ['музей' 'экспонат'] 2
# 180 ['южн' 'зап'] 2
# 181 ['нота' 'аккорд' 'октава'] 3
# 83 ['гравюра' 'рисунок'] 2
# 121 ['татарин' 'башкир'] 2
# 74 ['тысячелетие' 'век'] 2
# 182 ['монастырь' 'монах'] 2
# 34 ['понедельник' 'суббота' 'воскресение'] 3
# 7 ['миллион' 'сотня' 'тысяча'] 3
# 183 ['платье' 'костюм'] 2
# 184 ['монарх' 'царь'] 2
# 120 ['болгарин' 'турок' 'серб'] 3
# 110 ['латиница' 'кириллица' 'глаголица'] 3
# 152 ['церковь' 'собор'] 2
# 5 ['наличие' 'отсутствие'] 2
# 89 ['гора' 'хребет'] 2
# 185 ['жир' 'масло'] 2
# 144 ['село' 'деревня'] 2
# 186 ['бок' 'спина'] 2
# 187 ['заказ' 'заказчик' 'подрядчик'] 3
# 169 ['голосование' 'референдум'] 2
# 99 ['швеция' 'норвегия'] 2
# 4 ['анализ' 'исследование'] 2

# %% [markdown]
# ## Agglomerative Hierarchy
#
# Иерархическая кластеризация - это общее семейство алгоритмов кластеризации, которые строят вложенные кластеры путем последовательного слияния или разделения. Эта иерархия кластеров представляется в виде дерева (или дендрограммы). Корень дерева - это уникальный кластер, в котором собраны все образцы, а листья - кластеры, в которых есть только один образец.

# %%
if sample or ram > 16:
    from sklearn.cluster import AgglomerativeClustering

    num_clusters = 100
    
    name = "agglomerative"
    model = AgglomerativeClustering

    df_cls[name] = model().fit_predict(embeddings_reshaped)

    cluster_dict = get_cluster_id_words(name)
    print_cluster_to_word(cluster_dict)
else:
    print("Not enough memory")
# Out:
# 0 ['алгоритм' 'чарт' 'титул' ... 'признание' 'инцидент' 'менеджер'] 1183
# 1 ['яванец' 'население' 'матч' 'позиция' 'мяч' 'очки' 'дата' 'кубок' 'место'
#  'сезон' 'соперник' 'линия' 'год' 'спортсмен' 'турнир' 'мон' 'соперница'
#  'команда' 'победитель' 'игрок' 'лек' 'нагрузка' 'кан' 'клуб' 'планета'
#  'город' 'соревнование' 'армия' 'расстояние' 'отель' 'слалом' 'рио'
#  'судьба' 'расположение' 'финал' 'пол' 'поз' 'владелец' 'лига' 'пункт'
#  'цвет' 'ита' 'пилот' 'поул' 'конь' 'корпус' 'двигатель' 'раунд' 'тур'
#  'координата' 'чемпион' 'сплит' 'масса' 'бомбардировщик' 'очко' 'материал'
#  'район' 'блок' 'пассажиропоток' 'фра' 'месяц' 'тор' 'кат' 'улица' 'брак'
#  'сборная' 'противник' 'заплыв' 'остров' 'напор' 'вва' 'победа'
#  'чемпионат' 'палочка' 'юрг' 'игра' 'штурмовка' 'медалист' 'маршрут'
#  'метр' 'фронт' 'вместимость' 'старт' 'финиш' 'орбита' 'градус' 'дорожка'
#  'суперкубок' 'церемония' 'рывок' 'пантера' 'илл' 'судно' 'вооружение'
#  'восхождение' 'атлет' 'пас' 'капитан' 'вершина' 'пар' 'доска' 'сеп'
#  'корабль' 'стрельба' 'рыба' 'даза' 'юпитер' 'вылет' 'площадь' 'посадка'
#  'парк' 'пассажир' 'часть' 'стадион' 'преследование' 'копь' 'теннисист'
#  'бой' 'отряд' 'трасса' 'африка' 'дивизия' 'столица' 'длина'
#  'эксцентриситет' 'пересадка' 'уйгур' 'войско' 'дислокация'
#  'местонахождение' 'ро' 'платформа' 'пара' 'оля' 'кукла' 'шасси' 'склад'
#  'шина' 'подрайон' 'тренер' 'кролик' 'зомби' 'спринт' 'гурт' 'км' 'штат'
#  'день' 'выходной' 'подкова' 'направление' 'женщина' 'девушка' 'хозяин'
#  'высота' 'вратарь' 'аэродром' 'гол' 'македония' 'деньга' 'местоположение'
#  'местность' 'космос' 'спортсменка' 'гонка' 'мир' 'кандидат' 'дивизион'
#  'бокс' 'месторасположение' 'лич' 'леклерк' 'провинция' 'сет' 'фигурист'
#  'поб' 'астероид' 'обладатель' 'гость' 'заезд' 'экспедиция' 'хер'
#  'сторона' 'вода' 'территория' 'гонщик' 'хай' 'шеф' 'житель' 'диаметр'
#  'кольцо' 'защитник' 'аэростат' 'восток' 'покрытие' 'футболист' 'круг'
#  'колесо' 'еврей' 'камаз' 'минута' 'дистанция' 'рождение' 'радиус'
#  'гагауз' 'кратер' 'эстафета' 'квебек' 'сражение' 'толчок' 'супергигант'
#  'барьер' 'произведение' 'сила' 'чемп' 'конькобежец' 'бег' 'дир' 'чтение'
#  'патрон' 'выход' 'нападающий' 'причастие' 'авиакомпания' 'строение' 'пао'
#  'ио' 'офицер' 'температура' 'янг' 'дуэль' 'автомобиль' 'миль'
#  'велогонщик' 'скорость' 'инд' 'штурман' 'полузащитник' 'забег' 'армянин'
#  'воин' 'ени' 'мас' 'венгр' 'четверть' 'вечер' 'мотор' 'алк' 'рапира'
#  'зенит' 'трофей' 'порт' 'рекорд' 'фламинго' 'цыган' 'запуск' 'либра'
#  'рез' 'рус' 'нок' 'белогорье' 'киргиз' 'инструмент' 'плато' 'жертва'
#  'кар' 'первенство' 'транспорт' 'бан' 'точка' 'станция' 'энергия' 'разгон'
#  'бре' 'эст' 'вязкость' 'зона' 'динамо' 'чемпионка' 'брасс' 'орд' 'экипаж'
#  'супруг' 'гз' 'тау' 'зал' 'машина' 'томь' 'груз' 'велоспорт' 'ралли'
#  'лив' 'наставник' 'ант' 'аджа' 'поражение' 'голова' 'кри' 'вол'
#  'династия' 'юниор' 'луна' 'перевозка' 'форвард' 'участок' 'уезд' 'спуск'
#  'бай' 'орудие' 'плотность' 'погода' 'километр' 'запас' 'флот' 'посев'
#  'трояк' 'трамплин' 'ширина' 'родитель' 'передвижение' 'шайба' 'запах'
#  'аббатство' 'мужчина' 'пояс' 'пгт' 'час' 'боец' 'вар' 'куба' 'полк'
#  'муха' 'спорт' 'толщина' 'нарез' 'жрец' 'рейс' 'раб' 'кок' 'ирландия'
#  'скрупул' 'мусульманин' 'командир' 'королевство' 'герцогство' 'механик'
#  'смерть' 'майами' 'путешествие' 'кит' 'лазание' 'боулер' 'полуфинал'
#  'рысачок' 'канонизация' 'нек' 'танк' 'генерал' 'календарь' 'кир' 'кош'
#  'храм' 'водоизмещение' 'родственник' 'шир' 'бомбардир' 'победительница'
#  'спа' 'отв' 'устье' 'тра' 'плавание' 'королева' 'жирность' 'белград'
#  'трек' 'гдр' 'творение' 'плейофф' 'болид' 'поле' 'дворец' 'площадка'
#  'привод' 'аэропорт' 'бундеслига' 'война' 'мкс' 'ория' 'немец' 'пот'
#  'бангкок' 'клапрот' 'артикул' 'штаб' 'крыло' 'бригада' 'осм' 'исход'
#  'ппш' 'кла' 'повозка' 'ничья' 'ангара' 'рпд' 'полость' 'глашатай' 'сев'
#  'биатлонист' 'тройка' 'кав' 'грудь' 'кориолис' 'бор' 'паровоз' 'человек'
#  'кло' 'борт' 'кук' 'фараон' 'фак' 'боезапас' 'мотоцикл' 'гро' 'кос' 'бел'
#  'домен' 'прыжок' 'действо' 'созвездие' 'зен' 'тело' 'семейство'
#  'дальномер' 'этаж' 'оружие' 'апо' 'беш' 'фигуристка' 'рах' 'земля'
#  'пролог' 'олимпиада' 'северовосток' 'широта' 'сход' 'гимнастка' 'окс'
#  'арена' 'бол' 'локомотив' 'движок' 'перестрелка' 'картофель' 'гладиатор'
#  'звезда' 'посвящение' 'сау' 'неделя' 'полиция' 'ракета' 'спутник'
#  'волость' 'дом' 'пик' 'правление' 'стыковка' 'лок' 'метрдотель' 'авт'
#  'рыболовство' 'пан' 'кореец' 'соты' 'вождь' 'молоко' 'мек' 'претендент'
#  'праздник' 'ранетка' 'мм' 'сан' 'отец' 'рапид' 'евр' 'пасифик' 'синева'
#  'рош' 'обрезание' 'кам' 'воеводство' 'маг' 'дуб' 'персона' 'арбитр' 'гал'
#  'путь' 'рестлер' 'шах' 'глот' 'выигрыш' 'окрестность' 'ата' 'старшина'
#  'рот' 'гв' 'маз' 'анк' 'трейлер' 'состязание' 'новгород' 'стрела' 'тиг'
#  'фен' 'растение' 'араб' 'сме' 'граф' 'ска' 'терминал' 'овертайм' 'япония'
#  'епархия' 'эсминец' 'ои' 'спартак' 'литовец' 'духовенство' 'автодорога'
#  'зад' 'мордва' 'хоккеист' 'независимость' 'ром' 'поезд' 'эскадрилья'
#  'адмирал' 'кабинет' 'кузов' 'хаф' 'жим' 'сол' 'украинец' 'пробуждение'
#  'река' 'корень' 'добыча' 'прочность' 'хет' 'акробатика' 'олд' 'америка'
#  'впп' 'военный' 'рен' 'ад' 'рой' 'бар' 'плавление' 'южн' 'глубина'
#  'освоенность' 'зажигание' 'север' 'владение' 'блиц' 'тир' 'мальорка'
#  'крыса' 'тро' 'шти' 'лес' 'калибр' 'долгота' 'ярд' 'тер' 'тоннаж' 'вич'
#  'аромат' 'арг' 'ступень' 'поток' 'бак' 'мышца' 'многоборье' 'югославия'
#  'дорога' 'сибиряк' 'аппарат' 'одиночка' 'фабрициус' 'вал' 'кантон'
#  'чехия' 'бир' 'бад' 'спо' 'тайм' 'татарин' 'султан' 'спарта' 'мор'
#  'любовь' 'кас' 'животное' 'монастырь' 'полт' 'поединок' 'понедельник'
#  'остаток' 'вос' 'доступ' 'кре' 'рим' 'стабилизатор' 'протист' 'колея'
#  'напарник' 'шашка' 'эксплуатант' 'португалия' 'дерево' 'моисей' 'шт'
#  'кока' 'знаменитость' 'нум' 'фукуока' 'грузооборот' 'контур' 'лист'
#  'хельсинки' 'гриб' 'вагон' 'мех' 'айн' 'свобода' 'мос' 'тб' 'кер'
#  'грузин' 'ключ' 'правитель' 'таджик' 'платье' 'монарх' 'таврия' 'край'
#  'фунт' 'кол' 'болгарин' 'шар' 'квн' 'семья' 'запад' 'трос' 'кру' 'эри'
#  'лев' 'пенальти' 'церковь' 'сум' 'юноша' 'занятие' 'стэм' 'спирт'
#  'вирджиния' 'ветер' 'мультиплекс' 'атл' 'полиамид' 'грузопоток' 'монах'
#  'винтовка' 'память' 'тихомир' 'извержение' 'коу' 'колумбия' 'бельгия'
#  'посетитель' 'обезьяна' 'истребитель' 'пассажирооборот' 'океания' 'бутсы'
#  'онтарио' 'тяга' 'порог' 'марсель' 'ветвь' 'дин' 'гора' 'кай' 'мажестик'
#  'лента' 'ган' 'вино' 'гнездо' 'эксетер' 'карбюратор' 'нер' 'сатурн'
#  'подбой' 'бом' 'пари' 'бох' 'молдаванин' 'пересечение' 'бер' 'экс'
#  'полушарие' 'нор' 'яблоко' 'чак' 'герцогиня' 'аут' 'мкк' 'жир' 'ниж'
#  'гимнаст' 'импульс' 'проп' 'поляк' 'кость' 'вилка' 'зап' 'туризм'
#  'стихия' 'ребро' 'цветок' 'масло' 'казнь' 'атака' 'латвия' 'челленджер'
#  'вилайет' 'сал' 'ник' 'борец' 'турок' 'жем' 'каток' 'село' 'галлон'
#  'автодром' 'пожар' 'лыжник' 'костюм' 'лыжница' 'освобождение' 'коммисар'
#  'луч' 'светимость' 'заруб' 'суббота' 'шест' 'тит' 'бок' 'эве' 'индуизм'
#  'шотландия' 'причт' 'тму' 'цилиндр' 'поверхность' 'убийство'
#  'индианаполис' 'приамурье' 'делиль' 'мит' 'линейка' 'бур' 'половина'
#  'башкир' 'волейбол' 'конкурент' 'улов' 'камера' 'петух' 'тормоз' 'полоса'
#  'серб' 'заб' 'суперлига' 'танкер' 'вкус' 'гостиная' 'леопард' 'шахматист'
#  'двор' 'ткань' 'кора' 'спина' 'куб' 'александер' 'чер' 'ускоритель' 'каз'
#  'эскадрон' 'слой' 'казах' 'деревня' 'воздух' 'авто' 'артиллерия' 'вах'
#  'хард' 'кинт' 'икао' 'торпедо' 'кра' 'резиденция' 'воскресение' 'тенер'
#  'ард' 'альберта' 'олимпия' 'хребет' 'пинта' 'командор' 'вече' 'ессентуки'
#  'марафон' 'баскетбол' 'сиб' 'берн' 'аус' 'гвинея' 'губа' 'швеция'
#  'циклон' 'астронавт' 'азимут' 'курд' 'англия' 'палуба' 'ая' 'браслет'
#  'барбара' 'уклон' 'литр' 'чечевица' 'супруги' 'авиация' 'итт' 'китаец'
#  'космодром' 'фила' 'сечение' 'ску' 'кабель' 'розетка' 'аварец' 'снаряд'
#  'норвегия' 'син' 'проигрыш' 'инт' 'гри' 'зима' 'виннипег' 'оболочка'
#  'араго' 'вход' 'ково' 'олимпиакос' 'пловец' 'нахия' 'коронация' 'участь'
#  'вязьма' 'зазор' 'виноград' 'панчо' 'мад' 'шем' 'прорыв' 'вселенная'
#  'империя' 'кал' 'викарий' 'мисс' 'охотник' 'командующий' 'стервятник'
#  'зеландия' 'перс' 'защита' 'гондола' 'катание' 'императрица' 'близость'
#  'лека' 'ноо' 'здание' 'чех' 'бассейн' 'черкес' 'миннеаполис'
#  'препятствие' 'яйцо' 'касание' 'давление' 'движение' 'осадок' 'адыгеец'
#  'сверловка' 'ета' 'александрия' 'улус' 'сырь' 'кампания' 'греча' 'пом'
#  'любитель' 'баскетболист' 'собственник' 'диз' 'сток' 'бог' 'осадка'
#  'шнайдер' 'кап' 'гур' 'депо' 'трансмиссия' 'вор' 'нигер' 'священник'
#  'верста' 'авма' 'часовня' 'предлог' 'бес' 'амстердам' 'князь' 'авиалиния'
#  'такт' 'мальта' 'осетин' 'деятель' 'магистраль' 'цельсий' 'царь' 'шапка'
#  'консоль' 'шаг' 'лех' 'цдка' 'копейка' 'гардинер' 'бешикташ'
#  'водохранилище' 'упражнение' 'осада' 'итс' 'эдм' 'самбо' 'озеро' 'мантра'
#  'перигелий' 'эманация' 'мак' 'бро' 'кеми' 'воскрешение' 'норфолк'
#  'вампир' 'телебашня' 'четвертьфинал' 'сжатие' 'латыш' 'бросок' 'чт'
#  'габарит' 'лут' 'хвост' 'скобка' 'злодей' 'пригород' 'мат' 'солдат'
#  'кома' 'су' 'пос' 'теннисистка' 'собор' 'бостон' 'угол' 'оплот' 'сорт'
#  'бей' 'боеприпас' 'подпор' 'белорус' 'девочка' 'рок'] 997

# %% [markdown]
# ## K-means
#
# Алгоритм KMeans кластеризует данные, пытаясь разделить образцы по n группы с одинаковой дисперсией, минимизируя критерий - внутрикластерная сумма квадратов. Для этого алгоритма требуется число кластеров, которые необходимо указать. Он хорошо масштабируется для большого количества выборок и имеет использовался в самых разных областях применения в самых разных областях.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import KMeans

name = "kmeans"
model = KMeans

clustering_params = find_best_clustering_params(embeddings_reshaped, model, min_num_clusters=145, max_num_clusters=155)

print(clustering_params, end="\n\n\n")

df_cls[name] = clustering_params["best_clusters"]
cluster_dict = get_cluster_id_words(name)

print_cluster_to_word(cluster_dict)
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:13<00:00,  1.37s/it]
# {'best_clustering_score': 5.764167414303667, 'best_num_clusters': 145, 'best_clusters': array([21, 62, 44, ..., 19, 50, 62], dtype=int32)}
#
#
# 21 ['алгоритм' 'модель' 'координата' 'идентификатор' 'модификация'
#  'процессор' 'сервер' 'размерность' 'множитель' 'уравнение' 'модуль'
#  'комбинация' 'пиктограмма' 'дисплей' 'вариант' 'дау' 'разбиение'
#  'спецификация' 'фокусировка' 'последовательность' 'пользователь' 'схема'
#  'кластер' 'локация' 'диаграмма' 'отображение'] 26
# 62 ['чарт' 'лейбл' 'серия' 'сайт' 'релиз' 'сингл' 'альбом' 'дискография'
#  'хит' 'ремикс' 'рок'] 11
# 44 ['титул' 'имя' 'наименование' 'звание' 'должность' 'награда' 'ранг'
#  'статус' 'гражданство' 'медаль' 'карьера' 'присвоение' 'разряд' 'чин'
#  'честь' 'фамилия' 'профессия' 'сан' 'достоинство' 'прозвище'] 20
# 18 ['яванец' 'уйгур' 'киргиз' 'кореец' 'кантон' 'айн' 'таджик' 'казах'
#  'китаец'] 9
# 14 ['население' 'численность' 'итог' 'показатель' 'рост' 'процент'
#  'рождаемость' 'динамика' 'прирост' 'рейтинг' 'уровень'
#  'продолжительность' 'балл' 'доля' 'индекс' 'полугодие' 'темп'
#  'посещаемость' 'смертность' 'ввп' 'минимум' 'сальдо' 'заполняемость'
#  'превышение' 'баланс' 'цифра' 'обеспеченность' 'отметка'] 28
# 2 ['категория' 'тип' 'пример' 'описание' 'характеристика' 'образец'
#  'определение' 'качество' 'оценка' 'классификация' 'критерий' 'содержание'
#  'рекомендация' 'прототип'] 14
# 72 ['матч' 'кубок' 'турнир' 'соревнование' 'финал' 'чемпион' 'заплыв'
#  'чемпионат' 'игра' 'финиш' 'спринт' 'гонка' 'заезд' 'эстафета' 'забег'
#  'первенство' 'чемпионка' 'ралли' 'полуфинал' 'олимпиада' 'состязание'
#  'многоборье' 'поединок' 'суперлига' 'четвертьфинал'] 25
# 142 ['партия' 'свдп' 'блок' 'лидер' 'макашов' 'фракция' 'объединение' 'сда'
#  'лдпр' 'дпр' 'спс' 'яблоко' 'элита' 'коалиция' 'большинство'] 15
# 92 ['позиция' 'линия' 'пункт' 'сторона' 'точка' 'грань' 'момент' 'тир'
#  'пересечение'] 9
# 134 ['мяч' 'пас' 'вратарь' 'гол' 'защитник' 'нападающий' 'полузащитник'
#  'зенит' 'форвард' 'шайба' 'бомбардир' 'локомотив' 'тайм' 'пенальти' 'аут'
#  'торпедо' 'бросок'] 17
# 28 ['название' 'язык' 'транскрипция' 'обозначение' 'транслитерация' 'смысл'
#  'предмет' 'форма' 'префикс' 'атрибут' 'принадлежность' 'артикль'
#  'дифтонг' 'брауэр' 'понятие' 'приставка' 'падеж' 'нек' 'альтернация'
#  'эквивалент' 'спряжение' 'глосса' 'акцентуация' 'аффриката' 'частотность'
#  'индивид' 'термин' 'соссюр' 'маскулинность' 'переоткрытие' 'диалект'
#  'пси' 'фонема' 'просодия' 'контекст' 'аффикс' 'местоимение' 'изм'
#  'употребление' 'греча' 'гомосексуальность' 'ударение' 'интерпретация'] 43
# 137 ['очки' 'кольцо' 'бра' 'пояс' 'монета' 'грудь' 'фен' 'мех' 'ключ' 'платье'
#  'сум' 'лента' 'клад' 'ношение' 'браслет'] 15
# 118 ['дата' 'основание' 'число' 'получение' 'материал' 'источник' 'список'
#  'версия' 'вывод' 'таблица' 'датировка' 'информация' 'данные' 'документ'
#  'статистика' 'представление' 'цск' 'связь' 'сведение' 'доступ' 'запись'
#  'опрос' 'наблюдение' 'перепись' 'анализ' 'запрос' 'исследование'
#  'применяемость'] 28
# 4 ['страна' 'остров' 'африка' 'штат' 'македония' 'куба' 'ирландия'
#  'королевство' 'белград' 'гдр' 'япония' 'америка' 'югославия' 'чехия'
#  'португалия' 'колумбия' 'бельгия' 'океания' 'латвия' 'шотландия' 'гвинея'
#  'швеция' 'англия' 'норвегия' 'зеландия' 'нигер' 'мальта'] 27
# 138 ['место' 'маршрут' 'путь' 'дорога' 'колея' 'поиск' 'препятствие'] 7
# 64 ['торговля' 'продажа' 'предприятие' 'производство' 'выпуск' 'экспорт'
#  'промышленность' 'изделие' 'квота' 'нефтепереработка' 'потребление'
#  'отрасль' 'продукция' 'рынок' 'сбыт' 'импорт' 'поставка' 'сектор'
#  'автомобилестроение'] 19
# 29 ['сезон' 'год' 'время' 'месяц' 'пост' 'пара' 'день' 'выходной' 'пора'
#  'минута' 'погода' 'час' 'неделя' 'понедельник' 'ессентуки' 'зима'] 16
# 7 ['соперник' 'поул' 'раунд' 'тур' 'очко' 'победа' 'старт' 'суперкубок'
#  'бокс' 'сет' 'супергигант' 'рекорд' 'томь' 'шанс' 'трек' 'плейофф'
#  'бундеслига' 'ничья' 'арена' 'рапид' 'арбитр' 'рестлер' 'выигрыш'
#  'овертайм' 'блиц' 'мальорка' 'фукуока' 'лидерство' 'автодром'
#  'индианаполис' 'фила' 'проигрыш' 'олимпиакос' 'бешикташ'] 34
# 76 ['дисциплина' 'порядок' 'условие' 'режим' 'правило' 'требование' 'запрет'
#  'артикул' 'соответствие' 'расписание' 'ограничение' 'раздел' 'инструкция'
#  'норма' 'случай'] 15
# 0 ['валюта' 'номинал' 'получатель' 'кредит' 'фонд' 'солид' 'банкнот' 'лат'
#  'бик' 'доходность' 'банк' 'асв' 'карточка' 'вклад' 'капитал' 'погашение'
#  'инвестор' 'эмитент' 'котировка' 'сделка' 'инн' 'пакет' 'филиал'
#  'списание'] 24
# 60 ['спортсмен' 'атлет' 'теннисист' 'спортсменка' 'фигурист' 'гонщик'
#  'конькобежец' 'велогонщик' 'велоспорт' 'юниор' 'спорт' 'биатлонист'
#  'фигуристка' 'гимнастка' 'лыжник' 'лыжница' 'волейбол' 'шахматист'
#  'баскетбол' 'пловец' 'теннисистка'] 21
# 26 ['примечание' 'автор' 'комментарий' 'соавтор' 'создатель' 'перевод' 'жанр'
#  'произведение' 'синопсис' 'текст' 'буркхардт' 'аннотация' 'оригинал'
#  'цитата' 'поэт' 'авторство' 'классика' 'популярность' 'мыслитель'
#  'переводчик' 'жаргонизм' 'написание' 'комментатор' 'псевдоним'] 24
# 122 ['персонаж' 'легенда' 'сюжет' 'пересказ' 'сага' 'эпизод' 'хроника'
#  'подробность' 'рассказчик' 'роман' 'пролог' 'герой' 'повесть' 'рассказ'] 14
# 9 ['мон' 'отель' 'спа' 'метрдотель' 'пасифик' 'олд' 'бар' 'мажестик' 'хард'] 9
# 94 ['сертификация' 'изготовитель' 'стандарт' 'лицензия' 'разработчик'
#  'сертификат' 'контроль' 'маркировка' 'эксплуатант' 'мкк' 'туризм' 'мкб'
#  'федерация' 'икао' 'мониторинг' 'лицензиат'] 16
# 143 ['роль' 'вид' 'значение' 'мера' 'степень' 'обстоятельство' 'особенность'
#  'разнообразие' 'разница' 'признак' 'отношение' 'черта' 'образ' 'свойство'
#  'недостаток' 'характер' 'способность' 'поведение' 'близость' 'отсутствие'
#  'преимущество'] 21
# 68 ['соперница' 'фра' 'герцогство' 'королева' 'монарх' 'герцогиня' 'командор'
#  'императрица'] 8
# 123 ['команда' 'игрок' 'клуб' 'лига' 'сборная' 'стадион' 'тренер' 'футболист'
#  'динамо' 'водник' 'ска' 'спартак' 'хоккеист' 'каток' 'баскетболист'
#  'цдка'] 16
# 30 ['победитель' 'номинация' 'лауреат' 'номинант' 'подиум' 'участник'
#  'медалист' 'премия' 'конкурс' 'участница' 'финалистка' 'фестиваль' 'жюри'
#  'финалист' 'победительница' 'номинатор' 'приз' 'претендент' 'марафон'
#  'евровидение'] 20
# 23 ['млн' 'вес' 'количество' 'микрограмм' 'запас' 'кг' 'тыс' 'тонна'
#  'среднее' 'миллион' 'фунт' 'галлон' 'куб' 'сотня' 'тысяча' 'литр'] 16
# 121 ['результат' 'способ' 'регион' 'система' 'использование' 'метод' 'масштаб'
#  'доступность' 'механизм' 'сокращение' 'фактор' 'комплекс' 'структура'
#  'реализация' 'средство' 'приоритет' 'субрегион' 'эффективность'
#  'стабилизация' 'твд' 'возможность' 'повышение' 'освоенность' 'риск'
#  'ресурс' 'аналог' 'наличие' 'технология' 'замена' 'результативность'
#  'отбор' 'применение' 'миграция' 'совместимость' 'атр' 'ценность'
#  'сложность'] 37
# 111 ['лек' 'илл' 'инд' 'фин' 'стр' 'ория' 'мек' 'рен' 'соч' 'фабрициус' 'бир'
#  'асс' 'бер' 'ред' 'ник' 'тенер' 'сиб' 'аус' 'подпор'] 19
# 67 ['эволюция' 'отставание' 'достижение' 'переход' 'период' 'образование'
#  'стадия' 'этап' 'прогресс' 'формирование' 'создание' 'распространение'
#  'ступень' 'развитие' 'основа' 'расширение' 'экспансия' 'завершение'
#  'регресс'] 19
# 6 ['работа' 'конструктор' 'нтк' 'квалификация' 'участие' 'руководитель'
#  'механик' 'мастер' 'супервайзер' 'нкз' 'задание' 'иаэ' 'специалист'
#  'академик' 'руководство' 'подготовка' 'рпо' 'организатор' 'техника'
#  'химия' 'знание'] 21
# 40 ['номер' 'издание' 'иллюстрация' 'чтение' 'переиздание' 'каталог' 'тираж'
#  'сборник' 'заглавие' 'заметка' 'календарь' 'издатель' 'энциклопедия'
#  'книга' 'рецензия' 'публикация' 'издательство' 'статья' 'заголовок'
#  'журнал' 'колич' 'редактор' 'страница'] 23
# 27 ['нагрузка' 'напряжение' 'мощность' 'энергоблок' 'могул' 'энергия' 'гпз'
#  'топливо' 'мвт' 'аэс' 'суг' 'энергетика' 'мтз' 'нейтраль' 'ток' 'реактор'
#  'амп' 'тяга' 'мтд' 'эдс' 'передатчик' 'ускоритель' 'индуктивность'
#  'вольтаж' 'водохранилище'] 25
# 101 ['кан' 'сеп' 'хай' 'пао' 'янг' 'бан' 'династия' 'бай' 'окс' 'мин' 'кер'
#  'коу' 'дин' 'ган' 'син' 'мад' 'гур'] 17
# 116 ['планета' 'орбита' 'космос' 'мир' 'астероид' 'запуск' 'мкс' 'спутник'
#  'астронавт' 'космодром' 'вселенная'] 11
# 34 ['город' 'столица' 'миссия' 'дворец' 'резиденция' 'пригород'] 6
# 85 ['сценарист' 'фильм' 'экран' 'студия' 'продюсер' 'фото' 'дубляж'
#  'фильмография' 'клип' 'телеверсия' 'сериал' 'показ' 'дубль' 'прокат'
#  'прокатчик' 'мультсериал' 'раскадровка' 'кино' 'видеоклип' 'сценарий'
#  'мультфильм' 'комикс' 'телесериал' 'озвучивание' 'саундтрек' 'просмотр'
#  'кинокомпания' 'экранизация' 'киностудия' 'сценаристка' 'анимация' 'ммкф'] 32
# 126 ['факультет' 'курс' 'класс' 'колледж' 'университет' 'преподавательница'
#  'кафедра' 'ректор' 'занятие' 'магистратура' 'школа' 'учреждение'
#  'заведение'] 13
# 130 ['срок' 'преследование' 'ссылка' 'судья' 'явка' 'приговор' 'штраф' 'казнь'
#  'убийство' 'суд' 'мошенничество' 'деяние' 'вор' 'наказание'
#  'предупреждение' 'злодей'] 16
# 24 ['армия' 'фронт' 'войско' 'ставка' 'война' 'вязьма' 'прорыв'] 7
# 41 ['расстояние' 'метр' 'км' 'высота' 'дистанция' 'радиус' 'скорость'
#  'дальность' 'километр' 'долгота' 'ярд' 'промежуток' 'азимут' 'верста'
#  'шаг'] 15
# 96 ['слалом' 'кат' 'бег' 'брасс' 'трамплин' 'лазание' 'прыжок' 'жим'
#  'акробатика' 'гимнаст' 'катание' 'упражнение' 'самбо'] 13
# 108 ['деталь' 'сплит' 'подбор' 'эксплуатация' 'сев' 'ввод' 'стыковка'
#  'техпроцесс' 'метраж' 'монтаж' 'конструкция'] 11
# 48 ['рио' 'лич' 'леклерк' 'чемп' 'либра' 'роб' 'уолд' 'кок' 'гро' 'гук' 'лок'
#  'рош' 'ром' 'хаф' 'рой' 'тер' 'кока' 'эри' 'тихомир' 'марсель' 'пари'
#  'экс' 'чак' 'саф' 'эве' 'альберта' 'олимпия' 'пинта' 'итт' 'панчо' 'мисс'
#  'шнайдер' 'итс' 'рэнди' 'мак' 'норфолк'] 36
# 69 ['марка' 'дизайн' 'производитель' 'дистрибьютор' 'бренд' 'компания'
#  'агентство' 'фирма' 'боулер' 'мультиплекс' 'бизнес' 'логотип' 'спар'
#  'лэйбл' 'конкурент' 'дизайнер' 'слоган' 'опп'] 18
# 58 ['судьба' 'жертва' 'положение' 'смерть' 'исход' 'освобождение' 'участь'
#  'будущее'] 8
# 17 ['ратификация' 'брак' 'исполнение' 'членство' 'посвящение' 'акт'
#  'введение' 'вступление' 'продолжение' 'принятие' 'возобновление'] 11
# 33 ['шоу' 'канал' 'ведущий' 'тв' 'трансляция' 'аудитория' 'сми' 'эфир'
#  'телеканал' 'хронометраж' 'радио' 'передача' 'вещатель' 'радиостанция'
#  'видео' 'квн' 'интервью' 'телезритель' 'анонс' 'телешоу' 'обозреватель'] 21
# 120 ['расположение' 'разрешение' 'обслуживание' 'дислокация' 'местонахождение'
#  'сбор' 'местоположение' 'месторасположение' 'размещение' 'выбор' 'зона'
#  'этажность' 'передвижение' 'устройство' 'водоснабжение' 'захоронение'
#  'хранение' 'расселение' 'расстановка' 'питание'] 20
# 84 ['пол' 'корзина' 'палочка' 'рапира' 'соты' 'рот' 'гнездо' 'вилка'
#  'розетка'] 9
# 125 ['поз' 'дуэль' 'промах' 'рысачок' 'сибиряк' 'напарник' 'неудачник'
#  'охотник' 'стервятник' 'любитель'] 10
# 102 ['владелец' 'обладатель' 'владение' 'учредитель' 'гильдия' 'сат'
#  'продавец' 'собственник' 'подрядчик'] 9
# 100 ['цвет' 'погон' 'окрас' 'петлица' 'телосложение' 'подбой' 'цветок' 'мода'
#  'костюм' 'полоса'] 10
# 54 ['ита' 'сервис' 'сеть' 'фио' 'поддержка' 'договор' 'тариф' 'абонент'
#  'медпомощь' 'мот' 'заказ' 'рсо' 'услуга'] 13
# 31 ['пилот' 'бомбардировщик' 'штурмовка' 'вылет' 'аэродром' 'штурман' 'ант'
#  'перехват' 'крыло' 'ракета' 'эсминец' 'эскадрилья' 'тб' 'истребитель'
#  'окб' 'авиация' 'су'] 17
# 56 ['бронза' 'изображение' 'композиция' 'стиль' 'портрет' 'мозаика'
#  'художник' 'копия' 'скульптура' 'галерея' 'резьба' 'гравюра' 'рисунок'
#  'картина' 'скульптор' 'фигура' 'донатор' 'репродукция'] 18
# 25 ['конь' 'подкова' 'голова' 'вол' 'повозка' 'зад' 'шашка' 'бутсы' 'жем'
#  'бок' 'спина' 'шапка' 'хвост'] 13
# 119 ['группа' 'дст' 'строй' 'состав' 'организация' 'территория' 'подгруппа'
#  'служба' 'база' 'разведка' 'ряд' 'управление' 'подразделение' 'анк'
#  'операция' 'окп' 'подчинение' 'ппс' 'орб' 'отделение'] 20
# 43 ['планка' 'рывок' 'доска' 'вис' 'скип' 'барьер' 'вал' 'кол' 'трос'
#  'челленджер' 'шест' 'линейка' 'бур' 'кабель' 'связка' 'звено'] 16
# 97 ['корпус' 'отряд' 'дивизия' 'полк' 'бригада' 'кав' 'гв' 'эскадрон'] 8
# 63 ['сумма' 'прибыль' 'сбавка' 'долг' 'бюджет' 'цена' 'стоимость' 'заработок'
#  'руб' 'расход' 'налог' 'выдача' 'доход' 'начисление' 'выручка' 'копейка'
#  'плата'] 17
# 81 ['двигатель' 'шасси' 'шина' 'колесо' 'камаз' 'автомобиль' 'мотор' 'кар'
#  'машина' 'абс' 'болид' 'привод' 'движок' 'маз' 'кузов' 'зажигание'
#  'карбюратор' 'тормоз' 'авто' 'трансмиссия' 'консоль' 'комплектация'] 22
# 77 ['исполнитель' 'песня' 'композитор' 'танец' 'музыка' 'хореограф'
#  'музыкант' 'танцор' 'фуга' 'солист' 'исполнительница' 'ария'] 12
# 52 ['масса' 'пар' 'вода' 'покрытие' 'толчок' 'полость' 'тело' 'земля'
#  'глубина' 'поток' 'контур' 'край' 'шар' 'извержение' 'ребро'
#  'поверхность' 'слой' 'осколок' 'оболочка' 'зазор' 'касание' 'осадок'
#  'сток' 'осадка'] 24
# 22 ['режиссура' 'зритель' 'премьера' 'артист' 'театр' 'актриса' 'спектакль'
#  'действо' 'либретто' 'постановка' 'амплуа' 'сцена' 'либреттист' 'опера'
#  'постановщик' 'драматург' 'стэм' 'труппа' 'стд' 'пьеса' 'балет'] 21
# 38 ['персоналия' 'замечание' 'слово' 'обоснование' 'оппонент' 'формула'
#  'дополнение' 'формулировка' 'речь' 'обращение' 'уточнение' 'нотация'
#  'пояснение' 'умолчание' 'ответ' 'вопрос' 'аргумент' 'выражение'
#  'доказательство' 'признание'] 20
# 127 ['район' 'копь' 'подрайон' 'участок' 'пгт' 'полт' 'приамурье' 'вах'
#  'насаждение' 'кеми' 'пос'] 11
# 114 ['пассажиропоток' 'транспорт' 'груз' 'перевозка' 'перевозчик' 'автодорога'
#  'грузооборот' 'грузопоток' 'пассажирооборот' 'мпс' 'магистраль'] 11
# 78 ['тор' 'реверс' 'эксцентриситет' 'сила' 'разгон' 'склонение' 'кориолис'
#  'широта' 'разность' 'размах' 'наклонение' 'циклон' 'движение' 'авма'] 14
# 65 ['коммуна' 'супруг' 'община' 'родитель' 'родственник' 'семейство'
#  'одиночка' 'семья' 'общество' 'супруги'] 10
# 74 ['микрорайон' 'улица' 'дорожка' 'площадь' 'парк' 'гз' 'площадка' 'бел'
#  'этаж' 'дом' 'квартал' 'двор' 'гам' 'угол'] 14
# 124 ['серебро' 'золото' 'руда' 'никель' 'металл' 'клапрот' 'рубин' 'платина'
#  'добыча' 'газ' 'уголь' 'спирт' 'минерал' 'сурьма'] 14
# 133 ['чистота' 'алк' 'запах' 'пот' 'аромат' 'масло' 'вкус' 'воздух'] 8
# 91 ['размер' 'длина' 'величина' 'диаметр' 'ширина' 'толщина' 'нарез'
#  'удлинение' 'мм' 'прочность' 'калибр' 'шт' 'сечение' 'комплект'
#  'сверловка' 'габарит'] 16
# 105 ['противник' 'стрельба' 'бой' 'дивизион' 'орудие' 'танк' 'дальномер'
#  'перестрелка' 'сау' 'атака' 'артиллерия' 'снаряд'] 12
# 86 ['голос' 'бас' 'струна' 'нота' 'аккорд' 'октава' 'лека' 'такт' 'тон'] 9
# 42 ['напор' 'реакция' 'действие' 'эффект' 'контакт' 'воздействие'
#  'взаимодействие' 'стихия' 'последствие' 'среда' 'защита'] 11
# 110 ['вва' 'поб' 'белогорье' 'кло' 'апо' 'рах' 'авт' 'сме' 'вич' 'кас' 'вос'
#  'кре' 'проп' 'кра' 'инт' 'гри' 'шем' 'ета' 'пом'] 19
# 19 ['возраст' 'женщина' 'девушка' 'наставник' 'мужчина' 'лицо' 'человек'
#  'кос' 'юноша' 'девочка'] 10
# 140 ['окончание' 'назначение' 'пребывание' 'приход' 'выезд' 'ожидание'
#  'прибытие' 'вручение' 'отправление' 'возвращение' 'коронация' 'инцидент'] 12
# 136 ['юрг' 'рус' 'вручитель' 'посол' 'пан' 'воеводство' 'новгород' 'граф'
#  'лев' 'бох' 'заруб' 'князь' 'царь'] 13
# 66 ['декабрь' 'май' 'июль' 'январь' 'август' 'февраль' 'октябрь' 'июнь'
#  'март' 'апрель' 'сентябрь'] 11
# 39 ['мероприятие' 'программа' 'архитектор' 'изобретение' 'проект' 'новация'
#  'заявка' 'план' 'строительство' 'проектант' 'строитель' 'кампания'
#  'инициатор'] 13
# 51 ['правительство' 'муниципалитет' 'кандидат' 'президент' 'мандат' 'созыв'
#  'представительство' 'гражданин' 'депутат' 'республика' 'голосование'
#  'парламент' 'референдум' 'горсовет' 'избиратель' 'дума' 'ингушетия'
#  'премьер'] 18
# 73 ['катион' 'симметрия' 'строение' 'соединение' 'элемент' 'частица' 'бор'
#  'спин' 'ядро' 'светочувствительность' 'сингония' 'валентность' 'мос'
#  'античастица' 'полиамид' 'сма' 'изотоп' 'сродство' 'стереоизомер'
#  'икосаэдр' 'эманация'] 21
# 144 ['вместимость' 'судно' 'корабль' 'миль' 'водоизмещение' 'тоннаж' 'танкер'] 7
# 99 ['центр' 'деятельность' 'круг' 'субъект' 'область' 'сообщество' 'предел'
#  'оборот' 'компетенция' 'сфера' 'рамка' 'периферия'] 12
# 79 ['градус' 'температура' 'вязкость' 'плотность' 'плавление' 'светимость'
#  'давление' 'максимум' 'цельсий' 'течение' 'сжатие'] 11
# 61 ['кегль' 'алфавит' 'орфография' 'буква' 'шрифт' 'литера' 'строка'
#  'иероглиф' 'аббревиатура' 'подпись' 'латиница' 'кириллица' 'каллиграф'
#  'надпись' 'начертание' 'глаголица' 'скобка'] 17
# 113 ['громкость' 'инструмент' 'звук' 'произношение' 'каденция' 'звучание'
#  'диалог' 'тональность' 'сочетание' 'наив' 'акцент' 'мантра' 'огласовка'] 13
# 3 ['событие' 'попытка' 'основатель' 'хронология' 'история' 'психология'
#  'физиология' 'историк'] 8
# 1 ['код' 'карта' 'формат' 'расшифровка' 'нумерация' 'видеокарта' 'тос'
#  'кодировка' 'кодирование' 'байт' 'бит' 'набор' 'озу'] 13
# 109 ['фотография' 'трофей' 'музей' 'достопримечательность' 'экспонент'
#  'экспонат' 'артефакт'] 7
# 141 ['церемония' 'хозяин' 'гость' 'зал' 'кавалер' 'персона' 'кабинет' 'бал'
#  'знаменитость' 'посетитель' 'порог' 'гостиная' 'предлог'] 13
# 132 ['пантера' 'кролик' 'маг' 'крыса' 'животное' 'обезьяна' 'петух' 'леопард'] 8
# 104 ['длительность' 'объект' 'константа' 'изменение' 'частота' 'диапазон'
#  'единица' 'ксп' 'компонент' 'синхронизация' 'сдвиг' 'фаза' 'погрешность'
#  'деление' 'параметр' 'функция' 'вероятность' 'индикатор' 'соотношение'
#  'спектр' 'коэффициент' 'аппарат' 'днп' 'интервал' 'периодичность'
#  'вариация' 'зависимость' 'импульс' 'распределение' 'рэс' 'задержка'
#  'смещение' 'шкала' 'точность' 'отклонение' 'пропорциональность' 'эоп'] 37
# 117 ['вооружение' 'склад' 'патрон' 'ппш' 'рпд' 'боезапас' 'оружие' 'попадание'
#  'ппд' 'боезаряд' 'винтовка' 'пм' 'медикамент' 'боеприпас'] 14
# 80 ['восхождение' 'экспедиция' 'путешествие' 'плавание' 'кук' 'делиль'] 6
# 83 ['мфа' 'носитель' 'ед' 'мес' 'энцефалит' 'бс' 'ген' 'триба' 'алкан'
#  'подкласс' 'домен' 'компартмент' 'ингибирование' 'крс' 'тиг' 'имаго'
#  'рис' 'кз' 'нуклеотид' 'треонин' 'нер' 'нуклид' 'чувствительность'
#  'концентрация' 'ирт' 'сог' 'аст' 'метка' 'хеш' 'реципиент' 'рецептор'
#  'локализация' 'эдм' 'активность'] 34
# 50 ['арс' 'бонус' 'спонсор' 'оператор' 'поставщик' 'дистрибутор' 'контракт'
#  'топ' 'отс' 'работодатель' 'ифк' 'адр' 'хостинг' 'франшиза' 'заказчик'
#  'менеджер'] 16
# 107 ['флаг' 'знак' 'герб' 'эмблема' 'нок' 'шеврон' 'символ' 'значок' 'знамя'
#  'девиз'] 10
# 71 ['капитан' 'офицер' 'округ' 'командир' 'приказ' 'генерал' 'штаб' 'адмирал'
#  'военный' 'начальник' 'комиссар' 'коммисар' 'лво' 'ково' 'командующий'
#  'поливанов'] 16
# 57 ['вершина' 'местность' 'кратер' 'плато' 'тау' 'спуск' 'кош' 'устье' 'поле'
#  'гранит' 'пик' 'окрестность' 'река' 'север' 'лес' 'гора' 'бом' 'нор'
#  'хребет' 'бассейн' 'озеро'] 21
# 82 ['состояние' 'причина' 'травма' 'заболевание' 'болезнь' 'слабость'
#  'лекарство' 'мор' 'синдром' 'кома'] 10
# 45 ['рыба' 'деньга' 'фламинго' 'муха' 'кит' 'рыболовство' 'молоко' 'глот'
#  'шти' 'гриб' 'вино' 'улов' 'чечевица' 'яйцо'] 14
# 32 ['даза' 'хер' 'дир' 'ени' 'мас' 'рез' 'бре' 'лив' 'аджа' 'шир' 'тра' 'осм'
#  'кла' 'фак' 'зен' 'беш' 'кам' 'ата' 'ои' 'хет' 'арг' 'кай' 'мит' 'заб'
#  'чер' 'каз' 'ске' 'ард' 'ску' 'кал' 'ноо' 'диз' 'лут' 'мат'] 34
# 35 ['юпитер' 'ио' 'луна' 'диск' 'созвездие' 'звезда' 'сатурн' 'луч' 'араго'
#  'перигелий'] 10
# 70 ['посадка' 'трасса' 'пересадка' 'авиакомпания' 'офис' 'рейс' 'кабул'
#  'аэропорт' 'бангкок' 'терминал' 'впп' 'хельсинки' 'телефон' 'табло'
#  'авиалиния' 'телебашня'] 16
# 47 ['пассажир' 'платформа' 'гурт' 'станция' 'кип' 'паровоз' 'остановка'
#  'поезд' 'вагон' 'камера' 'депо'] 11
# 90 ['часть' 'начало' 'конец' 'четверть' 'остаток' 'половина'] 6
# 16 ['ро' 'кри' 'вар' 'тро' 'спо' 'кру' 'ая' 'бро'] 8
# 46 ['оля' 'кукла' 'зомби' 'фигурка' 'картинка' 'вампир'] 6
# 59 ['обновление' 'поражение' 'потеря' 'утрата' 'разрыв' 'пожар' 'разрушение'
#  'повреждение' 'оплот'] 9
# 93 ['направление' 'тема' 'цикл' 'мотив' 'тематика' 'задача' 'цель' 'охват'
#  'направленность' 'предназначение' 'суть' 'уклон'] 12
# 87 ['спр' 'глава' 'департамент' 'председатель' 'отдел' 'министр' 'заведующий'
#  'представитель' 'член' 'комитет' 'совет' 'вр' 'правление' 'мид'
#  'директор' 'бакатин' 'секретарь' 'внутр' 'бюро' 'помощник' 'деятель'
#  'комиссия'] 22
# 11 ['сессия' 'ассоциация' 'съезд' 'конгресс' 'ассамблея' 'эсперанто'
#  'конференция' 'фор' 'конфедерация' 'союз' 'ширак' 'берн' 'гардинер'
#  'секция'] 14
# 37 ['провинция' 'шеф' 'губернатор' 'сенатор' 'полиция' 'отставка' 'правитель'
#  'власть' 'ведомство' 'префектура' 'администрация' 'советник'] 12
# 103 ['житель' 'еврей' 'армянин' 'мусульманин' 'шах' 'араб' 'султан' 'вилайет'
#  'турок' 'курд' 'нахия' 'перс' 'бей'] 13
# 95 ['этнос' 'национальность' 'идеал' 'партийность' 'государство' 'народ'
#  'религия' 'нация' 'племя' 'личность' 'идеология' 'братство'
#  'вероисповедание' 'независимость' 'раса' 'свобода' 'самоназвание'
#  'самоидентификация' 'меньшинство' 'народность' 'конфессия' 'славянофил'
#  'империя'] 23
# 53 ['род' 'происхождение' 'предок' 'тысячелетие' 'память' 'поколение'
#  'потомок' 'век'] 8
# 10 ['аэростат' 'экипаж' 'борт' 'бак' 'цилиндр' 'палуба' 'гондола'] 7
# 13 ['восток' 'ареал' 'эра' 'формация' 'северовосток' 'эпоха' 'спарта' 'рим'
#  'неарктика' 'цивилизация' 'запад' 'атл' 'индуизм' 'романизация'
#  'письменность' 'культура' 'александрия'] 17
# 112 ['уход' 'выход' 'смена' 'упоминание' 'появление' 'открытие' 'пробуждение'
#  'открыватель' 'закрытие'] 9
# 115 ['рождение' 'вечер' 'праздник' 'суббота' 'воскресение' 'воскрешение'] 6
# 55 ['гагауз' 'цыган' 'мордва' 'татарин' 'грузин' 'башкир' 'аварец' 'черкес'
#  'адыгеец' 'осетин'] 10
# 139 ['квебек' 'майами' 'тройка' 'вирджиния' 'онтарио' 'эксетер' 'александер'
#  'барбара' 'виннипег' 'миннеаполис' 'амстердам' 'бостон'] 12
# 5 ['сражение' 'воин' 'орд' 'боец' 'жрец' 'раб' 'кир' 'глашатай' 'гладиатор'
#  'вождь' 'стрела' 'борец' 'осада' 'солдат'] 14
# 8 ['вещество' 'препарат' 'скрупул' 'размножение' 'доза' 'липаза' 'продукт'
#  'кислород' 'мышца' 'кислота' 'бад' 'гипертермия' 'белок' 'стабилизатор'
#  'протист' 'жир' 'фосфор' 'тмс' 'прикрепление' 'ткань' 'гистамин'
#  'минерализация' 'стимулятор'] 23
# 36 ['адрес' 'исп' 'выступление' 'резолюция' 'протокол'] 5
# 98 ['подвид' 'порода' 'посев' 'жирность' 'этикетка' 'картофель' 'ранетка'
#  'растение' 'виноград' 'сорт'] 10
# 49 ['причастие' 'канонизация' 'отец' 'епархия' 'духовенство' 'церковь'
#  'монах' 'причт' 'викарий' 'священник'] 10
# 128 ['крест' 'аббатство' 'закладка' 'храм' 'неф' 'монастырь' 'памятник' 'вход'
#  'здание' 'часовня' 'собор'] 11
# 75 ['венгр' 'эст' 'немец' 'литовец' 'украинец' 'болгарин' 'молдаванин'
#  'поляк' 'серб' 'чех' 'латыш' 'белорус'] 12
# 135 ['порт' 'флот' 'верфь' 'судоверфь' 'ангара' 'завод'] 6
# 89 ['уезд' 'сход' 'волость' 'поселение' 'старшина' 'сельсовет' 'ячейка'
#  'райцентр' 'село' 'деревня' 'вече' 'улус'] 12
# 106 ['трояк' 'отв' 'творение' 'фараон' 'обрезание' 'ад' 'любовь' 'моисей'
#  'нум' 'тит' 'тму' 'кинт' 'существо' 'бог' 'бес' 'библия' 'чт'] 17
# 12 ['выработка' 'рабочий' 'подача' 'хозяйство' 'кпр' 'кузбасс' 'обогащение'
#  'производительность'] 8
# 15 ['мотоцикл' 'трейлер'] 2
# 129 ['бол' 'южн' 'таврия' 'ниж' 'зак' 'зап' 'сал' 'кап' 'лех'] 9
# 131 ['евр' 'гал' 'сол'] 3
# 20 ['синева' 'ветер' 'инка' 'рокот' 'губа'] 5
# 88 ['дуб' 'корень' 'дерево' 'лист' 'ветвь' 'полушарие' 'кость' 'кора' 'сырь'] 9

# %%
get_metrics(embeddings_reshaped, df_cls[name])
# Out:
# {'silhouette_score': 0.025343803621024036,
#  'calinski_harabasz_index': 5.764167414303667,
#  'davies_bouldin_index': 3.1783457538898254}

# %% [markdown]
# ## Mini batch k-means
# Берется батч (срез) данных, по ним строится k-means, за счет чего быстро работает)

# %%
from sklearn.cluster import MiniBatchKMeans

name = "minibatch-kmeans"
model = MiniBatchKMeans

clustering_params = find_best_clustering_params(embeddings_reshaped, model,min_num_clusters=150, max_num_clusters=200)

print(clustering_params, end="\n\n\n")

df_cls[name] = clustering_params["best_clusters"]
cluster_dict = get_cluster_id_words(name)

print_cluster_to_word(cluster_dict)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [00:19<00:00,  2.52it/s]
# {'best_clustering_score': 5.523038984910519, 'best_num_clusters': 153, 'best_clusters': array([ 65,  24, 120, ...,  22,  82,  24], dtype=int32)}
#
#
# 65 ['алгоритм' 'сплит' 'блок' 'дст' 'идентификатор' 'кегль' 'код'
#  'обозначение' 'формат' 'информация' 'оператор' 'вис' 'сеть' 'процессор'
#  'сервер' 'расшифровка' 'нумерация' 'приставка' 'синхронизация'
#  'видеокарта' 'размерность' 'модуль' 'диск' 'аббревиатура' 'домен' 'ввод'
#  'тос' 'кодировка' 'пиктограмма' 'дисплей' 'дау' 'разбиение'
#  'спецификация' 'фокусировка' 'пользователь' 'абонент' 'память' 'пси'
#  'локация' 'байт' 'бит' 'логотип' 'набор' 'запись' 'озу' 'монтаж'
#  'линейка' 'метка' 'диаграмма' 'табло' 'хостинг' 'хеш' 'инн' 'эоп'
#  'отображение'] 55
# 24 ['чарт' 'шоу' 'номинант' 'подиум' 'лейбл' 'релиз' 'бонус' 'сингл'
#  'продюсер' 'спонсор' 'клип' 'скип' 'финалистка' 'фестиваль' 'солид'
#  'боулер' 'трек' 'топ' 'мультсериал' 'видеоклип' 'дискография' 'саундтрек'
#  'кинокомпания' 'хит' 'популярность' 'мультиплекс' 'ремикс' 'лэйбл' 'хард'
#  'телешоу' 'слоган' 'наив' 'евровидение' 'рэнди' 'ммкф' 'рок'] 36
# 120 ['титул' 'династия' 'кир' 'фараон' 'правитель' 'монарх' 'империя' 'царь'] 8
# 46 ['яванец' 'уйгур' 'миссия' 'племя' 'мусульманин' 'кабул' 'триба' 'шах'
#  'араб' 'раса' 'султан' 'айн' 'самоназвание' 'вилайет' 'курд' 'китаец'
#  'нахия' 'перс' 'улус' 'бей'] 20
# 63 ['население' 'место' 'пункт' 'район' 'микрорайон' 'регион' 'часть'
#  'дислокация' 'подрайон' 'местоположение' 'местность' 'месторасположение'
#  'территория' 'размещение' 'область' 'округ' 'зона' 'участок' 'пгт'
#  'водоснабжение' 'поселение' 'освоенность' 'край' 'орб' 'захоронение'
#  'приамурье' 'расселение' 'миграция' 'ингушетия'] 29
# 52 ['категория' 'численность' 'итог' 'показатель' 'результат' 'нагрузка'
#  'рост' 'отставание' 'период' 'рождаемость' 'таблица' 'динамика' 'прирост'
#  'рейтинг' 'уровень' 'режим' 'диапазон' 'балл' 'масштаб' 'алк'
#  'статистика' 'доля' 'единица' 'индекс' 'ксп' 'сокращение' 'предел'
#  'запас' 'полугодие' 'сдвиг' 'темп' 'посещаемость' 'смертность' 'деление'
#  'оборот' 'цск' 'субрегион' 'удлинение' 'ввп' 'минимум' 'индикатор'
#  'сальдо' 'эквивалент' 'стабилизация' 'потребление' 'коэффициент' 'суг'
#  'операция' 'охват' 'заполняемость' 'метраж' 'периодичность' 'превышение'
#  'риск' 'вклад' 'ппс' 'вариация' 'кз' 'кпр' 'баланс' 'разрыв'
#  'результативность' 'цифра' 'опрос' 'концентрация' 'распределение'
#  'задержка' 'шкала' 'сектор' 'обеспеченность' 'норма' 'перепись' 'регресс'
#  'максимум' 'мониторинг' 'отметка' 'производительность' 'течение'
#  'сложность'] 79
# 79 ['матч' 'сезон' 'соперник' 'соперница' 'команда' 'поул' 'раунд' 'тур'
#  'очко' 'игра' 'пас' 'гол' 'сет' 'зенит' 'томь' 'дубль' 'бомбардир'
#  'плейофф' 'ничья' 'рапид' 'арбитр' 'рестлер' 'ска' 'овертайм' 'блиц'
#  'тайм' 'поединок' 'пенальти' 'аут' 'суперлига' 'олимпиакос' 'бешикташ'
#  'бросок'] 33
# 16 ['партия' 'свдп' 'лидер' 'макашов' 'фракция' 'оппонент' 'президент'
#  'мандат' 'выступление' 'шанс' 'лдпр' 'депутат' 'претендент' 'анк' 'дпр'
#  'власть' 'спс' 'экс' 'меньшинство' 'элита' 'голосование' 'ширак'
#  'парламент' 'референдум' 'коалиция' 'кампания' 'избиратель' 'дума'
#  'большинство' 'премьер'] 30
# 95 ['позиция' 'направление' 'путь' 'прорыв'] 4
# 89 ['мяч' 'игрок' 'сборная' 'стадион' 'теннисист' 'тренер' 'вратарь' 'бокс'
#  'фигурист' 'футболист' 'нападающий' 'полузащитник' 'динамо' 'форвард'
#  'шайба' 'водник' 'локомотив' 'спартак' 'хоккеист' 'бутсы' 'лыжник'
#  'волейбол' 'шахматист' 'торпедо' 'баскетбол' 'баскетболист' 'цдка'] 27
# 115 ['название' 'имя' 'наименование' 'фамилия' 'прозвище'] 5
# 122 ['очки' 'цвет' 'кукла' 'окрас' 'кольцо' 'петлица' 'пояс' 'кос' 'мех'
#  'платье' 'лента' 'подбой' 'мода' 'костюм' 'ношение' 'браслет' 'шапка'] 17
# 70 ['дата' 'список' 'фио' 'документ' 'заявка' 'подпись' 'карточка' 'протокол'] 8
# 132 ['страна' 'африка' 'штат' 'квебек' 'куба' 'бангкок' 'япония' 'америка'
#  'кантон' 'рим' 'вирджиния' 'колумбия' 'океания' 'онтарио' 'эксетер'
#  'гвинея' 'виннипег' 'зеландия' 'александрия' 'нигер' 'амстердам' 'мальта'
#  'норфолк'] 23
# 151 ['кубок' 'спортсмен' 'турнир' 'победитель' 'соревнование' 'чемпион'
#  'заплыв' 'чемпионат' 'медалист' 'старт' 'финиш' 'спринт' 'спортсменка'
#  'гонка' 'обладатель' 'заезд' 'гонщик' 'дистанция' 'эстафета'
#  'конькобежец' 'велогонщик' 'забег' 'первенство' 'чемпионка' 'ралли'
#  'юниор' 'финалист' 'победительница' 'биатлонист' 'фигуристка' 'олимпиада'
#  'состязание' 'многоборье' 'лыжница' 'марафон' 'теннисистка'] 36
# 82 ['торговля' 'сертификация' 'марка' 'продажа' 'производитель'
#  'изготовитель' 'сервис' 'дистрибьютор' 'бренд' 'компания' 'агентство'
#  'фирма' 'экспорт' 'поставщик' 'лицензия' 'изделие' 'дистрибутор'
#  'сертификат' 'прокат' 'прокатчик' 'квота' 'продукт' 'продукция' 'рынок'
#  'сбыт' 'ифк' 'импорт' 'экспонент' 'поставка' 'бизнес' 'конкурент' 'заказ'
#  'франшиза' 'менеджер'] 34
# 119 ['линия' 'маршрут' 'трасса' 'автодорога' 'дорога' 'пересечение' 'полоса'
#  'магистраль'] 8
# 29 ['дисциплина' 'порядок' 'работа' 'группа' 'участник' 'мероприятие' 'строй'
#  'деятельность' 'квалификация' 'участие' 'организация' 'глава'
#  'руководитель' 'попытка' 'ассоциация' 'фонд' 'поддержка' 'объединение'
#  'представитель' 'государство' 'сообщество' 'ряд' 'представительство'
#  'нкз' 'управление' 'связь' 'членство' 'сда' 'компетенция' 'контроль'
#  'подразделение' 'отс' 'республика' 'план' 'конфедерация' 'руководство'
#  'подчинение' 'ячейка' 'союз' 'подготовка' 'организатор' 'федерация'
#  'общество' 'филиал' 'деятель' 'инициатор' 'запрос' 'звено' 'секция'] 49
# 9 ['год' 'декабрь' 'май' 'июль' 'январь' 'август' 'февраль' 'октябрь' 'июнь'
#  'март' 'апрель' 'сентябрь'] 12
# 121 ['валюта' 'номинал' 'банкнот' 'доходность' 'банк' 'адр' 'капитал'
#  'инвестор' 'эмитент' 'котировка' 'пакет'] 11
# 38 ['примечание' 'издание' 'автор' 'перевод' 'переиздание' 'синопсис' 'тираж'
#  'сборник' 'заглавие' 'стр' 'аннотация' 'заметка' 'календарь' 'издатель'
#  'хроника' 'энциклопедия' 'книга' 'рецензия' 'публикация' 'издательство'
#  'статья' 'соч' 'заголовок' 'журнал' 'редактор' 'ред' 'написание'
#  'страница' 'псевдоним'] 29
# 105 ['персонаж' 'легенда' 'версия' 'сюжет' 'зомби' 'жанр' 'сага' 'мотив'
#  'действо' 'комикс' 'жаргонизм' 'вампир'] 12
# 42 ['мон' 'ита' 'вва' 'илл' 'ро' 'поб' 'хер' 'чемп' 'фин' 'мас' 'белогорье'
#  'бре' 'бра' 'бик' 'нек' 'спа' 'тра' 'кла' 'кло' 'фак' 'гро' 'апо' 'бол'
#  'лок' 'авт' 'рош' 'глот' 'фен' 'сме' 'ои' 'сол' 'тро' 'вич' 'бад' 'спо'
#  'мор' 'кас' 'вос' 'кре' 'мос' 'кру' 'бер' 'зак' 'проп' 'мот' 'ник' 'спар'
#  'мит' 'бур' 'ске' 'вах' 'кра' 'ессентуки' 'сиб' 'аус' 'ая' 'ску' 'инт'
#  'гри' 'мад' 'ноо' 'ета' 'кап' 'лех' 'итс' 'бро' 'мат' 'су' 'пос'] 69
# 67 ['роль' 'студия' 'ведущий' 'соавтор' 'карьера' 'участница' 'телеверсия'
#  'показ' 'номинатор' 'профессия' 'амплуа' 'озвучивание' 'знаменитость'
#  'стэм' 'неудачник' 'стд' 'сценаристка'] 17
# 64 ['звание' 'должность' 'факультет' 'курс' 'класс' 'пост' 'кандидат'
#  'служба' 'колледж' 'наставник' 'университет' 'супервайзер' 'отставка'
#  'академик' 'кафедра' 'ректор' 'занятие' 'магистратура' 'школа' 'помощник'] 20
# 137 ['вид' 'значение' 'чистота' 'мера' 'предмет' 'род' 'пора' 'принадлежность'
#  'причина' 'степень' 'обстоятельство' 'особенность' 'происхождение'
#  'содержание' 'признак' 'отношение' 'черта' 'образ' 'свойство' 'слабость'
#  'характер' 'достоинство' 'последствие' 'способность' 'поведение'
#  'существо' 'случай' 'выражение'] 28
# 73 ['тип' 'эволюция' 'система' 'состав' 'объект' 'носитель' 'стадия' 'этап'
#  'форма' 'реакция' 'подгруппа' 'изменение' 'действие' 'качество' 'метод'
#  'элемент' 'компонент' 'фактор' 'фаза' 'эффект' 'параметр' 'структура'
#  'функция' 'формация' 'формирование' 'эффективность' 'соотношение' 'твд'
#  'спектр' 'контакт' 'иаэ' 'комбинация' 'вариант' 'соответствие'
#  'воздействие' 'взаимодействие' 'аналог' 'наличие' 'основа' 'кластер'
#  'зависимость' 'отбор' 'рэс' 'тмс' 'среда' 'сфера' 'совместимость'
#  'сочетание' 'локализация' 'активность'] 50
# 57 ['млн' 'процент' 'четверть' 'лат' 'тыс' 'тонна' 'среднее' 'миллион' 'фунт'
#  'галлон' 'половина' 'сотня' 'тысяча' 'литр' 'копейка'] 15
# 27 ['модель' 'серия' 'образец' 'модификация' 'ед' 'могул' 'гпз' 'бс' 'абс'
#  'техпроцесс' 'окп' 'мтз' 'рпо' 'мтд' 'пм' 'мкб' 'опп' 'комплект'
#  'комплектация'] 19
# 6 ['лек' 'лич' 'фламинго' 'кар' 'вар' 'тиг' 'рен' 'рой' 'имаго' 'фабрициус'
#  'эри' 'тихомир' 'асс' 'подпор'] 14
# 106 ['номер' 'адрес' 'офис' 'кабинет' 'телефон'] 5
# 15 ['кан' 'хай' 'пао' 'янг' 'бай' 'коу' 'дин' 'син'] 8
# 11 ['клуб' 'пар' 'пара' 'одиночка' 'посетитель' 'охотник' 'любитель'
#  'заведение'] 8
# 102 ['планета' 'юпитер' 'мир' 'созвездие' 'звезда' 'стихия' 'светимость'
#  'вселенная' 'перигелий' 'эманация'] 10
# 77 ['город' 'столица' 'провинция' 'житель' 'окрестность'
#  'достопримечательность' 'резиденция' 'пригород'] 8
# 23 ['номинация' 'награда' 'лауреат' 'премия' 'медаль' 'конкурс' 'жюри' 'приз'] 8
# 26 ['вес' 'планка' 'размер' 'вместимость' 'длина' 'величина' 'диаметр'
#  'скорость' 'ширина' 'толщина' 'нарез' 'полость' 'мм' 'ярд' 'рис'
#  'цилиндр' 'поверхность' 'куб' 'сечение' 'оболочка' 'зазор' 'сверловка'] 22
# 80 ['сценарист' 'фильм' 'дубляж' 'фильмография' 'роман' 'пролог'
#  'раскадровка' 'кино' 'сценарий' 'мультфильм' 'экранизация' 'герой'
#  'повесть' 'киностудия' 'анимация'] 15
# 0 ['срок' 'владелец' 'муниципалитет' 'получатель' 'хозяин' 'сбавка' 'долг'
#  'явка' 'контракт' 'заработок' 'гражданин' 'договор' 'рабочий'
#  'работодатель' 'медпомощь' 'учредитель' 'рсо' 'услуга' 'сделка' 'сат'
#  'мошенничество' 'продавец' 'заказчик' 'собственник' 'подрядчик'
#  'лицензиат'] 26
# 126 ['армия' 'корпус' 'фронт' 'отряд' 'дивизия' 'войско' 'дивизион' 'орд'
#  'разведка' 'боец' 'полк' 'командир' 'штаб' 'бригада' 'кав' 'гв' 'сал'
#  'эскадрон' 'артиллерия' 'лво' 'ково' 'командующий'] 22
# 21 ['расстояние' 'координата' 'тор' 'эксцентриситет' 'местонахождение'
#  'радиус' 'точка' 'кориолис' 'широта' 'наклонение' 'долгота' 'асв' 'шар'
#  'полушарие' 'сма' 'циклон' 'азимут' 'авма' 'угол'] 19
# 44 ['основание' 'пример' 'материал' 'источник' 'описание' 'вывод'
#  'характеристика' 'датировка' 'обоснование' 'определение' 'оценка'
#  'данные' 'классификация' 'представление' 'критерий' 'понятие'
#  'формулировка' 'уточнение' 'сведение' 'термин' 'физиология'
#  'переоткрытие' 'раздел' 'аргумент' 'знание' 'анализ' 'исследование'
#  'интерпретация' 'применяемость' 'доказательство'] 30
# 144 ['отель' 'рио' 'фра' 'арс' 'леклерк' 'либра' 'роб' 'кок' 'майами' 'фор'
#  'метрдотель' 'пасифик' 'олд' 'бар' 'кока' 'хельсинки' 'марсель'
#  'мажестик' 'пари' 'бох' 'чак' 'делиль' 'олимпия' 'пинта' 'берн' 'барбара'
#  'араго' 'панчо' 'миннеаполис' 'бостон'] 30
# 30 ['слалом' 'лига' 'победа' 'суперкубок' 'супергигант' 'рекорд' 'нок'
#  'брасс' 'шир' 'бундеслига' 'мальорка' 'фукуока' 'лидерство' 'автодром'
#  'индианаполис' 'фила' 'атр'] 17
# 128 ['деталь' 'двигатель' 'шасси' 'привод' 'стабилизатор' 'карбюратор'
#  'конструкция' 'трансмиссия' 'консоль' 'габарит'] 10
# 112 ['судьба' 'преследование' 'ссылка' 'судья' 'смерть' 'приговор' 'казнь'
#  'убийство' 'суд' 'участь' 'деяние' 'вор' 'наказание' 'злодей'] 14
# 76 ['способ' 'переход' 'масса' 'образование' 'использование' 'обновление'
#  'условие' 'подбор' 'выбор' 'доступность' 'передвижение' 'разнообразие'
#  'устройство' 'выработка' 'средство' 'возможность' 'распространение'
#  'введение' 'повышение' 'доступ' 'расширение' 'замена' 'прикрепление'
#  'хранение' 'разрушение' 'применение' 'обогащение' 'употребление' 'защита'
#  'преимущество'] 30
# 20 ['ратификация' 'получение' 'окончание' 'назначение' 'разрешение'
#  'исполнение' 'гражданство' 'присвоение' 'дополнение' 'обращение'
#  'открытие' 'акт' 'вступление' 'закрытие' 'принятие' 'подача' 'выдача'
#  'вручение' 'отправление' 'завершение' 'признание'] 21
# 78 ['расположение' 'состояние' 'травма' 'положение' 'повреждение'] 5
# 3 ['финал' 'полуфинал' 'четвертьфинал'] 3
# 48 ['пол' 'фигурка' 'голова' 'пот' 'лицо' 'грудь' 'тело' 'рот' 'зад' 'мышца'
#  'фигура' 'кость' 'ребро' 'жем' 'бок' 'спина' 'губа' 'хвост'] 18
# 7 ['поз' 'дуэль' 'вручитель' 'сенатор' 'посол' 'пан' 'воеводство' 'граф'
#  'лев' 'герцогиня' 'коронация' 'императрица' 'поливанов' 'князь'] 14
# 59 ['достижение' 'нтк' 'обслуживание' 'эксплуатация' 'программа' 'прогресс'
#  'база' 'стандарт' 'комплекс' 'изобретение' 'проект' 'новация'
#  'реализация' 'приоритет' 'создание' 'энергетика' 'специалист'
#  'строительство' 'ресурс' 'развитие' 'технология' 'мкк' 'техника' 'химия'
#  'экспансия'] 25
# 108 ['время' 'начало' 'уход' 'выход' 'пребывание' 'путешествие' 'приход'
#  'появление' 'выезд' 'исход' 'пробуждение' 'ожидание' 'прибытие'
#  'освобождение' 'возобновление' 'возвращение' 'поиск' 'близость' 'предлог'
#  'воскрешение'] 20
# 18 ['язык' 'транскрипция' 'транслитерация' 'префикс' 'артикль' 'дифтонг'
#  'падеж' 'склонение' 'альтернация' 'спряжение' 'произношение' 'глосса'
#  'акцентуация' 'аффриката' 'частотность' 'соссюр' 'диалект' 'фонема'
#  'просодия' 'аффикс' 'романизация' 'местоимение' 'изм' 'акцент'
#  'огласовка' 'ударение' 'скобка'] 27
# 85 ['число' 'количество' 'колич'] 3
# 55 ['пилот' 'бомбардировщик' 'штурмовка' 'вылет' 'посадка' 'аэродром'
#  'авиакомпания' 'ант' 'перехват' 'рейс' 'аэропорт' 'эскадрилья' 'впп' 'тб'
#  'истребитель' 'авиация' 'авиалиния'] 17
# 93 ['бронза' 'серебро' 'золото' 'покрытие' 'руда' 'никель' 'металл' 'монета'
#  'рубин' 'платина' 'добыча' 'газ' 'уголь' 'спирт' 'масло'] 15
# 136 ['конь' 'гурт' 'деньга' 'вол' 'трояк' 'рысачок' 'артикул' 'повозка'
#  'тройка' 'шти'] 10
# 143 ['сумма' 'кредит' 'прибыль' 'бюджет' 'стоимость' 'руб' 'расход'
#  'погашение' 'доход' 'выручка' 'списание'] 11
# 45 ['исполнитель' 'произведение' 'композитор' 'художник' 'мастер' 'творение'
#  'поэт' 'классика' 'рассказчик' 'музыкант' 'либреттист' 'драматург'
#  'мыслитель' 'переводчик' 'скульптор'] 15
# 101 ['изображение' 'фотография' 'фото' 'портрет' 'альбом' 'иллюстрация'
#  'каталог' 'оригинал' 'копия' 'скульптура' 'резьба' 'музей' 'гравюра'
#  'картинка' 'рисунок' 'картина' 'экспонат' 'репродукция'] 18
# 43 ['корзина' 'палочка' 'доска' 'кол' 'трос' 'вилка' 'шест'] 7
# 92 ['напряжение' 'громкость' 'частота' 'разряд' 'энергия' 'нейтраль' 'контур'
#  'ток' 'амп' 'эдс' 'передатчик' 'импульс' 'кабель' 'индуктивность'
#  'вольтаж' 'питание'] 16
# 36 ['режиссура' 'зритель' 'премьера' 'артист' 'театр' 'актриса' 'спектакль'
#  'танец' 'хореограф' 'либретто' 'постановка' 'сцена' 'опера' 'постановщик'
#  'солист' 'труппа' 'пьеса' 'балет' 'исполнительница' 'ария'] 20
# 139 ['персоналия' 'статус' 'смысл' 'этнос' 'атрибут' 'субъект' 'тема'
#  'партийность' 'хронология' 'грань' 'личность' 'тематика' 'авторство'
#  'идеология' 'персона' 'психология' 'индивид' 'маскулинность'
#  'самоидентификация' 'направленность' 'умолчание' 'предназначение'
#  'индуизм' 'контекст' 'рамка' 'конфессия' 'суть' 'диалог'
#  'гомосексуальность' 'ценность'] 30
# 4 ['пассажиропоток' 'транспорт' 'груз' 'перевозка' 'перевозчик' 'терминал'
#  'эксплуатант' 'грузооборот' 'расписание' 'грузопоток' 'пассажирооборот'
#  'мпс' 'икао'] 13
# 99 ['месяц' 'день' 'час' 'неделя' 'понедельник' 'суббота' 'воскресение'] 7
# 10 ['коммуна' 'национальность' 'идеал' 'община' 'народ' 'религия' 'нация'
#  'братство' 'вероисповедание' 'свобода' 'народность' 'славянофил'] 12
# 116 ['кат' 'сеп' 'дир' 'ио' 'миль' 'инд' 'ени' 'рез' 'бан' 'тау' 'аджа' 'кри'
#  'кош' 'кук' 'бел' 'зен' 'беш' 'рах' 'окс' 'мек' 'кам' 'ата' 'хаф' 'хет'
#  'тер' 'арг' 'бир' 'кер' 'атл' 'кай' 'ган' 'бом' 'нор' 'саф' 'заб' 'чер'
#  'каз' 'тенер' 'ард' 'итт' 'кал' 'диз' 'гур' 'мантра' 'лут'] 45
# 145 ['улица' 'дорожка' 'площадь' 'парк' 'склад' 'гз' 'зал' 'этажность'
#  'дворец' 'площадка' 'кип' 'этаж' 'дом' 'галерея' 'квартал' 'пожар'
#  'гостиная' 'двор' 'вход' 'здание' 'телебашня'] 21
# 146 ['брак' 'рождение' 'супруг' 'родитель' 'родственник' 'семейство'
#  'посвящение' 'отец' 'любовь' 'семья' 'супруги'] 11
# 49 ['экран' 'канал' 'сайт' 'тв' 'трансляция' 'аудитория' 'сми' 'эфир'
#  'телеканал' 'хронометраж' 'радио' 'передача' 'вещатель' 'радиостанция'
#  'видео' 'просмотр' 'квн' 'интервью' 'телезритель' 'комментатор' 'анонс'
#  'обозреватель'] 22
# 98 ['противник' 'бой' 'сражение' 'перестрелка' 'атака' 'осада'] 6
# 129 ['голос' 'песня' 'музыка' 'звук' 'струна' 'каденция' 'нота' 'фуга'
#  'звучание' 'рокот' 'аккорд' 'тональность' 'гам' 'тон'] 14
# 96 ['замечание' 'комментарий' 'слово' 'пересказ' 'чтение' 'упоминание'
#  'цитата' 'речь' 'строка' 'нотация' 'пояснение' 'ответ' 'рассказ'] 13
# 87 ['остров' 'экспедиция' 'устье' 'осм' 'заруб' 'верста' 'кеми'] 7
# 74 ['напор' 'рывок' 'реверс' 'конец' 'подкова' 'сторона' 'круг' 'минута'
#  'толчок' 'сила' 'разгон' 'крыло' 'стрела' 'момент' 'размах' 'ступень'
#  'бак' 'вал' 'колея' 'ключ' 'тяга' 'порог' 'камера' 'уклон' 'касание'
#  'движение' 'такт' 'шаг' 'связка'] 29
# 109 ['возраст' 'женщина' 'телосложение' 'мужчина' 'человек'] 5
# 40 ['юрг' 'рус' 'уезд' 'сход' 'волость' 'новгород' 'сельсовет' 'полт'
#  'райцентр' 'ниж' 'село' 'деревня' 'вече' 'вязьма'] 14
# 113 ['правительство' 'департамент' 'председатель' 'шеф' 'отдел' 'министр'
#  'заведующий' 'член' 'комитет' 'исп' 'губернатор' 'совет' 'вр' 'полиция'
#  'правление' 'мид' 'начальник' 'директор' 'комиссар' 'бакатин' 'секретарь'
#  'ведомство' 'учреждение' 'отделение' 'внутр' 'бюро' 'горсовет'
#  'администрация' 'комиссия' 'советник'] 30
# 124 ['катион' 'вещество' 'строение' 'соединение' 'частица' 'порода' 'алкан'
#  'спин' 'ядро' 'кислород' 'светочувствительность' 'сингония' 'кислота'
#  'днп' 'валентность' 'античастица' 'полиамид' 'нуклид' 'фосфор' 'минерал'
#  'слой' 'минерализация' 'изотоп' 'осадок' 'стереоизомер' 'икосаэдр'] 26
# 1 ['композиция' 'стиль' 'мозаика' 'вкус' 'расстановка'] 5
# 25 ['метр' 'километр'] 2
# 2 ['центр' 'периферия'] 2
# 50 ['орбита' 'космос' 'астероид' 'аэростат' 'запуск' 'луна' 'мкс' 'ракета'
#  'спутник' 'стыковка' 'сатурн' 'челленджер' 'астронавт' 'космодром'] 14
# 47 ['погон' 'офицер' 'чин' 'генерал' 'война' 'старшина' 'военный' 'коммисар'
#  'пом' 'солдат'] 10
# 135 ['градус' 'температура' 'вязкость' 'плотность' 'прочность' 'плавление'
#  'давление' 'осадка' 'цельсий'] 9
# 97 ['событие' 'эпизод' 'подробность' 'история' 'инцидент'] 5
# 19 ['ранг' 'флот' 'верфь' 'судоверфь' 'адмирал'] 5
# 110 ['церемония' 'выходной' 'гость' 'вечер' 'праздник' 'бал' 'каток' 'зима'
#  'катание'] 9
# 72 ['пантера' 'кролик' 'муха' 'соты' 'молоко' 'крыса' 'обезьяна' 'гнездо'
#  'петух' 'леопард' 'чечевица' 'стервятник' 'яйцо'] 13
# 91 ['карта' 'поражение' 'потеря' 'утрата' 'выигрыш' 'проигрыш'] 6
# 31 ['судно' 'капитан' 'корабль' 'штурман' 'порт' 'экипаж' 'водоизмещение'
#  'плавание' 'борт' 'эсминец' 'тоннаж' 'танкер' 'командор' 'палуба'
#  'гондола'] 15
# 131 ['длительность' 'продолжительность' 'интервал' 'последовательность'] 4
# 149 ['вооружение' 'патрон' 'трофей' 'инструмент' 'ппш' 'рпд' 'оружие' 'тир'
#  'ппд' 'шашка' 'сум' 'винтовка'] 12
# 66 ['восхождение' 'вершина' 'высота' 'плато' 'спуск' 'пик' 'гора' 'хребет'] 8
# 103 ['атлет' 'бег' 'рапира' 'трамплин' 'лазание' 'прыжок' 'гимнастка' 'арена'
#  'гладиатор' 'жим' 'акробатика' 'танцор' 'гимнаст' 'борец' 'пловец'
#  'упражнение'] 16
# 118 ['мфа' 'микрограмм' 'энцефалит' 'ген' 'размножение' 'жирность' 'подкласс'
#  'компартмент' 'липаза' 'ингибирование' 'крс' 'животное' 'белок' 'остаток'
#  'протист' 'нуклеотид' 'треонин' 'нер' 'жир' 'чувствительность' 'ирт'
#  'сог' 'ткань' 'гистамин' 'реципиент' 'рецептор'] 26
# 152 ['конструктор' 'дизайн' 'создатель' 'архитектор' 'разработчик' 'прототип'
#  'проектант' 'окб' 'дизайнер' 'строитель'] 10
# 134 ['флаг' 'знак' 'герб' 'эмблема' 'крест' 'шеврон' 'символ' 'значок' 'знамя'
#  'девиз' 'надпись'] 11
# 51 ['стрельба' 'орудие' 'танк' 'боезапас' 'дальномер' 'сау' 'мин' 'попадание'
#  'калибр' 'осколок' 'снаряд' 'боеприпас'] 12
# 71 ['рыба' 'кит' 'улов'] 3
# 33 ['пассажир' 'платформа' 'паровоз' 'остановка' 'поезд' 'вагон' 'депо'] 7
# 83 ['копь' 'кратер' 'поле' 'ангара' 'бор' 'гранит' 'земля' 'река' 'глубина'
#  'лес' 'извержение' 'клад' 'бассейн' 'сток' 'водохранилище' 'озеро'] 16
# 14 ['симметрия' 'константа' 'формула' 'множитель' 'уравнение' 'вероятность'
#  'сродство' 'пропорциональность'] 8
# 84 ['пересадка' 'посев' 'сев' 'картофель' 'ранетка' 'дуб' 'растение' 'корень'
#  'дерево' 'лист' 'гриб' 'ветвь' 'яблоко' 'цветок' 'кора' 'розетка'
#  'виноград' 'насаждение' 'сорт'] 19
# 53 ['предприятие' 'производство' 'выпуск' 'промышленность' 'нефтепереработка'
#  'отрасль' 'хозяйство' 'кузбасс' 'завод' 'автомобилестроение'] 10
# 37 ['мощность' 'энергоблок' 'топливо' 'мвт' 'аэс' 'реактор' 'боезаряд'
#  'ускоритель'] 8
# 22 ['оля' 'девушка' 'преподавательница' 'юноша' 'мисс' 'лека' 'девочка'] 7
# 150 ['шина' 'колесо' 'камаз' 'автомобиль' 'мотор' 'машина' 'механик' 'болид'
#  'мотоцикл' 'движок' 'маз' 'трейлер' 'кузов' 'зажигание' 'напарник' 'авто'] 16
# 8 ['км' 'дальность' 'кг' 'южн' 'шт' 'зап'] 6
# 100 ['сбор' 'цена' 'ставка' 'тариф' 'штраф' 'налог' 'начисление' 'плата'] 8
# 41 ['бас' 'северовосток' 'октава'] 3
# 54 ['македония' 'ирландия' 'белград' 'гдр' 'югославия' 'чехия' 'португалия'
#  'бельгия' 'латвия' 'шотландия' 'швеция' 'англия' 'норвегия'] 13
# 17 ['спр' 'буркхардт' 'брауэр' 'основатель' 'уолд' 'ория' 'клапрот'
#  'эсперанто' 'гук' 'открыватель' 'эве' 'аст' 'гильдия' 'шем' 'культура'
#  'греча' 'гардинер' 'эдм'] 18
# 75 ['сессия' 'съезд' 'созыв' 'конгресс' 'ассамблея' 'конференция' 'резолюция'] 7
# 138 ['алфавит' 'орфография' 'текст' 'буква' 'шрифт' 'литера' 'иероглиф'
#  'латиница' 'кириллица' 'каллиграф' 'письменность' 'начертание'
#  'глаголица'] 13
# 104 ['вода' 'погода' 'запах' 'синева' 'аромат' 'поток' 'ветер' 'инка' 'луч'
#  'воздух' 'сырь'] 11
# 69 ['защитник' 'воин' 'жертва' 'честь' 'жрец' 'раб' 'глашатай' 'вождь' 'маг'
#  'спарта' 'оплот'] 11
# 86 ['восток' 'север' 'запад'] 3
# 34 ['еврей' 'гагауз' 'армянин' 'цыган' 'киргиз' 'эст' 'кореец' 'мордва'
#  'украинец' 'сибиряк' 'татарин' 'грузин' 'таджик' 'молдаванин' 'башкир'
#  'казах' 'аварец' 'черкес' 'адыгеец' 'осетин' 'латыш' 'белорус'] 22
# 133 ['барьер' 'препятствие'] 2
# 148 ['подвид' 'ареал' 'неарктика'] 3
# 117 ['причастие' 'отв' 'евр' 'обрезание' 'гал' 'ад' 'моисей' 'нум' 'тит' 'тму'
#  'кинт' 'бог' 'бес' 'библия' 'чт'] 15
# 90 ['правило' 'требование' 'запрет' 'приказ' 'рекомендация' 'ограничение'
#  'инструкция' 'предупреждение'] 8
# 130 ['венгр' 'немец' 'литовец' 'болгарин' 'поляк' 'турок' 'серб' 'чех'] 8
# 5 ['механизм' 'аппарат' 'схема'] 3
# 81 ['сериал' 'телесериал'] 2
# 111 ['смена' 'цикл'] 2
# 12 ['мес' 'препарат' 'доза' 'заболевание' 'болезнь' 'лекарство' 'гипертермия'
#  'синдром' 'медикамент' 'стимулятор' 'кома'] 11
# 142 ['велоспорт' 'спорт' 'рыболовство' 'туризм' 'самбо'] 5
# 61 ['лив' 'александер'] 2
# 60 ['промах' 'погрешность' 'разница' 'разность' 'наблюдение' 'точность'
#  'отклонение'] 7
# 39 ['аббатство' 'закладка' 'канонизация' 'храм' 'неф' 'церковь' 'донатор'
#  'памятник' 'часовня' 'собор'] 10
# 127 ['кавалер' 'ром' 'вино'] 3
# 28 ['королевство' 'герцогство' 'независимость' 'владение' 'таврия'] 5
# 141 ['королева' 'альберта' 'шнайдер' 'мак'] 4
# 56 ['эра' 'предок' 'эпоха' 'тысячелетие' 'цивилизация' 'поколение' 'потомок'
#  'артефакт' 'век' 'будущее' 'историк'] 11
# 58 ['этикетка' 'маркировка'] 2
# 13 ['задание' 'задача' 'цель' 'вопрос'] 4
# 94 ['сан' 'епархия' 'духовенство' 'монастырь' 'монах' 'причт' 'викарий'
#  'священник'] 8
# 62 ['недостаток' 'отсутствие'] 2
# 114 ['смещение' 'сжатие'] 2

# %%
get_metrics(embeddings_reshaped, df_cls[name])
# Out:
# {'silhouette_score': 0.007550441738885716,
#  'calinski_harabasz_index': 5.523038984910519,
#  'davies_bouldin_index': 2.8758772495243115}

# %%
save_result = False
if save_result:
    df_cls.to_csv("df_cls.csv", sep=";", index=False)
