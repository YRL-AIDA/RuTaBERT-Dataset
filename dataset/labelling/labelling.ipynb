# %%
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

import gensim.downloader
import numpy as np

from pathlib import Path

import glob

# %% [markdown]
# # 1. Чтение лемм
#
# Дальнейшая разметка строится на предположении, что первое существительное в заголовке столбца отражает ту сущность, которая в нем содержится

# %%
df_list = []

number_of_chunks = len(glob.glob("../research/lemmatized/*.csv"))
for i in range(number_of_chunks):
    df_list.append(
        pd.read_csv(f"../research/lemmatized/lemmatized_{i}.csv", sep=";")
    )

df = pd.concat(df_list, axis=0)
df
# Out:
#                                                table_id  column_id  \
# 0        dataset/Dataset/data/7779522/table_0_meta.json          0
# 1        dataset/Dataset/data/7779522/table_0_meta.json          1
# 2       dataset/Dataset/data/2863377/table_11_meta.json          1
# 3       dataset/Dataset/data/2863377/table_11_meta.json          9
# 4        dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                 ...        ...
# 337142     dataset/Dataset/data/35185/table_5_meta.json          2
# 337143     dataset/Dataset/data/35185/table_5_meta.json          3
# 337144     dataset/Dataset/data/35185/table_5_meta.json          4
# 337145     dataset/Dataset/data/35185/table_5_meta.json          5
# 337146     dataset/Dataset/data/35185/table_5_meta.json          6
#
#           column_name
# 0                чарт
# 1       высшаяпозиция
# 2             команда
# 3                очки
# 4                 год
# ...               ...
# 337142           дата
# 337143           дата
# 337144           дата
# 337145           дата
# 337146           дата
#
# [3371478 rows x 3 columns]

# %% [markdown]
# **TODO:** use unique only in furhter labeling + join with all lemmas

# %%
unique_col_name_df = df.drop_duplicates(subset=["column_name"])
unique_col_name_df
# Out:
#                                                table_id  column_id  \
# 0        dataset/Dataset/data/7779522/table_0_meta.json          0
# 1        dataset/Dataset/data/7779522/table_0_meta.json          1
# 2       dataset/Dataset/data/2863377/table_11_meta.json          1
# 3       dataset/Dataset/data/2863377/table_11_meta.json          9
# 4        dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                 ...        ...
# 333591    dataset/Dataset/data/561562/table_2_meta.json          3
# 335746   dataset/Dataset/data/6446239/table_0_meta.json          5
# 336733    dataset/Dataset/data/956099/table_0_meta.json          0
# 336734    dataset/Dataset/data/956099/table_0_meta.json          1
# 336735    dataset/Dataset/data/956099/table_0_meta.json          2
#
#           column_name
# 0                чарт
# 1       высшаяпозиция
# 2             команда
# 3                очки
# 4                 год
# ...               ...
# 333591          подъм
# 335746          секеи
# 336733          ибаге
# 336734        невадос
# 336735          норте
#
# [15255 rows x 3 columns]

# %% [markdown]
# # 2. Чтение семантических типов
#
# Некоторые типы были изменены, т.к. состояли из > 1 слова. Так как далее работаем с word2vec, эти типы были сокращены до одного слова.

# %%
labels = set()
with open("sem_types.txt", mode="r") as f:
    for line in f:
        labels.add(line.lower().strip())

labels = list(labels)
sem_types = dict((labels[i], i) for i in range(len(labels)))
sem_types
# Out:
# {'создатель': 0,
#  'персона': 1,
#  'полицейский': 2,
#  'лингвист': 3,
#  'группа': 4,
#  'телешоу': 5,
#  'турнир': 6,
#  'плотина': 7,
#  'день': 8,
#  'идентификатор': 9,
#  'устройство': 10,
#  'остров': 11,
#  'событие': 12,
#  'элемент': 13,
#  'авиакомпания': 14,
#  'архив': 15,
#  'сингл': 16,
#  'газета': 17,
#  'период': 18,
#  'спортсмен': 19,
#  'местонахождение': 20,
#  'директор': 21,
#  'мельница': 22,
#  'телерадиокомпания': 23,
#  'дизайнер': 24,
#  'монарх': 25,
#  'памятник': 26,
#  'военная часть': 27,
#  'ресторан': 28,
#  'насекомое': 29,
#  'владелец': 30,
#  'конькобежец': 31,
#  'растение': 32,
#  'пещера': 33,
#  'сообщество': 34,
#  'казино': 35,
#  'наездник': 36,
#  'комик': 37,
#  'экономист': 38,
#  'тип': 39,
#  'болезнь': 40,
#  'самолет': 41,
#  'страна': 42,
#  'биомолекула': 43,
#  'муниципалитет': 44,
#  'демография': 45,
#  'мода': 46,
#  'скульптура': 47,
#  'борец': 48,
#  'договор': 49,
#  'музей': 50,
#  'гольфист': 51,
#  'женщина': 52,
#  'океан': 53,
#  'молл': 54,
#  'издатель': 55,
#  'шифр': 56,
#  'живопись': 57,
#  'локомотив': 58,
#  'робот': 59,
#  'роман': 60,
#  'поезд': 61,
#  'провинция': 62,
#  'описание': 63,
#  'аэропорт': 64,
#  'название': 65,
#  'корабль': 66,
#  'мотоцикл': 67,
#  'национальность': 68,
#  'фермер': 69,
#  'браузер': 70,
#  'военный': 71,
#  'примечание': 72,
#  'гитарист': 73,
#  'идеология': 74,
#  'звук': 75,
#  'работодатель': 76,
#  'фирма': 77,
#  'стандарт': 78,
#  'судья': 79,
#  'сайт': 80,
#  'документ': 81,
#  'спорт': 82,
#  'станция': 83,
#  'серфер': 84,
#  'двигатель': 85,
#  'танк': 86,
#  'танцор': 87,
#  'город': 88,
#  'атлет': 89,
#  'автомобиль': 90,
#  'отдых': 91,
#  'школа': 92,
#  'услуга': 93,
#  'модель': 94,
#  'птица': 95,
#  'драма': 96,
#  'аниме': 97,
#  'вакцина': 98,
#  'историк': 99,
#  'кинорежиссер': 100,
#  'телефон': 101,
#  'усадьба': 102,
#  'лыжник': 103,
#  'порядок': 104,
#  'структура': 105,
#  'кредит': 106,
#  'юморист': 107,
#  'здание': 108,
#  'шеф-повар': 109,
#  'ютубер': 110,
#  'гонка': 111,
#  'певец': 112,
#  'священник': 113,
#  'персонаж': 114,
#  'инструмент': 115,
#  'долина': 116,
#  'пьеса': 117,
#  'аффилиация': 118,
#  'статистика': 119,
#  'цитата': 120,
#  'техника': 121,
#  'район': 122,
#  'камера': 123,
#  'расстояние': 124,
#  'деньги': 125,
#  'бизнесмен': 126,
#  'ракета': 127,
#  'население': 128,
#  'служба': 129,
#  'обеспечение': 130,
#  'состояние': 131,
#  'парк': 132,
#  'психолог': 133,
#  'футболист': 134,
#  'алгоритм': 135,
#  'университет': 136,
#  'профсоюз': 137,
#  'сценарист': 138,
#  'фехтовальщик': 139,
#  'рефери': 140,
#  'семья': 141,
#  'монастырь': 142,
#  'театр': 143,
#  'фильм': 144,
#  'украшение': 145,
#  'юрист': 146,
#  'индустрия': 147,
#  'статус': 148,
#  'журналист': 149,
#  'префектура': 150,
#  'код': 151,
#  'канал': 152,
#  'рыба': 153,
#  'налог': 154,
#  'моряк': 155,
#  'изображение': 156,
#  'аристократ': 157,
#  'размер': 158,
#  'мечеть': 159,
#  'мемориал': 160,
#  'художник': 161,
#  'закон': 162,
#  'стадион': 163,
#  'происхождение': 164,
#  'банк': 165,
#  'ранг': 166,
#  'архитектор': 167,
#  'продолжительность': 168,
#  'туннель': 169,
#  'комикс': 170,
#  'таблица': 171,
#  'пустыня': 172,
#  'видеоигра': 173,
#  'диплом': 174,
#  'формат': 175,
#  'ввп': 176,
#  'гендер': 177,
#  'мотоциклист': 178,
#  'сад': 179,
#  'лес': 180,
#  'ведущий': 181,
#  'спортклуб': 182,
#  'писатель': 183,
#  'трек': 184,
#  'партия': 185,
#  'улица': 186,
#  'количество': 187,
#  'лига': 188,
#  'поэт': 189,
#  'файл': 190,
#  'башня': 191,
#  'кинотеатр': 192,
#  'фабрика': 193,
#  'автогонщик': 194,
#  'отель': 195,
#  'гриб': 196,
#  'шпион': 197,
#  'поэма': 198,
#  'менеджер': 199,
#  'праздник': 200,
#  'символ': 201,
#  'трамвай': 202,
#  'море': 203,
#  'порт': 204,
#  'астронавт': 205,
#  'дорога': 206,
#  'храм': 207,
#  'позиция': 208,
#  'пилот': 209,
#  'база': 210,
#  'религия': 211,
#  'флаг': 212,
#  'транспорт': 213,
#  'область': 214,
#  'пирамида': 215,
#  'батарея': 216,
#  'фотограф': 217,
#  'производитель': 218,
#  'мост': 219,
#  'резюме': 220,
#  'площадь': 221,
#  'игра': 222,
#  'животное': 223,
#  'манга': 224,
#  'сквер': 225,
#  'адрес': 226,
#  'столица': 227,
#  'больница': 228,
#  'журнал': 229,
#  'велосипедист': 230,
#  'язык': 231,
#  'пляж': 232,
#  'континент': 233,
#  'скульптор': 234,
#  'марка': 235,
#  'тренер': 236,
#  'команда': 237,
#  'пивоварня': 238,
#  'ученый': 239,
#  'электростанция': 240,
#  'кратер': 241,
#  'глубина': 242,
#  'пловец': 243,
#  'замок': 244,
#  'гитара': 245,
#  'ссылка': 246,
#  'награда': 247,
#  'вещество': 248,
#  'ипподром': 249,
#  'клуб': 250,
#  'маяк': 251,
#  'медицина': 252,
#  'река': 253,
#  'археолог': 254,
#  'политик': 255,
#  'бодибилдер': 256,
#  'вокзал': 257,
#  'баскетболист': 258,
#  'волейболист': 259,
#  'церковь': 260,
#  'высота': 261,
#  'коллекция': 262,
#  'озеро': 263,
#  'организация': 264,
#  'шахматист': 265,
#  'египтолог': 266,
#  'преступник': 267,
#  'зоопарк': 268,
#  'продюсер': 269,
#  'альбом': 270,
#  'классификация': 271,
#  'распродажа': 272,
#  'мультфильм': 273,
#  'компания': 274,
#  'теннисист': 275,
#  'книга': 276,
#  'фигурист': 277,
#  'требование': 278,
#  'арена': 279,
#  'аннотация': 280,
#  'отношение': 281,
#  'территория': 282,
#  'цвет': 283,
#  'гимнаст': 284,
#  'опера': 285,
#  'письмо': 286,
#  'мастер': 287,
#  'категория': 288,
#  'форд': 289,
#  'вулкан': 290,
#  'библиотека': 291,
#  'боксер': 292,
#  'литература': 293,
#  'актер': 294,
#  'ледник': 295,
#  'оператор': 296,
#  'бейсболист': 297,
#  'компонент': 298,
#  'премия': 299,
#  'академик': 300,
#  'мужчина': 301,
#  'мыс': 302,
#  'тюрьма': 303,
#  'бог': 304,
#  'инфраструктура': 305,
#  'программа': 306,
#  'пол': 307,
#  'место': 308,
#  'лейбл': 309,
#  'разновидность': 310,
#  'дата': 311,
#  'результат': 312,
#  'минерал': 313,
#  'класс': 314,
#  'синагога': 315,
#  'партнер': 316,
#  'правительство': 317,
#  'продукт': 318,
#  'работа': 319,
#  'гора': 320,
#  'деревня': 321,
#  'сми': 322,
#  'инженер': 323,
#  'проект': 324,
#  'философ': 325,
#  'биатлонист': 326,
#  'статья': 327,
#  'год': 328,
#  'возраст': 329,
#  'вес': 330,
#  'парламент': 331,
#  'образование': 332,
#  'агломерация': 333,
#  'песня': 334,
#  'еда': 335,
#  'жанр': 336,
#  'колледж': 337,
#  'протокол': 338}

# %% [markdown]
# # 3. Разметка
#
# Каждому заголовку сопоставляется наиболее близкий семантический тип (метрика cosine similarity)

# %%
ru_model = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def get_most_similar(word: str) -> str|None:
    """Need to split afterwards because returns (label cos.sim.value)
    """

    max_similarity = 0
    max_similar_label = None
    
    try:
        ru_model.__getitem__([f"{word}_NOUN"])[0]
    except KeyError:
        return f"{max_similar_label} {max_similarity}"

    for label in sem_types.keys():
        try:
            similarity = ru_model.similarity(f"{label}_NOUN", f"{word}_NOUN")
        except KeyError:
            continue

        if similarity > max_similarity:
            max_similarity = similarity
            max_similar_label = label

    return f"{max_similar_label} {max_similarity}"

# %%
if not Path("./labelled/labelled.csv").exists():
    df_list = []
    for i in range(number_of_chunks):
        df_list.append(
            pd.read_csv(f"./lemmatized/lemma_{i}.csv", sep=";", on_bad_lines="warn")
        )
    df = pd.concat(df_list, axis=0)

    # df = df.sample(frac=0.001)
    
    df["label"] = df["column_name"].progress_apply(get_most_similar)
    df.to_csv("./labelled/labelled.csv", sep=";", index=False)
else:
    df = pd.read_csv("./labelled/labelled.csv", sep=";")

df
# Out:
#                                                 table_id  column_id  \
# 0         dataset/Dataset/data/7779522/table_0_meta.json          0
# 1         dataset/Dataset/data/7779522/table_0_meta.json          1
# 2        dataset/Dataset/data/2863377/table_11_meta.json          1
# 3        dataset/Dataset/data/2863377/table_11_meta.json          9
# 4         dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                  ...        ...
# 3371473     dataset/Dataset/data/35185/table_5_meta.json          2
# 3371474     dataset/Dataset/data/35185/table_5_meta.json          3
# 3371475     dataset/Dataset/data/35185/table_5_meta.json          4
# 3371476     dataset/Dataset/data/35185/table_5_meta.json          5
# 3371477     dataset/Dataset/data/35185/table_5_meta.json          6
#
#            column_name                           label
# 0                 чарт        сингл 0.5395997762680054
# 1        высшаяпозиция                          None 0
# 2              команда      команда 1.0000001192092896
# 3                 очки  мотоциклист 0.3064345717430115
# 4                  год          год 0.9999999403953552
# ...                ...                             ...
# 3371473           дата                        дата 1.0
# 3371474           дата                        дата 1.0
# 3371475           дата                        дата 1.0
# 3371476           дата                        дата 1.0
# 3371477           дата                        дата 1.0
#
# [3371478 rows x 4 columns]

# %%
df[["label", "similarity"]] = df["label"].str.strip().str.split(" ", n=1, expand=True)
df
# Out:
#                                                 table_id  column_id  \
# 0         dataset/Dataset/data/7779522/table_0_meta.json          0
# 1         dataset/Dataset/data/7779522/table_0_meta.json          1
# 2        dataset/Dataset/data/2863377/table_11_meta.json          1
# 3        dataset/Dataset/data/2863377/table_11_meta.json          9
# 4         dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                  ...        ...
# 3371473     dataset/Dataset/data/35185/table_5_meta.json          2
# 3371474     dataset/Dataset/data/35185/table_5_meta.json          3
# 3371475     dataset/Dataset/data/35185/table_5_meta.json          4
# 3371476     dataset/Dataset/data/35185/table_5_meta.json          5
# 3371477     dataset/Dataset/data/35185/table_5_meta.json          6
#
#            column_name        label          similarity
# 0                 чарт        сингл  0.5395997762680054
# 1        высшаяпозиция         None                   0
# 2              команда      команда  1.0000001192092896
# 3                 очки  мотоциклист  0.3064345717430115
# 4                  год          год  0.9999999403953552
# ...                ...          ...                 ...
# 3371473           дата         дата                 1.0
# 3371474           дата         дата                 1.0
# 3371475           дата         дата                 1.0
# 3371476           дата         дата                 1.0
# 3371477           дата         дата                 1.0
#
# [3371478 rows x 5 columns]

# %%
df["table_id"] = df["table_id"].str.strip().str.split("_meta.json", n=1, expand=True)[0]
df
# Out:
#                                       table_id  column_id    column_name  \
# 0         dataset/Dataset/data/7779522/table_0          0           чарт
# 1         dataset/Dataset/data/7779522/table_0          1  высшаяпозиция
# 2        dataset/Dataset/data/2863377/table_11          1        команда
# 3        dataset/Dataset/data/2863377/table_11          9           очки
# 4         dataset/Dataset/data/4727026/table_0          0            год
# ...                                        ...        ...            ...
# 3371473     dataset/Dataset/data/35185/table_5          2           дата
# 3371474     dataset/Dataset/data/35185/table_5          3           дата
# 3371475     dataset/Dataset/data/35185/table_5          4           дата
# 3371476     dataset/Dataset/data/35185/table_5          5           дата
# 3371477     dataset/Dataset/data/35185/table_5          6           дата
#
#                label          similarity
# 0              сингл  0.5395997762680054
# 1               None                   0
# 2            команда  1.0000001192092896
# 3        мотоциклист  0.3064345717430115
# 4                год  0.9999999403953552
# ...              ...                 ...
# 3371473         дата                 1.0
# 3371474         дата                 1.0
# 3371475         дата                 1.0
# 3371476         дата                 1.0
# 3371477         дата                 1.0
#
# [3371478 rows x 5 columns]

# %% [markdown]
# ## Выбор порогового значения
#
# |порог|кол-во заголовков, схожесть >= порог|
# |-----|------------------------------------|
# |0.1|2.993.652|
# |0.2|2.993.550|
# |0.3|2.968.070|
# |0.4|2.754.081|
# |0.5|2.186.338|
# |0.6|1.659.870|
# |0.7|1.505.095|
# |0.8|1.435.068|
# |0.9|1.427.649|
# |1.0|901.335|
#
# P.s. Значения >= 1.0 за счет погрешности чисел с палвающей точкой

# %%
for i in range(1, 10+1):
    sim = (df["similarity"].apply(float) >= i / 10).sum()
    print(f"{i / 10} : {sim}")
# Out:
# 0.1 : 2993652
# 0.2 : 2993550
# 0.3 : 2968070
# 0.4 : 2754081
# 0.5 : 2186338
# 0.6 : 1659870
# 0.7 : 1505095
# 0.8 : 1435068
# 0.9 : 1427649
# 1.0 : 901335

# %%
threshold = 0.78

df_threshold = df[df["similarity"].astype(float) > threshold]
df_threshold.sort_values("similarity").head(10)
# Out:
#                                       table_id  column_id column_name  \
# 3354967   dataset/Dataset/data/8757853/table_0          0   мыслитель
# 605035    dataset/Dataset/data/7846870/table_0          0   мыслитель
# 819200    dataset/Dataset/data/7847449/table_0          0   мыслитель
# 3163977    dataset/Dataset/data/628974/table_1          3       мотор
# 2640380  dataset/Dataset/data/3727914/table_16          3       мотор
# 2919969   dataset/Dataset/data/4273768/table_4          2       мотор
# 1413735    dataset/Dataset/data/760709/table_7          2       мотор
# 2108365  dataset/Dataset/data/3620310/table_11          3       мотор
# 2356856  dataset/Dataset/data/2377385/table_12          3       мотор
# 330778     dataset/Dataset/data/973893/table_3          2       мотор
#
#              label          similarity
# 3354967    философ  0.7839148044586182
# 605035     философ  0.7839148044586182
# 819200     философ  0.7839148044586182
# 3163977  двигатель  0.7861505150794983
# 2640380  двигатель  0.7861505150794983
# 2919969  двигатель  0.7861505150794983
# 1413735  двигатель  0.7861505150794983
# 2108365  двигатель  0.7861505150794983
# 2356856  двигатель  0.7861505150794983
# 330778   двигатель  0.7861505150794983

# %%
df_threshold["label"].value_counts()[:20]
# Out:
# label
# год           253209
# название      189156
# место         116915
# дата          107649
# команда        82552
# примечание     61667
# результат      58263
# страна         42397
# турнир         36697
# клуб           24815
# город          23303
# категория      20853
# пол            20066
# население      19691
# награда        19402
# тип            18548
# позиция        17792
# спортсмен      17731
# описание       15168
# вес            13509
# Name: count, dtype: int64

# %%
df_threshold.sort_values("table_id", inplace=True)
df_threshold
# Out:
# /tmp/ipykernel_17741/420617415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_threshold.sort_values("table_id", inplace=True)
#                                      table_id  column_id column_name  \
# 334870   dataset/Dataset/data/1000006/table_0          4  примечание
# 334867   dataset/Dataset/data/1000006/table_0          1   спектакль
# 334866   dataset/Dataset/data/1000006/table_0          0       театр
# 1459759  dataset/Dataset/data/1000006/table_1          2    название
# 1459758  dataset/Dataset/data/1000006/table_1          0         год
# ...                                       ...        ...         ...
# 1252677   dataset/Dataset/data/999987/table_0          7       место
# 1252673   dataset/Dataset/data/999987/table_0          0         год
# 1252676   dataset/Dataset/data/999987/table_0          6   результат
# 1252674   dataset/Dataset/data/999987/table_0          1       город
# 1252675   dataset/Dataset/data/999987/table_0          2      турнир
#
#               label          similarity
# 334870   примечание  1.0000001192092896
# 334867        пьеса  0.7898139357566833
# 334866        театр                 1.0
# 1459759    название                 1.0
# 1459758         год  0.9999999403953552
# ...             ...                 ...
# 1252677       место  0.9999999403953552
# 1252673         год  0.9999999403953552
# 1252676   результат                 1.0
# 1252674       город  1.0000001192092896
# 1252675      турнир                 1.0
#
# [1449019 rows x 5 columns]

# %%
df_threshold.to_csv(f"./labelled/labelled_threshold_{threshold}.csv", sep=";", index=False)
