# %%
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

import gensim.downloader
import numpy as np

from pathlib import Path

import glob

# %% [markdown]
# # 1. Чтение лемм
#
# Дальнейшая разметка строится на предположении, что первое существительное в заголовке столбца отражает ту сущность, которая в нем содержится

# %%
df = pd.read_csv("../research/lemmatized/data.csv", sep=";")
df
# Out:
#                                      table_id  column_id column_name_lemma
# 0        dataset/Dataset/data/7779522/table_0          0              чарт
# 1        dataset/Dataset/data/1888657/table_1          2              чарт
# 2        dataset/Dataset/data/6223308/table_0          0              чарт
# 3        dataset/Dataset/data/4293840/table_0          0              чарт
# 4        dataset/Dataset/data/8245389/table_1          0              чарт
# ...                                       ...        ...               ...
# 3222710  dataset/Dataset/data/3660091/table_2          2           команда
# 3222711  dataset/Dataset/data/3660091/table_2          3           команда
# 3222712  dataset/Dataset/data/4212949/table_0          2             объем
# 3222713  dataset/Dataset/data/7525778/table_0          1             время
# 3222714  dataset/Dataset/data/7525778/table_0          4            альбом
#
# [3222715 rows x 3 columns]

# %% [markdown]
# # **TODO:** use unique only in furhter labeling + join with all lemmas

# %%
unique_lemmas = pd.DataFrame()
unique_lemmas["column_name_lemma"] = pd.Series(df["column_name_lemma"].unique())
unique_lemmas
# Out:
#       column_name_lemma
# 0                  чарт
# 1         высшаяпозиция
# 2                   год
# 3              название
# 4                  роль
# ...                 ...
# 13013             банрк
# 13014           субклад
# 13015              лагг
# 13016            ацетон
# 13017       сероуглерод
#
# [13018 rows x 1 columns]

# %% [markdown]
# # 2. Чтение семантических типов
#
# Некоторые типы были изменены, т.к. состояли из > 1 слова. Так как далее работаем с word2vec, эти типы были сокращены до одного слова.

# %%
labels = set()
with open("sem_types.txt", mode="r") as f:
    for line in f:
        if len(line.split(' ')) > 1:
            continue
        labels.add(line.lower().strip())

labels = list(labels)
labels.remove("мужчина")
labels.remove("женщина")
labels.remove("таблица")
labels.sort()

sem_types = dict((labels[i], i) for i in range(len(labels)))
sem_types
# Out:
# {'авиакомпания': 0,
#  'автогонщик': 1,
#  'автомобиль': 2,
#  'агломерация': 3,
#  'адрес': 4,
#  'академик': 5,
#  'актер': 6,
#  'алгоритм': 7,
#  'альбом': 8,
#  'аниме': 9,
#  'аннотация': 10,
#  'арена': 11,
#  'аристократ': 12,
#  'археолог': 13,
#  'архив': 14,
#  'архитектор': 15,
#  'астронавт': 16,
#  'атлет': 17,
#  'аффилиация': 18,
#  'аэропорт': 19,
#  'база': 20,
#  'банк': 21,
#  'баскетболист': 22,
#  'батарея': 23,
#  'башня': 24,
#  'бейсболист': 25,
#  'биатлонист': 26,
#  'библиотека': 27,
#  'бизнесмен': 28,
#  'биомолекула': 29,
#  'бог': 30,
#  'бодибилдер': 31,
#  'боксер': 32,
#  'болезнь': 33,
#  'больница': 34,
#  'борец': 35,
#  'браузер': 36,
#  'вакцина': 37,
#  'ввп': 38,
#  'ведущий': 39,
#  'велосипедист': 40,
#  'вес': 41,
#  'вещество': 42,
#  'видеоигра': 43,
#  'владелец': 44,
#  'военный': 45,
#  'возраст': 46,
#  'вокзал': 47,
#  'волейболист': 48,
#  'вулкан': 49,
#  'высота': 50,
#  'газета': 51,
#  'гендер': 52,
#  'гимнаст': 53,
#  'гитара': 54,
#  'гитарист': 55,
#  'глубина': 56,
#  'год': 57,
#  'гольфист': 58,
#  'гонка': 59,
#  'гора': 60,
#  'город': 61,
#  'гриб': 62,
#  'группа': 63,
#  'дата': 64,
#  'двигатель': 65,
#  'демография': 66,
#  'день': 67,
#  'деньги': 68,
#  'деревня': 69,
#  'дизайнер': 70,
#  'диплом': 71,
#  'директор': 72,
#  'договор': 73,
#  'документ': 74,
#  'долина': 75,
#  'дорога': 76,
#  'драма': 77,
#  'египтолог': 78,
#  'еда': 79,
#  'жанр': 80,
#  'живопись': 81,
#  'животное': 82,
#  'журнал': 83,
#  'журналист': 84,
#  'закон': 85,
#  'замок': 86,
#  'звук': 87,
#  'здание': 88,
#  'зоопарк': 89,
#  'игра': 90,
#  'идентификатор': 91,
#  'идеология': 92,
#  'издатель': 93,
#  'изображение': 94,
#  'индустрия': 95,
#  'инженер': 96,
#  'инструмент': 97,
#  'инфраструктура': 98,
#  'ипподром': 99,
#  'историк': 100,
#  'казино': 101,
#  'камера': 102,
#  'канал': 103,
#  'категория': 104,
#  'кинорежиссер': 105,
#  'кинотеатр': 106,
#  'класс': 107,
#  'классификация': 108,
#  'клуб': 109,
#  'книга': 110,
#  'код': 111,
#  'количество': 112,
#  'колледж': 113,
#  'коллекция': 114,
#  'команда': 115,
#  'комик': 116,
#  'комикс': 117,
#  'компания': 118,
#  'компонент': 119,
#  'континент': 120,
#  'конькобежец': 121,
#  'корабль': 122,
#  'кратер': 123,
#  'кредит': 124,
#  'ледник': 125,
#  'лейбл': 126,
#  'лес': 127,
#  'лига': 128,
#  'лингвист': 129,
#  'литература': 130,
#  'локомотив': 131,
#  'лыжник': 132,
#  'манга': 133,
#  'марка': 134,
#  'мастер': 135,
#  'маяк': 136,
#  'медицина': 137,
#  'мельница': 138,
#  'мемориал': 139,
#  'менеджер': 140,
#  'место': 141,
#  'местонахождение': 142,
#  'мечеть': 143,
#  'минерал': 144,
#  'мода': 145,
#  'модель': 146,
#  'молл': 147,
#  'монарх': 148,
#  'монастырь': 149,
#  'море': 150,
#  'моряк': 151,
#  'мост': 152,
#  'мотоцикл': 153,
#  'мотоциклист': 154,
#  'музей': 155,
#  'мультфильм': 156,
#  'муниципалитет': 157,
#  'мыс': 158,
#  'награда': 159,
#  'наездник': 160,
#  'название': 161,
#  'налог': 162,
#  'насекомое': 163,
#  'население': 164,
#  'национальность': 165,
#  'обеспечение': 166,
#  'область': 167,
#  'образование': 168,
#  'озеро': 169,
#  'океан': 170,
#  'опера': 171,
#  'оператор': 172,
#  'описание': 173,
#  'организация': 174,
#  'остров': 175,
#  'отдых': 176,
#  'отель': 177,
#  'отношение': 178,
#  'памятник': 179,
#  'парк': 180,
#  'парламент': 181,
#  'партия': 182,
#  'партнер': 183,
#  'певец': 184,
#  'период': 185,
#  'персона': 186,
#  'персонаж': 187,
#  'песня': 188,
#  'пещера': 189,
#  'пивоварня': 190,
#  'пилот': 191,
#  'пирамида': 192,
#  'писатель': 193,
#  'письмо': 194,
#  'пловец': 195,
#  'плотина': 196,
#  'площадь': 197,
#  'пляж': 198,
#  'поезд': 199,
#  'позиция': 200,
#  'пол': 201,
#  'политик': 202,
#  'полицейский': 203,
#  'порт': 204,
#  'порядок': 205,
#  'поэма': 206,
#  'поэт': 207,
#  'правительство': 208,
#  'праздник': 209,
#  'премия': 210,
#  'преступник': 211,
#  'префектура': 212,
#  'примечание': 213,
#  'провинция': 214,
#  'программа': 215,
#  'продолжительность': 216,
#  'продукт': 217,
#  'продюсер': 218,
#  'проект': 219,
#  'производитель': 220,
#  'происхождение': 221,
#  'протокол': 222,
#  'профсоюз': 223,
#  'психолог': 224,
#  'птица': 225,
#  'пустыня': 226,
#  'пьеса': 227,
#  'работа': 228,
#  'работодатель': 229,
#  'размер': 230,
#  'разновидность': 231,
#  'район': 232,
#  'ракета': 233,
#  'ранг': 234,
#  'распродажа': 235,
#  'расстояние': 236,
#  'растение': 237,
#  'результат': 238,
#  'резюме': 239,
#  'река': 240,
#  'религия': 241,
#  'ресторан': 242,
#  'рефери': 243,
#  'робот': 244,
#  'роман': 245,
#  'рыба': 246,
#  'сад': 247,
#  'сайт': 248,
#  'самолет': 249,
#  'священник': 250,
#  'семья': 251,
#  'серфер': 252,
#  'символ': 253,
#  'синагога': 254,
#  'сингл': 255,
#  'сквер': 256,
#  'скульптор': 257,
#  'скульптура': 258,
#  'служба': 259,
#  'сми': 260,
#  'событие': 261,
#  'создатель': 262,
#  'сообщество': 263,
#  'состояние': 264,
#  'спорт': 265,
#  'спортклуб': 266,
#  'спортсмен': 267,
#  'ссылка': 268,
#  'стадион': 269,
#  'стандарт': 270,
#  'станция': 271,
#  'статистика': 272,
#  'статус': 273,
#  'статья': 274,
#  'столица': 275,
#  'страна': 276,
#  'структура': 277,
#  'судья': 278,
#  'сценарист': 279,
#  'танк': 280,
#  'танцор': 281,
#  'театр': 282,
#  'телерадиокомпания': 283,
#  'телефон': 284,
#  'телешоу': 285,
#  'теннисист': 286,
#  'территория': 287,
#  'техника': 288,
#  'тип': 289,
#  'трамвай': 290,
#  'транспорт': 291,
#  'требование': 292,
#  'трек': 293,
#  'тренер': 294,
#  'туннель': 295,
#  'турнир': 296,
#  'тюрьма': 297,
#  'украшение': 298,
#  'улица': 299,
#  'университет': 300,
#  'усадьба': 301,
#  'услуга': 302,
#  'устройство': 303,
#  'ученый': 304,
#  'фабрика': 305,
#  'файл': 306,
#  'фермер': 307,
#  'фехтовальщик': 308,
#  'фигурист': 309,
#  'философ': 310,
#  'фильм': 311,
#  'фирма': 312,
#  'флаг': 313,
#  'форд': 314,
#  'формат': 315,
#  'фотограф': 316,
#  'футболист': 317,
#  'храм': 318,
#  'художник': 319,
#  'цвет': 320,
#  'церковь': 321,
#  'цитата': 322,
#  'шахматист': 323,
#  'шеф-повар': 324,
#  'шифр': 325,
#  'школа': 326,
#  'шпион': 327,
#  'экономист': 328,
#  'электростанция': 329,
#  'элемент': 330,
#  'юморист': 331,
#  'юрист': 332,
#  'ютубер': 333,
#  'язык': 334}

# %% [markdown]
# # 3. Разметка
#
# Каждому заголовку сопоставляется наиболее близкий семантический тип (метрика cosine similarity)

# %%
ru_model = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def get_most_similar(word: str) -> str|None:
    """Need to split afterwards because returns (label cos.sim.value)
    """

    max_similarity = 0
    max_similar_label = None
    
    try:
        ru_model.__getitem__([f"{word}_NOUN"])[0]
    except KeyError:
        return f"{max_similar_label} {max_similarity}"

    for label in sem_types.keys():
        try:
            similarity = ru_model.similarity(f"{label}_NOUN", f"{word}_NOUN")
        except KeyError:
            continue

        if similarity > max_similarity:
            max_similarity = similarity
            max_similar_label = label

    return f"{max_similar_label} {max_similarity}"

# %%
unique_lemmas["label"] = unique_lemmas["column_name_lemma"].progress_apply(lambda x: get_most_similar(x))
unique_lemmas
# Out:
# 100%|████████████████████████████████████| 13018/13018 [00:17<00:00, 748.06it/s]
#       column_name_lemma                        label
# 0                  чарт     сингл 0.5395997762680054
# 1         высшаяпозиция                       None 0
# 2                   год       год 0.9999999403953552
# 3              название                 название 1.0
# 4                  роль    актер 0.45205363631248474
# ...                 ...                          ...
# 13013             банрк                       None 0
# 13014           субклад                       None 0
# 13015              лагг                       None 0
# 13016            ацетон  вещество 0.5003224015235901
# 13017       сероуглерод  вещество 0.5720729827880859
#
# [13018 rows x 2 columns]

# %%
df = df.merge(unique_lemmas, how="left")
df
# Out:
#                                      table_id  column_id column_name_lemma  \
# 0        dataset/Dataset/data/7779522/table_0          0              чарт
# 1        dataset/Dataset/data/1888657/table_1          2              чарт
# 2        dataset/Dataset/data/6223308/table_0          0              чарт
# 3        dataset/Dataset/data/4293840/table_0          0              чарт
# 4        dataset/Dataset/data/8245389/table_1          0              чарт
# ...                                       ...        ...               ...
# 3222710  dataset/Dataset/data/3660091/table_2          2           команда
# 3222711  dataset/Dataset/data/3660091/table_2          3           команда
# 3222712  dataset/Dataset/data/4212949/table_0          2             объем
# 3222713  dataset/Dataset/data/7525778/table_0          1             время
# 3222714  dataset/Dataset/data/7525778/table_0          4            альбом
#
#                                  label
# 0             сингл 0.5395997762680054
# 1             сингл 0.5395997762680054
# 2             сингл 0.5395997762680054
# 3             сингл 0.5395997762680054
# 4             сингл 0.5395997762680054
# ...                                ...
# 3222710     команда 1.0000001192092896
# 3222711     команда 1.0000001192092896
# 3222712  количество 0.5559502840042114
# 3222713      период 0.4943215847015381
# 3222714                     альбом 1.0
#
# [3222715 rows x 4 columns]

# %%
df[["label", "similarity"]] = df["label"].str.strip().str.split(" ", n=1, expand=True)
df
# Out:
#                                      table_id  column_id column_name_lemma  \
# 0        dataset/Dataset/data/7779522/table_0          0              чарт
# 1        dataset/Dataset/data/1888657/table_1          2              чарт
# 2        dataset/Dataset/data/6223308/table_0          0              чарт
# 3        dataset/Dataset/data/4293840/table_0          0              чарт
# 4        dataset/Dataset/data/8245389/table_1          0              чарт
# ...                                       ...        ...               ...
# 3222710  dataset/Dataset/data/3660091/table_2          2           команда
# 3222711  dataset/Dataset/data/3660091/table_2          3           команда
# 3222712  dataset/Dataset/data/4212949/table_0          2             объем
# 3222713  dataset/Dataset/data/7525778/table_0          1             время
# 3222714  dataset/Dataset/data/7525778/table_0          4            альбом
#
#               label          similarity
# 0             сингл  0.5395997762680054
# 1             сингл  0.5395997762680054
# 2             сингл  0.5395997762680054
# 3             сингл  0.5395997762680054
# 4             сингл  0.5395997762680054
# ...             ...                 ...
# 3222710     команда  1.0000001192092896
# 3222711     команда  1.0000001192092896
# 3222712  количество  0.5559502840042114
# 3222713      период  0.4943215847015381
# 3222714      альбом                 1.0
#
# [3222715 rows x 5 columns]

# %%
empty_label_mask = (df["label"] == "None")
df[empty_label_mask]
# Out:
#                                      table_id  column_id column_name_lemma  \
# 18702    dataset/Dataset/data/7779522/table_0          1     высшаяпозиция
# 18703    dataset/Dataset/data/4293840/table_0          1     высшаяпозиция
# 18704    dataset/Dataset/data/3215234/table_1          1     высшаяпозиция
# 18705     dataset/Dataset/data/962150/table_0          1     высшаяпозиция
# 18706    dataset/Dataset/data/6904957/table_1          1     высшаяпозиция
# ...                                       ...        ...               ...
# 3222672  dataset/Dataset/data/1103808/table_1          6          фрегезии
# 3222673  dataset/Dataset/data/7008878/table_0          0             банрк
# 3222678  dataset/Dataset/data/4685610/table_0          3           субклад
# 3222698  dataset/Dataset/data/5273033/table_3          3              лагг
# 3222706  dataset/Dataset/data/1741211/table_1          2              вице
#
#         label similarity
# 18702    None          0
# 18703    None          0
# 18704    None          0
# 18705    None          0
# 18706    None          0
# ...       ...        ...
# 3222672  None          0
# 3222673  None          0
# 3222678  None          0
# 3222698  None          0
# 3222706  None          0
#
# [96381 rows x 5 columns]

# %%
df = df[~empty_label_mask]
df
# Out:
#                                      table_id  column_id column_name_lemma  \
# 0        dataset/Dataset/data/7779522/table_0          0              чарт
# 1        dataset/Dataset/data/1888657/table_1          2              чарт
# 2        dataset/Dataset/data/6223308/table_0          0              чарт
# 3        dataset/Dataset/data/4293840/table_0          0              чарт
# 4        dataset/Dataset/data/8245389/table_1          0              чарт
# ...                                       ...        ...               ...
# 3222710  dataset/Dataset/data/3660091/table_2          2           команда
# 3222711  dataset/Dataset/data/3660091/table_2          3           команда
# 3222712  dataset/Dataset/data/4212949/table_0          2             объем
# 3222713  dataset/Dataset/data/7525778/table_0          1             время
# 3222714  dataset/Dataset/data/7525778/table_0          4            альбом
#
#               label          similarity
# 0             сингл  0.5395997762680054
# 1             сингл  0.5395997762680054
# 2             сингл  0.5395997762680054
# 3             сингл  0.5395997762680054
# 4             сингл  0.5395997762680054
# ...             ...                 ...
# 3222710     команда  1.0000001192092896
# 3222711     команда  1.0000001192092896
# 3222712  количество  0.5559502840042114
# 3222713      период  0.4943215847015381
# 3222714      альбом                 1.0
#
# [3126334 rows x 5 columns]

# %% [markdown]
# ## Выбор порогового значения
#
# |порог|кол-во заголовков, схожесть >= порог|
# |-----|------------------------------------|
# |0.1|2.993.652|
# |0.2|2.993.550|
# |0.3|2.968.070|
# |0.4|2.754.081|
# |0.5|2.186.338|
# |0.6|1.659.870|
# |0.7|1.505.095|
# |0.8|1.435.068|
# |0.9|1.427.649|
# |1.0|901.335|
#
# P.s. Значения >= 1.0 за счет погрешности чисел с палвающей точкой

# %%
for i in range(1, 10+1):
    sim = (df["similarity"].apply(float) >= i / 10).sum()
    print(f"{i / 10} : {sim}")
# Out:
# 0.1 : 3126334
# 0.2 : 3126232
# 0.3 : 3097159
# 0.4 : 2872031
# 0.5 : 2262380
# 0.6 : 1725406
# 0.7 : 1566161
# 0.8 : 1475735
# 0.9 : 1468204
# 1.0 : 940120

# %%
threshold = 0.78

df_threshold = df[df["similarity"].astype(float) > threshold]
df_threshold.sort_values("similarity")
# Out:
#                                      table_id  column_id column_name_lemma  \
# 3133886  dataset/Dataset/data/7847449/table_0          0         мыслитель
# 3133884  dataset/Dataset/data/7846870/table_0          0         мыслитель
# 3133885  dataset/Dataset/data/8757853/table_0          0         мыслитель
# 2139300  dataset/Dataset/data/3414651/table_4          2             мотор
# 2139299  dataset/Dataset/data/1004039/table_4          4             мотор
# ...                                       ...        ...               ...
# 813954   dataset/Dataset/data/2479117/table_4          1           команда
# 813955   dataset/Dataset/data/2706454/table_5          1           команда
# 813956   dataset/Dataset/data/4989442/table_1          1           команда
# 813948    dataset/Dataset/data/761249/table_0          0           команда
# 1039044  dataset/Dataset/data/6684078/table_0          2            партия
#
#              label          similarity
# 3133886    философ  0.7839148044586182
# 3133884    философ  0.7839148044586182
# 3133885    философ  0.7839148044586182
# 2139300  двигатель  0.7861505150794983
# 2139299  двигатель  0.7861505150794983
# ...            ...                 ...
# 813954     команда  1.0000001192092896
# 813955     команда  1.0000001192092896
# 813956     команда  1.0000001192092896
# 813948     команда  1.0000001192092896
# 1039044     партия  1.0000001192092896
#
# [1508422 rows x 5 columns]

# %%
df_threshold["label"].value_counts()[:170]
# Out:
# label
# год           252264
# название      188881
# место         117167
# дата          107979
# команда        82698
#                ...
# колледж           93
# префектура        93
# борец             93
# фирма             92
# дорога            92
# Name: count, Length: 170, dtype: int64

# %%
__mask = df_threshold["label"].value_counts()[:170].index

df_threshold = df_threshold[df_threshold["label"].isin(__mask)]
df_threshold
# Out:
#                                      table_id  column_id column_name_lemma  \
# 24885    dataset/Dataset/data/4022432/table_0          0               год
# 24886    dataset/Dataset/data/1777076/table_0          0               год
# 24887     dataset/Dataset/data/143639/table_0          0               год
# 24888    dataset/Dataset/data/1274811/table_2          0               год
# 24889    dataset/Dataset/data/1250015/table_1          0               год
# ...                                       ...        ...               ...
# 3222708  dataset/Dataset/data/3660091/table_2          0           команда
# 3222709  dataset/Dataset/data/3660091/table_2          1           команда
# 3222710  dataset/Dataset/data/3660091/table_2          2           команда
# 3222711  dataset/Dataset/data/3660091/table_2          3           команда
# 3222714  dataset/Dataset/data/7525778/table_0          4            альбом
#
#            label          similarity
# 24885        год  0.9999999403953552
# 24886        год  0.9999999403953552
# 24887        год  0.9999999403953552
# 24888        год  0.9999999403953552
# 24889        год  0.9999999403953552
# ...          ...                 ...
# 3222708  команда  1.0000001192092896
# 3222709  команда  1.0000001192092896
# 3222710  команда  1.0000001192092896
# 3222711  команда  1.0000001192092896
# 3222714   альбом                 1.0
#
# [1505003 rows x 5 columns]

# %%
df_threshold.sort_values("table_id", inplace=True)
df_threshold
# Out:
#                                      table_id  column_id column_name_lemma  \
# 2366161  dataset/Dataset/data/1000006/table_0          0             театр
# 2532049  dataset/Dataset/data/1000006/table_0          1         спектакль
# 1056778  dataset/Dataset/data/1000006/table_0          4        примечание
# 1201015  dataset/Dataset/data/1000006/table_1          2          название
# 84764    dataset/Dataset/data/1000006/table_1          0               год
# ...                                       ...        ...               ...
# 750279    dataset/Dataset/data/999987/table_0          6         результат
# 880312    dataset/Dataset/data/999987/table_0          2            турнир
# 164720    dataset/Dataset/data/999987/table_0          0               год
# 539279    dataset/Dataset/data/999987/table_0          7             место
# 1351778   dataset/Dataset/data/999987/table_0          1             город
#
#               label          similarity
# 2366161       театр                 1.0
# 2532049       пьеса  0.7898139357566833
# 1056778  примечание  1.0000001192092896
# 1201015    название                 1.0
# 84764           год  0.9999999403953552
# ...             ...                 ...
# 750279    результат                 1.0
# 880312       турнир                 1.0
# 164720          год  0.9999999403953552
# 539279        место  0.9999999403953552
# 1351778       город  1.0000001192092896
#
# [1505003 rows x 5 columns]

# %%
df_threshold[df_threshold["similarity"].astype(float) >= 0.999]
# Out:
#                                      table_id  column_id column_name_lemma  \
# 2366161  dataset/Dataset/data/1000006/table_0          0             театр
# 1056778  dataset/Dataset/data/1000006/table_0          4        примечание
# 1201015  dataset/Dataset/data/1000006/table_1          2          название
# 84764    dataset/Dataset/data/1000006/table_1          0               год
# 2366198  dataset/Dataset/data/1000007/table_0          0             театр
# ...                                       ...        ...               ...
# 750279    dataset/Dataset/data/999987/table_0          6         результат
# 880312    dataset/Dataset/data/999987/table_0          2            турнир
# 164720    dataset/Dataset/data/999987/table_0          0               год
# 539279    dataset/Dataset/data/999987/table_0          7             место
# 1351778   dataset/Dataset/data/999987/table_0          1             город
#
#               label          similarity
# 2366161       театр                 1.0
# 1056778  примечание  1.0000001192092896
# 1201015    название                 1.0
# 84764           год  0.9999999403953552
# 2366198       театр                 1.0
# ...             ...                 ...
# 750279    результат                 1.0
# 880312       турнир                 1.0
# 164720          год  0.9999999403953552
# 539279        место  0.9999999403953552
# 1351778       город  1.0000001192092896
#
# [1464839 rows x 5 columns]

# %%
len(df_threshold["label"].unique())
# Out:
# 170

# %%
df_threshold.to_csv(f"./labelled/threshold_{threshold}.csv", sep=";", index=False)
