# %%
# !pip install glob2

# %%
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

import gensim.downloader
import numpy as np

from pathlib import Path

import glob

# %% [markdown]
# # 1. Лемматизация
#
# Дальнейшая разметка строится на предположении, что первое существительное в заголовке столбца отражает ту сущность, которая в нем содержится

# %%
import spacy

nlp = spacy.load("ru_core_news_sm", disable=['parser', 'ner'])

def lemmatize_word(word: str) -> str|None:
    for token in nlp(sequence):
        if token.pos_ == "NOUN":
            return token.lemma_
    return None

# %%
number_of_chunks = len(glob.glob("./cleansed/*"))

for chunk_id in range(number_of_chunks):
    if not Path(f"./lemmatized/lemmatized_{chunk_id}.csv").exists():
        df_cleansed = pd.read_csv(f"./cleansed/df_cleansed_{chunk_id}.csv", sep=";")
    
        df_cleansed.loc[:, "column_name"] = df_cleansed["column_name"].progress_apply(lemmatize_word)
        df_cleansed.to_csv(f"./lemmatized/lemmatized_{chunk_id}.csv", sep=";", index=False)

# %%
df_list = []

for i in range(number_of_chunks):
    df_list.append(
        pd.read_csv(f"lemmatized/lemmatized_{i}.csv", sep=";")
    )
df = pd.concat(df_list, axis=0)
df
# Out:
#                                                table_id  column_id  \
# 0        dataset/Dataset/data/7779522/table_0_meta.json          0
# 1        dataset/Dataset/data/7779522/table_0_meta.json          1
# 2       dataset/Dataset/data/2863377/table_11_meta.json          1
# 3       dataset/Dataset/data/2863377/table_11_meta.json          9
# 4        dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                 ...        ...
# 337142     dataset/Dataset/data/35185/table_5_meta.json          2
# 337143     dataset/Dataset/data/35185/table_5_meta.json          3
# 337144     dataset/Dataset/data/35185/table_5_meta.json          4
# 337145     dataset/Dataset/data/35185/table_5_meta.json          5
# 337146     dataset/Dataset/data/35185/table_5_meta.json          6
#
#           column_name
# 0                чарт
# 1       высшаяпозиция
# 2             команда
# 3                очки
# 4                 год
# ...               ...
# 337142           дата
# 337143           дата
# 337144           дата
# 337145           дата
# 337146           дата
#
# [3371478 rows x 3 columns]

# %%
unique_col_name_df = df.drop_duplicates(subset=["column_name"])
unique_col_name_df
# Out:
#                                                table_id  column_id  \
# 0        dataset/Dataset/data/7779522/table_0_meta.json          0
# 1        dataset/Dataset/data/7779522/table_0_meta.json          1
# 2       dataset/Dataset/data/2863377/table_11_meta.json          1
# 3       dataset/Dataset/data/2863377/table_11_meta.json          9
# 4        dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                 ...        ...
# 333591    dataset/Dataset/data/561562/table_2_meta.json          3
# 335746   dataset/Dataset/data/6446239/table_0_meta.json          5
# 336733    dataset/Dataset/data/956099/table_0_meta.json          0
# 336734    dataset/Dataset/data/956099/table_0_meta.json          1
# 336735    dataset/Dataset/data/956099/table_0_meta.json          2
#
#           column_name
# 0                чарт
# 1       высшаяпозиция
# 2             команда
# 3                очки
# 4                 год
# ...               ...
# 333591          подъм
# 335746          секеи
# 336733          ибаге
# 336734        невадос
# 336735          норте
#
# [15255 rows x 3 columns]

# %%
unique_col_name_df.sort_values("column_name")["column_name"][:100]
# Out:
# 114170                    аа
# 140548                   аай
# 73017                    аал
# 144824                   аах
# 187760                   аба
#                  ...
# 103534            автоматика
# 41468              автомашин
# 125920    автомобилестроение
# 922               автомобиль
# 28561      автономностьсуток
# Name: column_name, Length: 100, dtype: object

# %% [markdown]
# # 2. Чтение семантических типов
#
# Изначальные типы изменил, которые состояли из > 1 слова для w2v

# %%
sem_types = pd.read_csv("sem_types.txt", sep=";", header=None, names=["labels"])
sem_types = sem_types.drop_duplicates()
sem_types["labels"] = sem_types["labels"].apply(lambda x: str(x).lower())

# %% [markdown]
# # 3. Разметка
# Для кластеризации удаляем столбцы, для которых не было получено ембеддингов

# %%
ru_model = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def get_most_similar(word: str) -> str|None:
    """Need to split afterwards because returns (label cos.sim.value)
    """

    max_similarity = 0
    max_similar_label = None
    
    try:
        ru_model.__getitem__([f"{word}_NOUN"])[0]
    except KeyError:
        return f"{max_similar_label} {max_similarity}"

    for label in sem_types["labels"]:
        try:
            similarity = ru_model.similarity(f"{label}_NOUN", f"{word}_NOUN")
        except KeyError:
            continue

        if similarity > max_similarity:
            max_similarity = similarity
            max_similar_label = label

    return f"{max_similar_label} {max_similarity}"

# %%
if not Path("./labelled/labelled_1.csv").exists():
    df_list = []
    for i in range(number_of_chunks):
        df_list.append(
            pd.read_csv(f"./lemmatized/lemmatized_{i}.csv", sep=";", on_bad_lines="warn")
        )
    df = pd.concat(df_list, axis=0)

    # df = df.sample(frac=0.001)
    
    df["label"] = df["column_name"].progress_apply(get_most_similar)
    df.to_csv("./labelled/labelled_1.csv", sep=";", index=False)
else:
    df = pd.read_csv("./labelled/labelled_1.csv", sep=";")

df
# Out:
#                                                 table_id  column_id  \
# 0         dataset/Dataset/data/7779522/table_0_meta.json          0
# 1         dataset/Dataset/data/7779522/table_0_meta.json          1
# 2        dataset/Dataset/data/2863377/table_11_meta.json          1
# 3        dataset/Dataset/data/2863377/table_11_meta.json          9
# 4         dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                  ...        ...
# 3371473     dataset/Dataset/data/35185/table_5_meta.json          2
# 3371474     dataset/Dataset/data/35185/table_5_meta.json          3
# 3371475     dataset/Dataset/data/35185/table_5_meta.json          4
# 3371476     dataset/Dataset/data/35185/table_5_meta.json          5
# 3371477     dataset/Dataset/data/35185/table_5_meta.json          6
#
#            column_name                           label
# 0                 чарт        сингл 0.5395997762680054
# 1        высшаяпозиция                          None 0
# 2              команда      команда 1.0000001192092896
# 3                 очки  мотоциклист 0.3064345717430115
# 4                  год          год 0.9999999403953552
# ...                ...                             ...
# 3371473           дата                        дата 1.0
# 3371474           дата                        дата 1.0
# 3371475           дата                        дата 1.0
# 3371476           дата                        дата 1.0
# 3371477           дата                        дата 1.0
#
# [3371478 rows x 4 columns]

# %%
df[["label", "similarity"]] = df["label"].str.strip().str.split(" ", n=1, expand=True)
df
# Out:
#                                                 table_id  column_id  \
# 0         dataset/Dataset/data/7779522/table_0_meta.json          0
# 1         dataset/Dataset/data/7779522/table_0_meta.json          1
# 2        dataset/Dataset/data/2863377/table_11_meta.json          1
# 3        dataset/Dataset/data/2863377/table_11_meta.json          9
# 4         dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                  ...        ...
# 3371473     dataset/Dataset/data/35185/table_5_meta.json          2
# 3371474     dataset/Dataset/data/35185/table_5_meta.json          3
# 3371475     dataset/Dataset/data/35185/table_5_meta.json          4
# 3371476     dataset/Dataset/data/35185/table_5_meta.json          5
# 3371477     dataset/Dataset/data/35185/table_5_meta.json          6
#
#            column_name        label          similarity
# 0                 чарт        сингл  0.5395997762680054
# 1        высшаяпозиция         None                   0
# 2              команда      команда  1.0000001192092896
# 3                 очки  мотоциклист  0.3064345717430115
# 4                  год          год  0.9999999403953552
# ...                ...          ...                 ...
# 3371473           дата         дата                 1.0
# 3371474           дата         дата                 1.0
# 3371475           дата         дата                 1.0
# 3371476           дата         дата                 1.0
# 3371477           дата         дата                 1.0
#
# [3371478 rows x 5 columns]

# %%
df["table_id"] = df["table_id"].str.strip().str.split("_meta.json", n=1, expand=True)[0]
df
# Out:
#                                       table_id  column_id    column_name  \
# 0         dataset/Dataset/data/7779522/table_0          0           чарт
# 1         dataset/Dataset/data/7779522/table_0          1  высшаяпозиция
# 2        dataset/Dataset/data/2863377/table_11          1        команда
# 3        dataset/Dataset/data/2863377/table_11          9           очки
# 4         dataset/Dataset/data/4727026/table_0          0            год
# ...                                        ...        ...            ...
# 3371473     dataset/Dataset/data/35185/table_5          2           дата
# 3371474     dataset/Dataset/data/35185/table_5          3           дата
# 3371475     dataset/Dataset/data/35185/table_5          4           дата
# 3371476     dataset/Dataset/data/35185/table_5          5           дата
# 3371477     dataset/Dataset/data/35185/table_5          6           дата
#
#                label          similarity
# 0              сингл  0.5395997762680054
# 1               None                   0
# 2            команда  1.0000001192092896
# 3        мотоциклист  0.3064345717430115
# 4                год  0.9999999403953552
# ...              ...                 ...
# 3371473         дата                 1.0
# 3371474         дата                 1.0
# 3371475         дата                 1.0
# 3371476         дата                 1.0
# 3371477         дата                 1.0
#
# [3371478 rows x 5 columns]

# %% [markdown]
# ## Выбор порогового значения
#
# |порог|кол-во заголовков, схожесть >= порог|
# |-----|------------------------------------|
# |0.1|2.993.652|
# |0.2|2.993.550|
# |0.3|2.968.070|
# |0.4|2.754.081|
# |0.5|2.186.338|
# |0.6|1.659.870|
# |0.7|1.505.095|
# |0.8|1.435.068|
# |0.9|1.427.649|
# |1.0|901.335|
#
# P.s. Значения >= 1.0 за счет погрешности чисел с палвающей точкой

# %%
for i in range(1, 10+1):
    sim = (df["similarity"].apply(float) >= i / 10).sum()
    print(f"{i / 10} : {sim}")
# Out:
# 0.1 : 2993652
# 0.2 : 2993550
# 0.3 : 2968070
# 0.4 : 2754081
# 0.5 : 2186338
# 0.6 : 1659870
# 0.7 : 1505095
# 0.8 : 1435068
# 0.9 : 1427649
# 1.0 : 901335

# %%
threshold = 0.77

df_threshold = df[df["similarity"].astype(float) > threshold]
df_threshold.sort_values("similarity").head(10)
# Out:
#                                      table_id  column_id     column_name  \
# 705762   dataset/Dataset/data/6922823/table_0          0        переулок
# 705763   dataset/Dataset/data/6922823/table_0          1        переулок
# 2832447  dataset/Dataset/data/8487286/table_6          1  бомбардировщик
# 949618   dataset/Dataset/data/5252496/table_1          3  бомбардировщик
# 1186337  dataset/Dataset/data/4496195/table_2          1  бомбардировщик
# 1744297  dataset/Dataset/data/6848959/table_3          3  бомбардировщик
# 3191290  dataset/Dataset/data/4496192/table_2          1  бомбардировщик
# 1773191  dataset/Dataset/data/6247054/table_3          3  бомбардировщик
# 1336802  dataset/Dataset/data/6848960/table_3          3  бомбардировщик
# 2154787  dataset/Dataset/data/5267091/table_3          3  бомбардировщик
#
#            label          similarity
# 705762     улица  0.7720689177513123
# 705763     улица  0.7720689177513123
# 2832447  самолет  0.7729793190956116
# 949618   самолет  0.7729793190956116
# 1186337  самолет  0.7729793190956116
# 1744297  самолет  0.7729793190956116
# 3191290  самолет  0.7729793190956116
# 1773191  самолет  0.7729793190956116
# 1336802  самолет  0.7729793190956116
# 2154787  самолет  0.7729793190956116

# %%
df_threshold.to_csv(f"labelled_threshold_{threshold}.csv", sep=";", index=False)
