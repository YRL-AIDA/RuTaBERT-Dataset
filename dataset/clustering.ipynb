# %% [markdown]
# # Чтение данных

# %%
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

df_cleansed = pd.read_csv("df_cleansed.csv", sep=";")
df_cleansed.shape
# Out:
# (3893128, 3)

# %% [markdown]
# # Лемматизация
#
# *Дальнейшая кластеризация строится на предположении, что первое слово в заголовке столбца отражает ту сущность, которая в нем содержится*

# %% [markdown]
# ## 1. Добавление столбца с первым словом в названии столбца

# %%
df_cleansed["first_word"] = df_cleansed["column_name"].progress_apply(lambda x: str(x).split(" ")[0].lower())
df_cleansed
# Out:
# 100%|████████████████████████████| 3893128/3893128 [00:01<00:00, 2029517.29it/s]
#                                                 table_id  column_id  \
# 0         dataset/Dataset/data/7779522/table_0_meta.json          0
# 1         dataset/Dataset/data/7779522/table_0_meta.json          1
# 2        dataset/Dataset/data/2863377/table_11_meta.json          1
# 3        dataset/Dataset/data/2863377/table_11_meta.json          2
# 4        dataset/Dataset/data/2863377/table_11_meta.json          3
# ...                                                  ...        ...
# 3893123     dataset/Dataset/data/35185/table_5_meta.json          2
# 3893124     dataset/Dataset/data/35185/table_5_meta.json          3
# 3893125     dataset/Dataset/data/35185/table_5_meta.json          4
# 3893126     dataset/Dataset/data/35185/table_5_meta.json          5
# 3893127     dataset/Dataset/data/35185/table_5_meta.json          6
#
#                                  column_name     first_word
# 0                                       Чарт           чарт
# 1                              Высшаяпозиция  высшаяпозиция
# 2                                    Команда        команда
# 3                                          И              и
# 4                                          В              в
# ...                                      ...            ...
# 3893123      Дата получения Любекского права           дата
# 3893124      Дата получения Кульмского права           дата
# 3893125  Дата получения Магдебургского права           дата
# 3893126               Дата вступления в союз           дата
# 3893127                 Дата выхода из союза           дата
#
# [3893128 rows x 4 columns]

# %% [markdown]
# ## 2. Необходимо удалить заголовки имеющие длину < 2 (т.к. вроде бы нет слов меньшей длины)

# %%
# пока что беру длину 3, потому что аббревиатуры не развернуты
no_word_in_header_cleansed = df_cleansed["first_word"].str.len() < 3
df_cleansed[no_word_in_header_cleansed]
# Out:
#                                                 table_id  column_id  \
# 3        dataset/Dataset/data/2863377/table_11_meta.json          2
# 4        dataset/Dataset/data/2863377/table_11_meta.json          3
# 5        dataset/Dataset/data/2863377/table_11_meta.json          4
# 6        dataset/Dataset/data/2863377/table_11_meta.json          5
# 7        dataset/Dataset/data/2863377/table_11_meta.json          6
# ...                                                  ...        ...
# 3893109   dataset/Dataset/data/5909973/table_3_meta.json          5
# 3893110   dataset/Dataset/data/5909973/table_3_meta.json          6
# 3893111   dataset/Dataset/data/5909973/table_3_meta.json          7
# 3893112   dataset/Dataset/data/5909973/table_3_meta.json          8
# 3893113   dataset/Dataset/data/5909973/table_3_meta.json          9
#
#         column_name first_word
# 3                 И          и
# 4                 В          в
# 5                 Н          н
# 6                 П          п
# 7                ГЗ         гз
# ...             ...        ...
# 3893109          ВК         вк
# 3893110          ФФ         фф
# 3893111          БЛ         бл
# 3893112           В          в
# 3893113           П          п
#
# [433065 rows x 4 columns]

# %%
df_cleansed = df_cleansed[~no_word_in_header_cleansed]
df_cleansed
# Out:
#                                                 table_id  column_id  \
# 0         dataset/Dataset/data/7779522/table_0_meta.json          0
# 1         dataset/Dataset/data/7779522/table_0_meta.json          1
# 2        dataset/Dataset/data/2863377/table_11_meta.json          1
# 9        dataset/Dataset/data/2863377/table_11_meta.json          9
# 10        dataset/Dataset/data/4727026/table_0_meta.json          0
# ...                                                  ...        ...
# 3893123     dataset/Dataset/data/35185/table_5_meta.json          2
# 3893124     dataset/Dataset/data/35185/table_5_meta.json          3
# 3893125     dataset/Dataset/data/35185/table_5_meta.json          4
# 3893126     dataset/Dataset/data/35185/table_5_meta.json          5
# 3893127     dataset/Dataset/data/35185/table_5_meta.json          6
#
#                                  column_name     first_word
# 0                                       Чарт           чарт
# 1                              Высшаяпозиция  высшаяпозиция
# 2                                    Команда        команда
# 9                                       Очки           очки
# 10                                       Год            год
# ...                                      ...            ...
# 3893123      Дата получения Любекского права           дата
# 3893124      Дата получения Кульмского права           дата
# 3893125  Дата получения Магдебургского права           дата
# 3893126               Дата вступления в союз           дата
# 3893127                 Дата выхода из союза           дата
#
# [3460063 rows x 4 columns]

# %%
df_cleansed["column_name"].isna().sum()
# Out:
# 0

# %% [markdown]
# ##  Далее работаю с подвыборкой, из-за нехватки ресурсов

# %%
df_cleansed_sample = df_cleansed.sample(random_state=2023, frac=0.025)
df_cleansed_sample
# Out:
#                                                table_id  column_id  \
# 485994   dataset/Dataset/data/1674874/table_0_meta.json         10
# 486568   dataset/Dataset/data/8058169/table_1_meta.json          6
# 130087   dataset/Dataset/data/4854488/table_0_meta.json          5
# 2142820  dataset/Dataset/data/8668795/table_1_meta.json          1
# 101958   dataset/Dataset/data/6067630/table_0_meta.json          0
# ...                                                 ...        ...
# 2629364  dataset/Dataset/data/7003087/table_3_meta.json          2
# 564906   dataset/Dataset/data/6079239/table_3_meta.json          1
# 293782   dataset/Dataset/data/6732730/table_0_meta.json          0
# 1267866  dataset/Dataset/data/4068147/table_0_meta.json          3
# 1014921  dataset/Dataset/data/6644420/table_1_meta.json          3
#
#           column_name   first_word
# 485994            Окт          окт
# 486568    Комментарии  комментарии
# 130087      Произвкод    произвкод
# 2142820        Турнир       турнир
# 101958            Год          год
# ...               ...          ...
# 2629364     Категория    категория
# 564906           Матч         матч
# 293782          Сезон        сезон
# 1267866         Сборы        сборы
# 1014921  Счт в финале          счт
#
# [86502 rows x 4 columns]

# %%
len(df_cleansed_sample["first_word"].unique())
# Out:
# 5753

# %% [markdown]
# ## 3. Построение леммы для первого слова заголовка

# %%
import spacy
nlp = spacy.load("ru_core_news_sm", disable=['parser', 'ner'])

# %%
# kernel dies when executes this

def lemmatize_first_word(first_word: str) -> str:
    try:
        return nlp(first_word)[0].lemma_
    except IndexError:
        return None

df_cleansed_sample["first_word_lemma"] = df_cleansed_sample["first_word"].progress_apply(lemmatize_first_word)
# Out:
# 100%|████████████████████████████████████| 86502/86502 [01:45<00:00, 818.89it/s]

# %%
df_cleansed_sample["first_word_lemma"].isna().sum()
# Out:
# 0

# %% [markdown]
# # Создание эмбеддингов
# Для кластеризации удаляю столбцы, для которых не было получено ембеддингов

# %%
import gensim.downloader
import numpy as np

ru_model = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def get_embedding(word: str) -> list|None:
    try:
        return ru_model.__getitem__([f"{word}_NOUN"])[0].astype(float)
    except KeyError:
        return None

df_cleansed_sample["embedding"] = df_cleansed_sample["first_word_lemma"].progress_apply(get_embedding)
df_cleansed_sample
# Out:
# 100%|█████████████████████████████████| 86502/86502 [00:00<00:00, 241196.31it/s]
#                                                table_id  column_id  \
# 485994   dataset/Dataset/data/1674874/table_0_meta.json         10
# 486568   dataset/Dataset/data/8058169/table_1_meta.json          6
# 130087   dataset/Dataset/data/4854488/table_0_meta.json          5
# 2142820  dataset/Dataset/data/8668795/table_1_meta.json          1
# 101958   dataset/Dataset/data/6067630/table_0_meta.json          0
# ...                                                 ...        ...
# 2629364  dataset/Dataset/data/7003087/table_3_meta.json          2
# 564906   dataset/Dataset/data/6079239/table_3_meta.json          1
# 293782   dataset/Dataset/data/6732730/table_0_meta.json          0
# 1267866  dataset/Dataset/data/4068147/table_0_meta.json          3
# 1014921  dataset/Dataset/data/6644420/table_1_meta.json          3
#
#           column_name   first_word first_word_lemma  \
# 485994            Окт          окт              окт
# 486568    Комментарии  комментарии      комментарий
# 130087      Произвкод    произвкод        произвкод
# 2142820        Турнир       турнир           турнир
# 101958            Год          год              год
# ...               ...          ...              ...
# 2629364     Категория    категория        категория
# 564906           Матч         матч             матч
# 293782          Сезон        сезон            сезон
# 1267866         Сборы        сборы             сбор
# 1014921  Счт в финале          счт              счт
#
#                                                  embedding
# 485994   [0.11048173159360886, -0.06807802617549896, 0....
# 486568   [0.07857518643140793, -0.005067707505077124, -...
# 130087                                                None
# 2142820  [-0.016068028286099434, -0.013522529974579811,...
# 101958   [-0.02274102345108986, -0.043927066028118134, ...
# ...                                                    ...
# 2629364  [0.06008725240826607, -0.03459995612502098, -0...
# 564906   [0.04683051258325577, 0.012336688116192818, 0....
# 293782   [0.02808276005089283, -0.012687585316598415, 0...
# 1267866  [0.1548513025045395, 0.04657189920544624, 0.00...
# 1014921                                               None
#
# [86502 rows x 6 columns]

# %% [markdown]
# ## Фильтрация столбцов, для которых не построились эмбеддинги

# %%
mask_hasnt_embedding = df_cleansed_sample["embedding"].isna()
df_cleansed_sample = df_cleansed_sample[~mask_hasnt_embedding]
df_cleansed_sample
# Out:
#                                                table_id  column_id  \
# 485994   dataset/Dataset/data/1674874/table_0_meta.json         10
# 486568   dataset/Dataset/data/8058169/table_1_meta.json          6
# 2142820  dataset/Dataset/data/8668795/table_1_meta.json          1
# 101958   dataset/Dataset/data/6067630/table_0_meta.json          0
# 2819355  dataset/Dataset/data/1948124/table_0_meta.json         13
# ...                                                 ...        ...
# 2419080  dataset/Dataset/data/1804657/table_2_meta.json          0
# 2629364  dataset/Dataset/data/7003087/table_3_meta.json          2
# 564906   dataset/Dataset/data/6079239/table_3_meta.json          1
# 293782   dataset/Dataset/data/6732730/table_0_meta.json          0
# 1267866  dataset/Dataset/data/4068147/table_0_meta.json          3
#
#                                               column_name   first_word  \
# 485994                                                Окт          окт
# 486568                                        Комментарии  комментарии
# 2142820                                            Турнир       турнир
# 101958                                                Год          год
# 2819355  ЗАЗ подразделение УкрАвто  время выпуска с  года          заз
# ...                                                   ...          ...
# 2419080                                             Тариф        тариф
# 2629364                                         Категория    категория
# 564906                                               Матч         матч
# 293782                                              Сезон        сезон
# 1267866                                             Сборы        сборы
#
#         first_word_lemma                                          embedding
# 485994               окт  [0.11048173159360886, -0.06807802617549896, 0....
# 486568       комментарий  [0.07857518643140793, -0.005067707505077124, -...
# 2142820           турнир  [-0.016068028286099434, -0.013522529974579811,...
# 101958               год  [-0.02274102345108986, -0.043927066028118134, ...
# 2819355              заз  [0.007524707354605198, 0.12947626411914825, -0...
# ...                  ...                                                ...
# 2419080            тариф  [-0.03294992819428444, 0.0019375268602743745, ...
# 2629364        категория  [0.06008725240826607, -0.03459995612502098, -0...
# 564906              матч  [0.04683051258325577, 0.012336688116192818, 0....
# 293782             сезон  [0.02808276005089283, -0.012687585316598415, 0...
# 1267866             сбор  [0.1548513025045395, 0.04657189920544624, 0.00...
#
# [72292 rows x 6 columns]

# %% [markdown]
# # Кластеризация
#
# ---
# - DBScan O(n^2) + съедает ресурсы, не подходит для датасета.
# - Использую mini batch k-means
#
# Можно улучшить, взяв параллельный k-means на cuda https://github.com/src-d/kmcuda
#
# ---

# %% [markdown]
# ## Reshape embeddings

# %%
import numpy as np
from random import randint

rs = 13

embeddings_reshaped = np.array(list(map(lambda x: x, df_cleansed_sample["embedding"])))
embeddings_reshaped.shape

df_cls = pd.DataFrame()
df_cls["first_word_lemma"] = df_cleansed_sample["first_word_lemma"]

# %% [markdown]
# ## DBSCAN - out of memory

# %%
from sklearn.cluster import DBSCAN

name = "dbscan"
model = DBSCAN

# df_cls[name] = model().fit_predict(embeddings_reshaped)

# %% [markdown]
# ## Affinity propagation - out of memory

# %%
from sklearn.cluster import AffinityPropagation

name = "affinity_prop"
model = AffinityPropagation
# df_cls[name] = model().fit_predict(embeddings_reshaped)

# %% [markdown]
# ## Gaussian mixture

# %% [markdown]
# ## BIRCH

# %%
from sklearn.cluster import Birch

num_clusters = 150
name = "birch"
model = Birch

df_cls[name] = model(n_clusters=num_clusters).fit_predict(embeddings_reshaped)

# %%
df_cls[df_cls[name] == randint(0, num_clusters - 1)]
# Out:
#         first_word_lemma  birch
# 1914224        нарушение     93
# 2228539            режим     93
# 286363           условие     93
# 1143357            режим     93
# 236494           условие     93
# 6296               режим     93
# 821728           условие     93
# 3645157          условие     93
# 1320229       требование     93
# 2499136          правило     93
# 3577113          правило     93
# 1574578          условие     93
# 1665899          условие     93
# 1451062          условие     93
# 2754442          правило     93
# 1450958            режим     93
# 3300424        нарушение     93
# 862874         нарушение     93
# 3671860            режим     93
# 699147           условие     93
# 3141071            режим     93
# 1443659       требование     93
# 739321           правило     93
# 2875233        нарушение     93
# 2413238            режим     93
# 203294           правило     93
# 2401193            режим     93
# 913829           правило     93
# 3780765          условие     93
# 1271246          правило     93
# 89949            правило     93
# 1840814            закон     93
# 2398352          правило     93
# 1329321          условие     93
# 869824             режим     93
# 1915857          правило     93
# 1242332          правило     93
# 2357596          условие     93
# 1207675       требование     93
# 898345             режим     93
# 3037078          условие     93
# 538506             режим     93
# 2652331            режим     93
# 2676005          правило     93
# 3556851            режим     93
# 3610372       требование     93
# 808631           правило     93
# 741547           условие     93

# %%
df_cls[df_cls[name] == randint(0, num_clusters - 1)]["first_word_lemma"].unique()
# Out:
# array(['область', 'сфера'], dtype=object)

# %% [markdown]
# ## Mean-Shift - slow

# %%
from sklearn.cluster import MeanShift

name = "mean_shift"
model = MeanShift

# df_cls[name] = model().fit_predict(embeddings_reshaped)

# %%
# df_cls[df_cls[name] == randint(0, num_clusters - 1)]

# %%
# df_cls[df_cls[name] == randint(0, num_clusters - 1)]["first_word_lemma"].unique()

# %% [markdown]
# ## OPTICS - slow

# %%
from sklearn.cluster import OPTICS

name = "optics"
model = OPTICS
#df_cls[name] = model().fit_predict(embeddings_reshaped)

#num_clusters = max(df_cls[name])

# %%
#df_cls[df_cls[name] == randint(0, num_clusters - 1)]

# %%
#df_cls[df_cls[name] == randint(0, num_clusters - 1)]["first_word_lemma"].unique()

# %% [markdown]
# ## Agglomerative Hierarchy - memory error

# %%
from sklearn.cluster import AgglomerativeClustering

num_clusters = 100

name = "agglomerative"
model = AgglomerativeClustering
# df_cls[name] = model(n_clusters=num_clusters).fit_predict(embeddings_reshaped)

# %%
# df_cls[df_cls[name] == randint(0, num_clusters - 1)]

# %%
# df_cls[df_cls[name] == randint(0, num_clusters - 1)]["first_word_lemma"].unique()

# %% [markdown]
# ## K-means

# %%
from sklearn.cluster import KMeans

num_clusters = 150

name = "kmeans"
model = KMeans
df_cls[name] = model(n_clusters=num_clusters, random_state=rs).fit_predict(embeddings_reshaped)
# Out:
# /home/kirilltobola/Dev/github.com/isp/cta/venv/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df_cls[df_cls[name] == randint(0, num_clusters - 1)]
# Out:
#         first_word_lemma  birch  kmeans
# 324521           участие    136      66
# 352073          участник    136      66
# 200924         участница    136      66
# 2823746         участник    136      66
# 2865674         участник    136      66
# ...                  ...    ...     ...
# 1257771         участник    136      66
# 1261984         участник    136      66
# 3020629          участие    136      66
# 2957947          участие    136      66
# 441320          участник    136      66
#
# [193 rows x 3 columns]

# %%
df_cls[df_cls[name] == randint(0, num_clusters - 1)]["first_word_lemma"].unique()
# Out:
# array(['продажа', 'цена', 'рынок', 'производство', 'выпуск', 'торговля',
#        'потребление', 'экспорт', 'импорт', 'сбыт', 'покупка'],
#       dtype=object)

# %% [markdown]
# ## Mini batch k-means
# Берется батч (срез) данных, по ним строится k-means, за счет чего быстро работает)

# %%
from sklearn.cluster import MiniBatchKMeans

num_clusters = 150

name = "minibatch-kmeans"
model = MiniBatchKMeans
df_cls[name] = model(n_clusters=num_clusters, random_state=rs, max_iter=200).fit_predict(embeddings_reshaped)
# Out:
# /home/kirilltobola/Dev/github.com/isp/cta/venv/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1934: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=3)

# %%
df_cls[df_cls[name] == randint(0, num_clusters - 1)]
# Out:
#         first_word_lemma  birch  kmeans  minibatch-kmeans
# 258312             титул     69      37                17
# 2107730            титул     69      37                17
# 12389              титул     69      37                17
# 1504007            титул     69      37                17
# 3617617            титул     69      37                17
# ...                  ...    ...     ...               ...
# 2502191            титул     69      37                17
# 2874759            титул     69      37                17
# 2569681            титул     69      37                17
# 3678911            титул     69      37                17
# 1469638            титул     69      37                17
#
# [607 rows x 4 columns]

# %%
df_cls[df_cls[name] == randint(0, num_clusters - 1)]["first_word_lemma"].unique()
# Out:
# array(['код', 'расшифровка', 'кодирование', 'кодировка'], dtype=object)
